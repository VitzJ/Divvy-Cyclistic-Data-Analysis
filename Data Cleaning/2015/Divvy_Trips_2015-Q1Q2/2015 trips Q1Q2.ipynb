# %%
import pandas as pd

df = pd.concat([pd.read_csv('Divvy_Trips_2015-Q1.csv'), pd.read_csv('Divvy_Trips_2015-Q2.csv')], ignore_index=True)

# %%
df
# Out:
#          trip_id        starttime       stoptime  bikeid  tripduration  \
# 0        4738454  3/31/2015 23:58  4/1/2015 0:03    1095           299
# 1        4738450  3/31/2015 23:59  4/1/2015 0:15     537           940
# 2        4738449  3/31/2015 23:59  4/1/2015 0:11    2350           751
# 3        4738448  3/31/2015 23:59  4/1/2015 0:19     938          1240
# 4        4738445  3/31/2015 23:54  4/1/2015 0:15     379          1292
# ...          ...              ...            ...     ...           ...
# 1096234  4738459    4/1/2015 0:05  4/1/2015 0:07     422           122
# 1096235  4738458    4/1/2015 0:04  4/1/2015 0:15     320           675
# 1096236  4738457    4/1/2015 0:03  4/1/2015 0:09    2757           363
# 1096237  4738456    4/1/2015 0:03  4/1/2015 0:14    2923           667
# 1096238  4738451    4/1/2015 0:00  4/1/2015 0:02     422           134
#
#          from_station_id               from_station_name  to_station_id  \
# ...

# %%
df.to_csv('Divvy_Trips_2015_Q1Q2.csv')
