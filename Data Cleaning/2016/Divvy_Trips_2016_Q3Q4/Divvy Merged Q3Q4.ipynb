# %%
import pandas as pd

stations = pd.read_csv('Divvy_Stations_2016_Q3.csv')
trips = pd.read_csv('Divvy_Trips_2016_Q3.csv')

# %% [markdown]
# # Metadata for Trips Table Q3 - Q4:
#
# Variables:
#
# trip_id: ID attached to each trip taken
#
# starttime: day and time trip started, in CST
#
# stoptime: day and time trip ended, in CST
#
# bikeid: ID attached to each bike
#
# tripduration: time of trip in seconds
#
# from_station_name: name of station where trip originated
#
# to_station_name: name of station where trip terminated
#
# from_station_id: ID of station where trip originated
#
# to_station_id: ID of station where trip terminated
#
# usertype: "Customer" is a rider who purchased a 24-Hour Pass; "Subscriber" is a rider who purchased an Annual Membership
#
# gender: gender of rider
#
# birthyear: birth year of rider
#
#
# Notes:
#
# * First row contains column names
# * Total records = 683,832
# * Trips that did not include a start or end date were removed from original table.
# * Gender and birthday are only available for Subscribers

# %% [markdown]
# # Metadata for Stations table Q3:
#
# Variables:
#
# id: ID attached to each station
#
# name: station name
#
# latitude: station latitude
#
# longitude: station longitude
#
# dpcapacity: number of total docks at each station as of 9/30/2016
#
# online_date: date the station went live in the system

# %% [markdown]
# # Metadata for Stations table Q4:
#
# Variables:
#
# id: ID attached to each station
#
# name: station name
#
# latitude: station latitude
#
# longitude: station longitude
#
# dpcapacity: number of total docks at each station as of 9/30/2016
#
# online_date: date the station went live in the system

# %%
trips
# Out:
#           trip_id           starttime            stoptime  bikeid  \
# 0        12150160  9/30/2016 23:59:58  10/1/2016 00:04:03    4959
# 1        12150159  9/30/2016 23:59:58  10/1/2016 00:04:09    2589
# 2        12150158  9/30/2016 23:59:51  10/1/2016 00:24:51    3656
# 3        12150157  9/30/2016 23:59:51  10/1/2016 00:03:56    3570
# 4        12150156  9/30/2016 23:59:32  10/1/2016 00:26:50    3158
# ...           ...                 ...                 ...     ...
# 1441806  10426662   7/1/2016 00:02:30   7/1/2016 00:08:32    4225
# 1441807  10426661   7/1/2016 00:02:14   7/1/2016 00:16:57    1757
# 1441808  10426660   7/1/2016 00:02:09   7/1/2016 00:16:28    1687
# 1441809  10426659   7/1/2016 00:01:58   7/1/2016 00:47:30    3151
# 1441810  10426658   7/1/2016 00:01:14   7/1/2016 00:03:37    5228
#
#          tripduration  from_station_id               from_station_name  \
# 0                 245               69          Damen Ave & Pierce Ave
# 1                 251              383       Ashland Ave & Harrison St
# 2                1500              302  Sheffield Ave & Wrightwood Ave
# 3                 245              475    Washtenaw Ave & Lawrence Ave
# 4                1638              302  Sheffield Ave & Wrightwood Ave
# ...               ...              ...                             ...
# 1441806           362              294           Broadway & Berwyn Ave
# 1441807           884              264    Stetson Ave & South Water St
# 1441808           860              264    Stetson Ave & South Water St
# 1441809          2732              177             Theater on the Lake
# 1441810           143              246  Ashland Ave & Belle Plaine Ave
#
#          to_station_id              to_station_name    usertype  gender  \
# 0                   17        Wood St & Division St  Subscriber    Male
# 1                  320     Loomis St & Lexington St  Subscriber  Female
# 2                  334  Lake Shore Dr & Belmont Ave    Customer     NaN
# 3                  471   Francisco Ave & Foster Ave  Subscriber  Female
# 4                  492      Leavitt St & Addison St    Customer     NaN
# ...                ...                          ...         ...     ...
# 1441806            458     Broadway & Thorndale Ave  Subscriber    Male
# 1441807            168       Michigan Ave & 14th St  Subscriber    Male
# 1441808            168       Michigan Ave & 14th St  Subscriber  Female
# 1441809            340    Clark St & Wrightwood Ave    Customer     NaN
# 1441810            292     Southport Ave & Clark St  Subscriber    Male
#
#          birthyear
# 0           1988.0
# 1           1990.0
# 2              NaN
# 3           1988.0
# 4              NaN
# ...            ...
# 1441806     1980.0
# 1441807     1965.0
# 1441808     1964.0
# 1441809        NaN
# 1441810     1983.0
#
# [1441811 rows x 12 columns]

# %%
stations
# Out:
#       id                          name   latitude  longitude  dpcapacity  \
# 0    456           2112 W Peterson Ave  41.991178 -87.683593          15
# 1    101                 63rd St Beach  41.781016 -87.576120          23
# 2    109             900 W Harrison St  41.874675 -87.650019          19
# 3     21    Aberdeen St & Jackson Blvd  41.877726 -87.654787          15
# 4     80       Aberdeen St & Monroe St  41.880420 -87.655599          19
# ..   ...                           ...        ...        ...         ...
# 576  317           Wood St & Taylor St  41.869154 -87.671045          23
# 577  248        Woodlawn Ave & 55th St  41.795264 -87.596471          19
# 578  569        Woodlawn Ave & 75th St  41.759160 -87.595751          15
# 579  413  Woodlawn Ave & Lake Park Ave  41.814093 -87.597005          15
# 580  396          Yates Blvd & 75th St  41.758768 -87.566440          11
#
#     online_date
# 0     5/12/2015
# 1     4/20/2015
# 2      8/6/2013
# 3     6/21/2013
# 4     6/26/2013
# ..          ...
# 576   9/21/2013
# 577   8/23/2013
# 578   6/23/2016
# 579   4/14/2015
# 580    5/7/2015
#
# [581 rows x 6 columns]

# %%
stations = stations.drop(['name','online_date'], axis=1)
from_stations = stations
from_stations = from_stations.rename(columns = {'id': 'from_station_id', 'latitude' : 'from_station_latitude', 'longitude' : 'from_station_longitude'})
from_stations = from_stations.drop_duplicates()
df = pd.merge(trips, from_stations, how='left', on=['from_station_id'], left_on=None, right_on=None,
      left_index=False, right_index=False, sort=True,
      suffixes=('_x', '_y'), copy=True)
to_stations = stations.drop(['dpcapacity'],axis=1)
to_stations = to_stations.rename(columns = {'id': 'to_station_id', 'latitude' : 'to_station_latitude', 'longitude' : 'to_station_longitude'})
to_stations = to_stations.drop_duplicates()
df = pd.merge(df, to_stations, how='left', on=['to_station_id'], left_on=None, right_on=None,
      left_index=False, right_index=False, sort=True,
      suffixes=('_x', '_y'), copy=True)

# %%
df
# Out:
#           trip_id           starttime            stoptime  bikeid  \
# 0        12142530  9/30/2016 12:04:34  9/30/2016 13:01:05    1482
# 1        12142479  9/30/2016 11:59:17  9/30/2016 13:00:57    1142
# 2        12142468  9/30/2016 11:57:04  9/30/2016 13:00:48    1238
# 3        12142463  9/30/2016 11:56:41  9/30/2016 13:01:05    2484
# 4        12115649  9/27/2016 22:14:17  9/27/2016 22:44:40    1412
# ...           ...                 ...                 ...     ...
# 1441806  11925265  9/17/2016 10:19:15  9/17/2016 10:21:49    2504
# 1441807  11814658  9/11/2016 10:21:14  9/11/2016 10:23:55    1144
# 1441808  12099001  9/26/2016 22:10:03  9/26/2016 22:11:15    4272
# 1441809  12098543  9/26/2016 21:04:22  9/26/2016 21:05:41    4272
# 1441810  11857528  9/13/2016 14:45:27  9/13/2016 14:52:44    3932
#
#          tripduration  from_station_id                     from_station_name  \
# 0                3391                2              Michigan Ave & Balbo Ave
# 1                3700                2              Michigan Ave & Balbo Ave
# 2                3824                2              Michigan Ave & Balbo Ave
# 3                3864                2              Michigan Ave & Balbo Ave
# 4                1823                2              Michigan Ave & Balbo Ave
# ...               ...              ...                                   ...
# 1441806           155              364                  Larrabee St & Oak St
# 1441807           161              364                  Larrabee St & Oak St
# 1441808            72              620  Orleans St & Chestnut St (NEXT Apts)
# 1441809            79              620  Orleans St & Chestnut St (NEXT Apts)
# 1441810           437              620  Orleans St & Chestnut St (NEXT Apts)
#
#          to_station_id                       to_station_name    usertype  \
# 0                    2              Michigan Ave & Balbo Ave    Customer
# 1                    2              Michigan Ave & Balbo Ave    Customer
# 2                    2              Michigan Ave & Balbo Ave    Customer
# 3                    2              Michigan Ave & Balbo Ave    Customer
# 4                    2              Michigan Ave & Balbo Ave    Customer
# ...                ...                                   ...         ...
# 1441806            620  Orleans St & Chestnut St (NEXT Apts)  Subscriber
# 1441807            620  Orleans St & Chestnut St (NEXT Apts)  Subscriber
# 1441808            620  Orleans St & Chestnut St (NEXT Apts)  Subscriber
# 1441809            620  Orleans St & Chestnut St (NEXT Apts)  Subscriber
# 1441810            620  Orleans St & Chestnut St (NEXT Apts)  Subscriber
#
#         gender  birthyear  from_station_latitude  from_station_longitude  \
# 0          NaN        NaN              41.872638              -87.623979
# 1          NaN        NaN              41.872638              -87.623979
# 2          NaN        NaN              41.872638              -87.623979
# 3          NaN        NaN              41.872638              -87.623979
# 4          NaN        NaN              41.872638              -87.623979
# ...        ...        ...                    ...                     ...
# 1441806   Male     1987.0              41.900219              -87.642985
# 1441807   Male     1987.0              41.900219              -87.642985
# 1441808   Male     1984.0              41.898203              -87.637536
# 1441809   Male     1974.0              41.898203              -87.637536
# 1441810   Male     1967.0              41.898203              -87.637536
#
#          dpcapacity  to_station_latitude  to_station_longitude
# 0                35            41.872638            -87.623979
# 1                35            41.872638            -87.623979
# 2                35            41.872638            -87.623979
# 3                35            41.872638            -87.623979
# 4                35            41.872638            -87.623979
# ...             ...                  ...                   ...
# 1441806          15            41.898203            -87.637536
# 1441807          15            41.898203            -87.637536
# 1441808          15            41.898203            -87.637536
# 1441809          15            41.898203            -87.637536
# 1441810          15            41.898203            -87.637536
#
# [1441811 rows x 17 columns]

# %%
# count nulls in each column
df.isnull().sum(axis=0)
# Out:
# trip_id                        0
# starttime                      0
# stoptime                       0
# bikeid                         0
# tripduration                   0
# from_station_id                0
# from_station_name              0
# to_station_id                  0
# to_station_name                0
# usertype                       0
# gender                    426199
# birthyear                 426080
# from_station_latitude          0
# from_station_longitude         0
# dpcapacity                     0
# to_station_latitude            0
# to_station_longitude           0
# dtype: int64

# %% [markdown]
# Repeat with other section, for Q4

# %%
stations = pd.read_csv('Divvy_Stations_2016_Q4.csv')
trips = pd.read_csv('Divvy_Trips_2016_Q4.csv')

# %%
stations = stations.drop(['name','online_date'], axis=1)
from_stations = stations
from_stations = from_stations.rename(columns = {'id': 'from_station_id', 'latitude' : 'from_station_latitude', 'longitude' : 'from_station_longitude'})
from_stations = from_stations.drop_duplicates()
df2 = pd.merge(trips, from_stations, how='left', on=['from_station_id'], left_on=None, right_on=None,
      left_index=False, right_index=False, sort=True,
      suffixes=('_x', '_y'), copy=True)
to_stations = stations.drop(['dpcapacity'],axis=1)
to_stations = to_stations.rename(columns = {'id': 'to_station_id', 'latitude' : 'to_station_latitude', 'longitude' : 'to_station_longitude'})
to_stations = to_stations.drop_duplicates()
df2 = pd.merge(df2, to_stations, how='left', on=['to_station_id'], left_on=None, right_on=None,
      left_index=False, right_index=False, sort=True,
      suffixes=('_x', '_y'), copy=True)

# %%
df2
# Out:
#          trip_id            starttime             stoptime  bikeid  \
# 0       12943774  12/21/2016 13:26:56  12/21/2016 14:17:29    1026
# 1       12827189  11/27/2016 16:39:22  11/27/2016 17:15:05    3785
# 2       12799902  11/21/2016 18:14:36  11/21/2016 18:56:48     369
# 3       12799900  11/21/2016 18:14:28  11/21/2016 18:56:19    4900
# 4       12779972  11/18/2016 10:22:32  11/18/2016 10:23:46    3850
# ...          ...                  ...                  ...     ...
# 683827  12349798  10/15/2016 10:19:18  10/15/2016 10:21:41    5671
# 683828  12317286  10/13/2016 06:13:03  10/13/2016 06:15:56    2676
# 683829  12261959   10/9/2016 10:22:32   10/9/2016 10:26:07    1410
# 683830  12214571   10/5/2016 18:14:43   10/5/2016 18:16:53    5264
# 683831  12213839   10/5/2016 17:52:39   10/5/2016 17:54:21    5264
#
#         tripduration  from_station_id                     from_station_name  \
# 0               3033                2              Michigan Ave & Balbo Ave
# 1               2143                2              Michigan Ave & Balbo Ave
# 2               2532                2              Michigan Ave & Balbo Ave
# 3               2511                2              Michigan Ave & Balbo Ave
# 4                 74                2              Michigan Ave & Balbo Ave
# ...              ...              ...                                   ...
# 683827           143              364                  Larrabee St & Oak St
# 683828           173              364                  Larrabee St & Oak St
# 683829           215              364                  Larrabee St & Oak St
# 683830           130              620  Orleans St & Chestnut St (NEXT Apts)
# 683831           102              620  Orleans St & Chestnut St (NEXT Apts)
#
#         to_station_id                       to_station_name    usertype  \
# 0                   2              Michigan Ave & Balbo Ave    Customer
# 1                   2              Michigan Ave & Balbo Ave  Subscriber
# 2                   2              Michigan Ave & Balbo Ave    Customer
# 3                   2              Michigan Ave & Balbo Ave    Customer
# 4                   2              Michigan Ave & Balbo Ave  Subscriber
# ...               ...                                   ...         ...
# 683827            620  Orleans St & Chestnut St (NEXT Apts)  Subscriber
# 683828            620  Orleans St & Chestnut St (NEXT Apts)  Subscriber
# 683829            620  Orleans St & Chestnut St (NEXT Apts)  Subscriber
# 683830            620  Orleans St & Chestnut St (NEXT Apts)  Subscriber
# 683831            620  Orleans St & Chestnut St (NEXT Apts)  Subscriber
#
#         gender  birthyear  from_station_latitude  from_station_longitude  \
# 0          NaN        NaN              41.872638              -87.623979
# 1       Female     1990.0              41.872638              -87.623979
# 2          NaN        NaN              41.872638              -87.623979
# 3          NaN        NaN              41.872638              -87.623979
# 4       Female     1967.0              41.872638              -87.623979
# ...        ...        ...                    ...                     ...
# 683827    Male     1987.0              41.900219              -87.642985
# 683828    Male     1982.0              41.900219              -87.642985
# 683829    Male     1987.0              41.900219              -87.642985
# 683830    Male     1990.0              41.898203              -87.637536
# 683831  Female     1994.0              41.898203              -87.637536
#
#         dpcapacity  to_station_latitude  to_station_longitude
# 0               35            41.872638            -87.623979
# 1               35            41.872638            -87.623979
# 2               35            41.872638            -87.623979
# 3               35            41.872638            -87.623979
# 4               35            41.872638            -87.623979
# ...            ...                  ...                   ...
# 683827          15            41.898203            -87.637536
# 683828          15            41.898203            -87.637536
# 683829          15            41.898203            -87.637536
# 683830          15            41.898203            -87.637536
# 683831          15            41.898203            -87.637536
#
# [683832 rows x 17 columns]

# %%
# count nulls in each column
df.isnull().sum(axis=0)
# Out:
# trip_id                        0
# starttime                      0
# stoptime                       0
# bikeid                         0
# tripduration                   0
# from_station_id                0
# from_station_name              0
# to_station_id                  0
# to_station_name                0
# usertype                       0
# gender                    426199
# birthyear                 426080
# from_station_latitude          0
# from_station_longitude         0
# dpcapacity                     0
# to_station_latitude            0
# to_station_longitude           0
# dtype: int64

# %% [markdown]
# Now we merge the datasets into one

# %%
Q3Q4 = pd.concat([df, df2], ignore_index=True)

# %%
Q3Q4
# Out:
#           trip_id            starttime             stoptime  bikeid  \
# 0        12142530   9/30/2016 12:04:34   9/30/2016 13:01:05    1482
# 1        12142479   9/30/2016 11:59:17   9/30/2016 13:00:57    1142
# 2        12142468   9/30/2016 11:57:04   9/30/2016 13:00:48    1238
# 3        12142463   9/30/2016 11:56:41   9/30/2016 13:01:05    2484
# 4        12115649   9/27/2016 22:14:17   9/27/2016 22:44:40    1412
# ...           ...                  ...                  ...     ...
# 2125638  12349798  10/15/2016 10:19:18  10/15/2016 10:21:41    5671
# 2125639  12317286  10/13/2016 06:13:03  10/13/2016 06:15:56    2676
# 2125640  12261959   10/9/2016 10:22:32   10/9/2016 10:26:07    1410
# 2125641  12214571   10/5/2016 18:14:43   10/5/2016 18:16:53    5264
# 2125642  12213839   10/5/2016 17:52:39   10/5/2016 17:54:21    5264
#
#          tripduration  from_station_id                     from_station_name  \
# 0                3391                2              Michigan Ave & Balbo Ave
# 1                3700                2              Michigan Ave & Balbo Ave
# 2                3824                2              Michigan Ave & Balbo Ave
# 3                3864                2              Michigan Ave & Balbo Ave
# 4                1823                2              Michigan Ave & Balbo Ave
# ...               ...              ...                                   ...
# 2125638           143              364                  Larrabee St & Oak St
# 2125639           173              364                  Larrabee St & Oak St
# 2125640           215              364                  Larrabee St & Oak St
# 2125641           130              620  Orleans St & Chestnut St (NEXT Apts)
# 2125642           102              620  Orleans St & Chestnut St (NEXT Apts)
#
#          to_station_id                       to_station_name    usertype  \
# 0                    2              Michigan Ave & Balbo Ave    Customer
# 1                    2              Michigan Ave & Balbo Ave    Customer
# 2                    2              Michigan Ave & Balbo Ave    Customer
# 3                    2              Michigan Ave & Balbo Ave    Customer
# 4                    2              Michigan Ave & Balbo Ave    Customer
# ...                ...                                   ...         ...
# 2125638            620  Orleans St & Chestnut St (NEXT Apts)  Subscriber
# 2125639            620  Orleans St & Chestnut St (NEXT Apts)  Subscriber
# 2125640            620  Orleans St & Chestnut St (NEXT Apts)  Subscriber
# 2125641            620  Orleans St & Chestnut St (NEXT Apts)  Subscriber
# 2125642            620  Orleans St & Chestnut St (NEXT Apts)  Subscriber
#
#          gender  birthyear  from_station_latitude  from_station_longitude  \
# 0           NaN        NaN              41.872638              -87.623979
# 1           NaN        NaN              41.872638              -87.623979
# 2           NaN        NaN              41.872638              -87.623979
# 3           NaN        NaN              41.872638              -87.623979
# 4           NaN        NaN              41.872638              -87.623979
# ...         ...        ...                    ...                     ...
# 2125638    Male     1987.0              41.900219              -87.642985
# 2125639    Male     1982.0              41.900219              -87.642985
# 2125640    Male     1987.0              41.900219              -87.642985
# 2125641    Male     1990.0              41.898203              -87.637536
# 2125642  Female     1994.0              41.898203              -87.637536
#
#          dpcapacity  to_station_latitude  to_station_longitude
# 0                35            41.872638            -87.623979
# 1                35            41.872638            -87.623979
# 2                35            41.872638            -87.623979
# 3                35            41.872638            -87.623979
# 4                35            41.872638            -87.623979
# ...             ...                  ...                   ...
# 2125638          15            41.898203            -87.637536
# 2125639          15            41.898203            -87.637536
# 2125640          15            41.898203            -87.637536
# 2125641          15            41.898203            -87.637536
# 2125642          15            41.898203            -87.637536
#
# [2125643 rows x 17 columns]

# %%
Q3Q4.to_csv('Divvy_2016_Q3Q4.csv')

# %%
Q3Q4.columns
# Out:
# Index(['trip_id', 'starttime', 'stoptime', 'bikeid', 'tripduration',
#        'from_station_id', 'from_station_name', 'to_station_id',
#        'to_station_name', 'usertype', 'gender', 'birthyear',
#        'from_station_latitude', 'from_station_longitude', 'dpcapacity',
#        'to_station_latitude', 'to_station_longitude'],
#       dtype='object')
