# %%
import pandas as pd

df = pd.concat([pd.read_csv('Divvy 2014 Q1Q2 merged.csv'), pd.read_csv('Divvy 2014 Q3Q4 merged.csv')], ignore_index=True)

# %%
df.drop(['Unnamed: 0'],axis=1)
# Out:
#          trip_id         starttime          stoptime  bikeid  tripduration  \
# 0        2340422   6/29/2014 19:48   6/29/2014 21:41    2870          6835
# 1        2340356   6/29/2014 19:44   6/29/2014 21:42    2462          7070
# 2        2330419   6/29/2014 12:44   6/29/2014 14:18    2398          5640
# 3        2323885   6/28/2014 22:10   6/28/2014 22:50    2356          2425
# 4        2315406   6/28/2014 14:25   6/28/2014 14:36    2255           656
# ...          ...               ...               ...     ...           ...
# 2454629  2896950    8/1/2014 16:40    8/1/2014 17:02    2865          1352
# 2454630  4385112  12/21/2014 15:55  12/21/2014 16:57    2197          3677
# 2454631  4385109  12/21/2014 15:55  12/21/2014 16:56     651          3651
# 2454632  3952556  10/14/2014 10:09  10/14/2014 11:15    2002          3980
# 2454633  3859067    10/6/2014 8:31    10/6/2014 8:49     528          1052
#
# ...

# %%
df.to_csv('Divvy 2014 merged.csv')
