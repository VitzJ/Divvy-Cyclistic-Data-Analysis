# %%
import pandas as pd

Q3 = pd.concat([pd.read_csv('Divvy_Trips_2014-Q3-07.csv'), pd.read_csv('Divvy_Trips_2014-Q3-0809.csv')], ignore_index=True)
Q3.to_csv('Divvy_Trips_2014_Q3.csv')
Q3Q4 = pd.concat([pd.read_csv('Divvy_Trips_2014_Q3.csv'), pd.read_csv('Divvy_Trips_2014-Q4.csv')], ignore_index=True)
Q3Q4.to_csv('Divvy_Trips_2014_Q3Q4.csv')

# %% [markdown]
# # Metadata for Trips Table:
#
# Variables:
#
# trip_id: ID attached to each trip taken
#
# starttime: day and time trip started, in CST
#
# stoptime: day and time trip ended, in CST
#
# bikeid: ID attached to each bike
#
# tripduration: time of trip in seconds
#
# from_station_name: name of station where trip originated
#
# to_station_name: name of station where trip terminated
#
# from_station_id: ID of station where trip originated
#
# to_station_id: ID of station where trip terminated
#
# usertype: "Customer" is a rider who purchased a 24-Hour Pass; "Subscriber" is a rider who purchased an Annual Membership
#
# gender: gender of rider
#
# birthyear: birth year of rider
#
#
# Notes:
#
# * First row contains column names
# * Total records =
# Q3-07 = 410,340
# Q3-0809 = 700,630
# Q4 = 437,965
# * Trips that did not include a start or end date were removed from original table.
# * Gender and birthday are only available for Subscribers

# %%
trips = Q3
stations = pd.read_csv('Divvy_Stations_2014-Q3Q4.csv')

# %%
trips
# Out:
#          trip_id        starttime       stoptime  bikeid  tripduration  \
# 0        2886259  7/31/2014 23:56  8/1/2014 0:03    2602           386
# 1        2886258  7/31/2014 23:58  8/1/2014 0:07    2403           495
# 2        2886257  7/31/2014 23:58  8/1/2014 2:10     669          7947
# 3        2886256  7/31/2014 23:58  8/1/2014 0:19    2431          1282
# 4        2886255  7/31/2014 23:57  8/1/2014 2:10    2885          7972
# ...          ...              ...            ...     ...           ...
# 1110965  2886264    8/1/2014 0:01  8/1/2014 0:20      67          1159
# 1110966  2886263    8/1/2014 0:00  8/1/2014 0:13    1452           797
# 1110967  2886262    8/1/2014 0:00  8/1/2014 0:20     334          1172
# 1110968  2886261    8/1/2014 0:00  8/1/2014 0:05    1645           299
# 1110969  2886260    8/1/2014 0:00  8/1/2014 0:11    2887           696
#
#          from_station_id             from_station_name  to_station_id  \
# 0                    291      Wells St & Evergreen Ave             53
# 1                     98    LaSalle St & Washington St            106
# 2                    240  Sheridan Rd & Irving Park Rd            240
# 3                     47          State St & Kinzie St             14
# 4                    240  Sheridan Rd & Irving Park Rd            240
# ...                  ...                           ...            ...
# 1110965              310     Damen Ave & Charleston St            113
# 1110966              330      Lincoln Ave & Addison St            239
# 1110967              310     Damen Ave & Charleston St            113
# 1110968              166  Ashland Ave & Wrightwood Ave            152
# 1110969              251    Clarendon Ave & Leland Ave            299
#
#                       to_station_name    usertype  gender  birthyear
# 0                  Wells St & Erie St  Subscriber  Female     1979.0
# 1               State St & Pearson St  Subscriber    Male     1974.0
# 2        Sheridan Rd & Irving Park Rd    Customer     NaN        NaN
# 3                 Morgan St & 18th St    Customer     NaN        NaN
# 4        Sheridan Rd & Irving Park Rd    Customer     NaN        NaN
# ...                               ...         ...     ...        ...
# 1110965     Bissell St & Armitage Ave    Customer     NaN        NaN
# 1110966      Western Ave & Leland Ave  Subscriber    Male     1977.0
# 1110967     Bissell St & Armitage Ave    Customer     NaN        NaN
# 1110968   Lincoln Ave & Diversey Pkwy  Subscriber    Male     1995.0
# 1110969        Halsted St & Roscoe St  Subscriber    Male     1983.0
#
# [1110970 rows x 12 columns]

# %%
# count nulls in each column
trips.isnull().sum(axis=0)
# Out:
# trip_id                   0
# starttime                 0
# stoptime                  0
# bikeid                    0
# tripduration              0
# from_station_id           0
# from_station_name         0
# to_station_id             0
# to_station_name           0
# usertype                  0
# gender               407669
# birthyear            407685
# dtype: int64

# %% [markdown]
# # Metadata for Stations table:
#
# Variables:
#
# name: station name
#
# latitude: station latitude
#
# longitude: station longitude
#
# dpcapacity: number of total docks at each station as of 12/31/2014
#
# online date: date the station went live in the system

# %%
stations.head()
# Out:
#    id                        name   latitude  longitude  dpcapacity  \
# 0   5      State St & Harrison St  41.873958 -87.627739          19
# 1  13  Wilton Ave & Diversey Pkwy  41.932500 -87.652681          19
# 2  14         Morgan St & 18th St  41.858086 -87.651073          15
# 3  15        Racine Ave & 19th St  41.856453 -87.656471          15
# 4  16         Wood St & North Ave  41.910329 -87.672516          15
#
#        dateCreated
# 0  6/10/2013 10:46
# 1  6/22/2013 18:29
# 2  6/22/2013 18:33
# 3  6/22/2013 18:35
# 4  6/22/2013 18:55

# %%
# count nulls in each column
stations.isnull().sum(axis=0)
# Out:
# id             0
# name           0
# latitude       0
# longitude      0
# dpcapacity     0
# dateCreated    0
# dtype: int64

# %%
stations = stations.drop(['name', 'dateCreated'], axis=1)
from_stations = stations
from_stations = from_stations.rename(columns = {'id': 'from_station_id', 'latitude' : 'from_station_latitude', 'longitude' : 'from_station_longitude'})
from_stations = from_stations.drop_duplicates()
df = pd.merge(trips, from_stations, how='left', on=['from_station_id'], left_on=None, right_on=None,
      left_index=False, right_index=False, sort=True,
      suffixes=('_x', '_y'), copy=True)

# %%
df.head()
# Out:
#    trip_id        starttime         stoptime  bikeid  tripduration  \
# 0  2885586  7/31/2014 22:17  7/31/2014 22:39     866          1297
# 1  2884955  7/31/2014 21:15  7/31/2014 21:22    2375           437
# 2  2884939  7/31/2014 21:18  7/31/2014 21:24    1338           363
# 3  2884725  7/31/2014 20:58  7/31/2014 21:09    1783           691
# 4  2884640  7/31/2014 20:49  7/31/2014 21:15    1454          1557
#
#    from_station_id       from_station_name  to_station_id  \
# 0                5  State St & Harrison St            171
# 1                5  State St & Harrison St             77
# 2                5  State St & Harrison St            168
# 3                5  State St & Harrison St            273
# 4                5  State St & Harrison St            291
#
#             to_station_name    usertype  gender  birthyear  \
# 0     May St & Cullerton St  Subscriber  Female     1985.0
# 1   Clinton St & Madison St  Subscriber    Male     1984.0
# 2    Michigan Ave & 14th St  Subscriber    Male     1983.0
# 3    Michigan Ave & 18th St  Subscriber  Female     1986.0
# 4  Wells St & Evergreen Ave  Subscriber    Male     1985.0
#
#    from_station_latitude  from_station_longitude  dpcapacity
# 0              41.873958              -87.627739          19
# 1              41.873958              -87.627739          19
# 2              41.873958              -87.627739          19
# 3              41.873958              -87.627739          19
# 4              41.873958              -87.627739          19

# %%
# counting unique longitude values to make sure it merged correctly
# this works too: len(pd.unique(new['from_station_longitude']))
print(df.from_station_longitude.nunique())
# Out:
# 299

# %%
# count nulls in each column
trips.isnull().sum(axis=0)
# Out:
# trip_id                   0
# starttime                 0
# stoptime                  0
# bikeid                    0
# tripduration              0
# from_station_id           0
# from_station_name         0
# to_station_id             0
# to_station_name           0
# usertype                  0
# gender               407669
# birthyear            407685
# dtype: int64

# %%
to_stations = stations.drop(['dpcapacity'],axis=1)
to_stations = to_stations.rename(columns = {'id': 'to_station_id', 'latitude' : 'to_station_latitude', 'longitude' : 'to_station_longitude'})
to_stations = to_stations.drop_duplicates()
df = pd.merge(df, to_stations, how='left', on=['to_station_id'], left_on=None, right_on=None,
      left_index=False, right_index=False, sort=True,
      suffixes=('_x', '_y'), copy=True)

# %%
df
# Out:
#          trip_id        starttime         stoptime  bikeid  tripduration  \
# 0        2857636  7/30/2014 14:25  7/30/2014 14:27     838           137
# 1        2857578  7/30/2014 14:21  7/30/2014 14:28    2835           370
# 2        2856592  7/30/2014 13:07  7/30/2014 13:16    2130           545
# 3        2838968  7/29/2014 11:55  7/29/2014 13:06    1117          4257
# 4        2838543  7/29/2014 11:24  7/29/2014 11:53    1971          1748
# ...          ...              ...              ...     ...           ...
# 1110965  2900341   8/1/2014 19:00   8/1/2014 19:16    2865           987
# 1110966  2899805   8/1/2014 18:31   8/1/2014 18:59    2865          1654
# 1110967  2899064   8/1/2014 17:57   8/1/2014 18:30    2865          1986
# 1110968  2897582   8/1/2014 17:03   8/1/2014 17:32    2865          1726
# 1110969  2896950   8/1/2014 16:40   8/1/2014 17:02    2865          1352
#
#          from_station_id            from_station_name  to_station_id  \
# 0                      5       State St & Harrison St              5
# 1                      5       State St & Harrison St              5
# 2                      5       State St & Harrison St              5
# 3                      5       State St & Harrison St              5
# 4                      5       State St & Harrison St              5
# ...                  ...                          ...            ...
# 1110965              351  Cottage Grove Ave & 51st St            351
# 1110966              351  Cottage Grove Ave & 51st St            351
# 1110967              351  Cottage Grove Ave & 51st St            351
# 1110968              351  Cottage Grove Ave & 51st St            351
# 1110969              351  Cottage Grove Ave & 51st St            351
#
#                      to_station_name    usertype gender  birthyear  \
# 0             State St & Harrison St    Customer    NaN        NaN
# 1             State St & Harrison St    Customer    NaN        NaN
# 2             State St & Harrison St  Subscriber   Male     1975.0
# 3             State St & Harrison St    Customer    NaN        NaN
# 4             State St & Harrison St    Customer    NaN        NaN
# ...                              ...         ...    ...        ...
# 1110965  Cottage Grove Ave & 51st St    Customer    NaN        NaN
# 1110966  Cottage Grove Ave & 51st St    Customer    NaN        NaN
# 1110967  Cottage Grove Ave & 51st St    Customer    NaN        NaN
# 1110968  Cottage Grove Ave & 51st St    Customer    NaN        NaN
# 1110969  Cottage Grove Ave & 51st St    Customer    NaN        NaN
#
#          from_station_latitude  from_station_longitude  dpcapacity  \
# 0                    41.873958              -87.627739          19
# 1                    41.873958              -87.627739          19
# 2                    41.873958              -87.627739          19
# 3                    41.873958              -87.627739          19
# 4                    41.873958              -87.627739          19
# ...                        ...                     ...         ...
# 1110965              41.803038              -87.606615          15
# 1110966              41.803038              -87.606615          15
# 1110967              41.803038              -87.606615          15
# 1110968              41.803038              -87.606615          15
# 1110969              41.803038              -87.606615          15
#
#          to_station_latitude  to_station_longitude
# 0                  41.873958            -87.627739
# 1                  41.873958            -87.627739
# 2                  41.873958            -87.627739
# 3                  41.873958            -87.627739
# 4                  41.873958            -87.627739
# ...                      ...                   ...
# 1110965            41.803038            -87.606615
# 1110966            41.803038            -87.606615
# 1110967            41.803038            -87.606615
# 1110968            41.803038            -87.606615
# 1110969            41.803038            -87.606615
#
# [1110970 rows x 17 columns]

# %%
pd.unique(df['usertype'])
# Out:
# array(['Customer', 'Subscriber'], dtype=object)

# %%
# changing boolean strings so that they are in line with our actual variable names

df.loc[df.usertype=='Customer', 'usertype'] = 'casual'
df.loc[df.usertype=='Subscriber', 'usertype'] = 'member'
pd.unique(df['usertype'])
# Out:
# array(['casual', 'member'], dtype=object)

# %%
df
# Out:
#          trip_id        starttime         stoptime  bikeid  tripduration  \
# 0        2857636  7/30/2014 14:25  7/30/2014 14:27     838           137
# 1        2857578  7/30/2014 14:21  7/30/2014 14:28    2835           370
# 2        2856592  7/30/2014 13:07  7/30/2014 13:16    2130           545
# 3        2838968  7/29/2014 11:55  7/29/2014 13:06    1117          4257
# 4        2838543  7/29/2014 11:24  7/29/2014 11:53    1971          1748
# ...          ...              ...              ...     ...           ...
# 1110965  2900341   8/1/2014 19:00   8/1/2014 19:16    2865           987
# 1110966  2899805   8/1/2014 18:31   8/1/2014 18:59    2865          1654
# 1110967  2899064   8/1/2014 17:57   8/1/2014 18:30    2865          1986
# 1110968  2897582   8/1/2014 17:03   8/1/2014 17:32    2865          1726
# 1110969  2896950   8/1/2014 16:40   8/1/2014 17:02    2865          1352
#
#          from_station_id            from_station_name  to_station_id  \
# 0                      5       State St & Harrison St              5
# 1                      5       State St & Harrison St              5
# 2                      5       State St & Harrison St              5
# 3                      5       State St & Harrison St              5
# 4                      5       State St & Harrison St              5
# ...                  ...                          ...            ...
# 1110965              351  Cottage Grove Ave & 51st St            351
# 1110966              351  Cottage Grove Ave & 51st St            351
# 1110967              351  Cottage Grove Ave & 51st St            351
# 1110968              351  Cottage Grove Ave & 51st St            351
# 1110969              351  Cottage Grove Ave & 51st St            351
#
#                      to_station_name usertype gender  birthyear  \
# 0             State St & Harrison St   casual    NaN        NaN
# 1             State St & Harrison St   casual    NaN        NaN
# 2             State St & Harrison St   member   Male     1975.0
# 3             State St & Harrison St   casual    NaN        NaN
# 4             State St & Harrison St   casual    NaN        NaN
# ...                              ...      ...    ...        ...
# 1110965  Cottage Grove Ave & 51st St   casual    NaN        NaN
# 1110966  Cottage Grove Ave & 51st St   casual    NaN        NaN
# 1110967  Cottage Grove Ave & 51st St   casual    NaN        NaN
# 1110968  Cottage Grove Ave & 51st St   casual    NaN        NaN
# 1110969  Cottage Grove Ave & 51st St   casual    NaN        NaN
#
#          from_station_latitude  from_station_longitude  dpcapacity  \
# 0                    41.873958              -87.627739          19
# 1                    41.873958              -87.627739          19
# 2                    41.873958              -87.627739          19
# 3                    41.873958              -87.627739          19
# 4                    41.873958              -87.627739          19
# ...                        ...                     ...         ...
# 1110965              41.803038              -87.606615          15
# 1110966              41.803038              -87.606615          15
# 1110967              41.803038              -87.606615          15
# 1110968              41.803038              -87.606615          15
# 1110969              41.803038              -87.606615          15
#
#          to_station_latitude  to_station_longitude
# 0                  41.873958            -87.627739
# 1                  41.873958            -87.627739
# 2                  41.873958            -87.627739
# 3                  41.873958            -87.627739
# 4                  41.873958            -87.627739
# ...                      ...                   ...
# 1110965            41.803038            -87.606615
# 1110966            41.803038            -87.606615
# 1110967            41.803038            -87.606615
# 1110968            41.803038            -87.606615
# 1110969            41.803038            -87.606615
#
# [1110970 rows x 17 columns]

# %%
df.to_csv('Divvy 2014 Q3Q4 merged.csv')
