# %%
import pandas as pd

stations = pd.read_csv('master_station_list.csv')
stations = stations.drop(['Unnamed: 0'], axis=1)

# %%
stations
# Out:
#       id                            name   latitude  longitude  dpcapacity  \
# 0      5          State St & Harrison St  41.873958 -87.627739          19
# 1     13      Wilton Ave & Diversey Pkwy  41.932500 -87.652681          19
# 2     14             Morgan St & 18th St  41.858086 -87.651073          15
# 3     15            Racine Ave & 18th St  41.858181 -87.656487          15
# 4     16             Wood St & North Ave  41.910329 -87.672516          15
# ..   ...                             ...        ...        ...         ...
# 581  622      California Ave & Cortez St  41.900363 -87.696704           0
# 582  623           Michigan Ave & 8th St  41.872773 -87.623981          23
# 583  624  Dearborn St & Van Buren St (*)  41.876268 -87.629155          16
# 584  625       Chicago Ave & Dempster St  42.041691 -87.680687          15
# 585  626        Delano Ct & Roosevelt Rd  41.867491 -87.632190          19
#
#      landmark      city
# 0        30.0   Chicago
# ...

# %%
# city for both is chicago, landmark for both is 0

# Humboldt Dr & Luis Munoz Marin Dr -  372: id 

# California Ave & Augusta Blvd -  357 : id

# %%
# only values are Clark Clark St & 9th St (AMLI) so we can just set all
# from_lat and from_long to the above numbers

# merged2013_2017.from_lat = merged2013_2017.from_lat.fillna(41.87048)
# merged2013_2017.from_long = merged2013_2017.from_long.fillna(-87.63100)

# %%
stations.loc[stations['id'] == 372]
# Out:
#       id                           name   latitude  longitude  dpcapacity  \
# 342  372  California Ave & Augusta Blvd  41.899358 -87.696439          19
#
#      landmark     city
# 342     660.0  Chicago

# %%
372 in stations['id'].values
# Out:
# True

# %%
# this means we have to add into our from_city section entires for california Ave & August Blvd and Humbol Dr & 
# Luis Munoz Marin Dr

# first however I will check if they are even present in the dataset from 2018-2019

# %%
headers = pd.read_csv('merged2013_2017.csv')

# %%
headers = headers.drop('Unnamed: 0', axis=1)
headers
# Out:
#            trip_id start_time end_time  bikeid  tripduration  from_station_id  \
# 0             9651      00:00    00:09     478           487               34
# 1            19385      00:00    00:06     893           359               20
# 2            29952      00:00    00:27     311          1623               59
# 3            37222      00:00    00:44     420          2639               76
# 4            59638      00:00    00:25     187          1479               27
# ...            ...        ...      ...     ...           ...              ...
# 13382744  17528056       9:59    10:04    1171           326              346
# 13382745  17531658       9:59    10:07    4710           446               39
# 13382746  17531657       9:59    10:10    5932           672              110
# 13382747  17535685       9:59    10:06    6449           413               84
# 13382748  17535686       9:59    10:13    2898           818              249
#
# ...

# %%
# We want the same headers to be in our next set of dataframes for 2018 and 2019, because at the end we will merge them together
required_headers = headers.columns

# %%
df1 = pd.read_csv('Divvy 2018 merged nostation.csv').drop('Unnamed: 0', axis=1)

# %%
df1
# Out:
#           trip_id           start_time             end_time  bikeid  \
# 0        17536702  2018-01-01 00:12:00  2018-01-01 00:17:23    3304
# 1        17536703  2018-01-01 00:41:35  2018-01-01 00:47:52    5367
# 2        17536704  2018-01-01 00:44:46  2018-01-01 01:33:10    4599
# 3        17536705  2018-01-01 00:53:10  2018-01-01 01:05:37    2302
# 4        17536706  2018-01-01 00:53:37  2018-01-01 00:56:40    3696
# ...           ...                  ...                  ...     ...
# 3603077  21742438  2018-12-31 23:45:17  2018-12-31 23:50:05    2931
# 3603078  21742439  2018-12-31 23:48:48  2018-12-31 23:57:22    4386
# 3603079  21742440  2018-12-31 23:50:09  2018-12-31 23:57:16    4927
# 3603080  21742441  2018-12-31 23:55:04  2018-12-31 23:58:24    1350
# 3603081  21742442  2018-12-31 23:59:18  2019-01-01 00:20:43    2006
#
#         tripduration  from_station_id               from_station_name  \
# 0              323.0               69          Damen Ave & Pierce Ave
# ...

# %%
df2 = pd.read_csv('Divvy 2019 merged nostation.csv').drop('Unnamed: 0',axis=1)

# %%
df2
# Out:
#           trip_id           start_time             end_time  bikeid  \
# 0        21742443  2019-01-01 00:04:37  2019-01-01 00:11:07    2167
# 1        21742444  2019-01-01 00:08:13  2019-01-01 00:15:34    4386
# 2        21742445  2019-01-01 00:13:23  2019-01-01 00:27:12    1524
# 3        21742446  2019-01-01 00:13:45  2019-01-01 00:43:28     252
# 4        21742447  2019-01-01 00:14:52  2019-01-01 00:20:56    1170
# ...           ...                  ...                  ...     ...
# 3817999  25962900  2019-12-31 23:56:13  2020-01-01 00:15:45    2196
# 3818000  25962901  2019-12-31 23:56:34  2020-01-01 00:22:08    4877
# 3818001  25962902  2019-12-31 23:57:05  2020-01-01 00:05:46     863
# 3818002  25962903  2019-12-31 23:57:11  2020-01-01 00:05:45    2637
# 3818003  25962904  2019-12-31 23:57:17  2019-12-31 23:59:18    5930
#
#         tripduration  from_station_id                    from_station_name  \
# ...

# %%
merged2018_2019 = pd.concat([df1, df2], ignore_index=True)

# %%
merged2018_2019
# Out:
#           trip_id           start_time             end_time  bikeid  \
# 0        17536702  2018-01-01 00:12:00  2018-01-01 00:17:23    3304
# 1        17536703  2018-01-01 00:41:35  2018-01-01 00:47:52    5367
# 2        17536704  2018-01-01 00:44:46  2018-01-01 01:33:10    4599
# 3        17536705  2018-01-01 00:53:10  2018-01-01 01:05:37    2302
# 4        17536706  2018-01-01 00:53:37  2018-01-01 00:56:40    3696
# ...           ...                  ...                  ...     ...
# 7421081  25962900  2019-12-31 23:56:13  2020-01-01 00:15:45    2196
# 7421082  25962901  2019-12-31 23:56:34  2020-01-01 00:22:08    4877
# 7421083  25962902  2019-12-31 23:57:05  2020-01-01 00:05:46     863
# 7421084  25962903  2019-12-31 23:57:11  2020-01-01 00:05:45    2637
# 7421085  25962904  2019-12-31 23:57:17  2019-12-31 23:59:18    5930
#
#         tripduration  from_station_id            from_station_name  \
# 0              323.0               69       Damen Ave & Pierce Ave
# ...

# %%
# Tasks

# Check for nulls

# split start_time and end_time
# splitting start_time and end_time into two columns
# merged2018_2019[['start_date','start_time']] = merged2018_2019.start_time.str.split(" ",expand=True)
# merged2018_2019[['end_date','end_time']] = merged2018_2019.end_time.str.split(" ",expand=True)

# change usertype: Customer -> casual, Subscriber -> member
# merged2018_2019.loc[merged2018_2019['usertype'] == 'Customer', 'usertype'] = 'casual'
# merged2018_2019.loc[merged2018_2019['usertype'] == 'Subscriber', 'usertype'] = 'member'

# %%
merged2018_2019.duplicated()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 7421081    False
# 7421082    False
# 7421083    False
# 7421084    False
# 7421085    False
# Length: 7421086, dtype: bool

# %%
# checking for our previous problems station #1
print('California Ave & Augusta Blvd' in merged2018_2019['from_station_name'])
print('California Ave & Augusta Blvd' in merged2018_2019['to_station_name'])

# checking for our previous problems station #2
print('Humboldt Dr & Luis Munoz Marin Dr' in merged2018_2019['from_station_name'])
print('Humboldt Dr & Luis Munoz Marin Dr' in merged2018_2019['to_station_name'])
# Out:
# False
# False
# False
# False

# %%
merged2018_2019.shape
# Out:
# (7421086, 12)

# %%
# remove duplicates
merged2018_2019.drop_duplicates()
# Out:
#           trip_id           start_time             end_time  bikeid  \
# 0        17536702  2018-01-01 00:12:00  2018-01-01 00:17:23    3304
# 1        17536703  2018-01-01 00:41:35  2018-01-01 00:47:52    5367
# 2        17536704  2018-01-01 00:44:46  2018-01-01 01:33:10    4599
# 3        17536705  2018-01-01 00:53:10  2018-01-01 01:05:37    2302
# 4        17536706  2018-01-01 00:53:37  2018-01-01 00:56:40    3696
# ...           ...                  ...                  ...     ...
# 7421081  25962900  2019-12-31 23:56:13  2020-01-01 00:15:45    2196
# 7421082  25962901  2019-12-31 23:56:34  2020-01-01 00:22:08    4877
# 7421083  25962902  2019-12-31 23:57:05  2020-01-01 00:05:46     863
# 7421084  25962903  2019-12-31 23:57:11  2020-01-01 00:05:45    2637
# 7421085  25962904  2019-12-31 23:57:17  2019-12-31 23:59:18    5930
#
#         tripduration  from_station_id            from_station_name  \
# 0              323.0               69       Damen Ave & Pierce Ave
# ...

# %%
merged2018_2019.shape
# Out:
# (7421086, 12)

# %%
# remove duplicate trip_id
merged2018_2019.drop_duplicates(subset=['trip_id'])
# Out:
#           trip_id           start_time             end_time  bikeid  \
# 0        17536702  2018-01-01 00:12:00  2018-01-01 00:17:23    3304
# 1        17536703  2018-01-01 00:41:35  2018-01-01 00:47:52    5367
# 2        17536704  2018-01-01 00:44:46  2018-01-01 01:33:10    4599
# 3        17536705  2018-01-01 00:53:10  2018-01-01 01:05:37    2302
# 4        17536706  2018-01-01 00:53:37  2018-01-01 00:56:40    3696
# ...           ...                  ...                  ...     ...
# 7421081  25962900  2019-12-31 23:56:13  2020-01-01 00:15:45    2196
# 7421082  25962901  2019-12-31 23:56:34  2020-01-01 00:22:08    4877
# 7421083  25962902  2019-12-31 23:57:05  2020-01-01 00:05:46     863
# 7421084  25962903  2019-12-31 23:57:11  2020-01-01 00:05:45    2637
# 7421085  25962904  2019-12-31 23:57:17  2019-12-31 23:59:18    5930
#
#         tripduration  from_station_id            from_station_name  \
# 0              323.0               69       Damen Ave & Pierce Ave
# ...

# %%
# now we know all of our entries are unique, we can start performing data operations.

# %%
merged2018_2019.isnull().sum()
# Out:
# trip_id                    0
# start_time                 0
# end_time                   0
# bikeid                     0
# tripduration               0
# from_station_id            0
# from_station_name          0
# to_station_id              0
# to_station_name            0
# usertype                   0
# gender               1121711
# birthyear            1093960
# dtype: int64

# %%
# our values for gender and birthyear have many nulls, which is actually not a problem. we just need to make sure that
# all our nulls are casual riders and that there are no nulls in our member rider category.

# checking our entries for usertype


# change usertype: Customer -> casual, Subscriber -> member

merged2018_2019['usertype'].unique()
# Out:
# array(['Subscriber', 'Customer'], dtype=object)

# %%
# change usertype: Customer -> casual, Subscriber -> member

merged2018_2019.loc[merged2018_2019['usertype'] == 'Customer', 'usertype'] = 'casual'
merged2018_2019.loc[merged2018_2019['usertype'] == 'Subscriber', 'usertype'] = 'member'

# %%
merged2018_2019['usertype'].unique()
# Out:
# array(['member', 'casual'], dtype=object)

# %%
# now I need to make sure that the amount of null entries in gender == the amount in birthyear is true
# I will cast all the null values to 0.0 to make this easier for me
# Also, I will check to see if there are any 0.0 values for the birthdate so that I can remove them, as any that exist
# before I cast all the nulls == 0 are invalid birthyears

# %%
0.0 in merged2018_2019['birthyear'].values
# Out:
# False

# %%
#now we can move on to editing gender and birthyear rows

# %%
merged2018_2019['gender'].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
merged2018_2019 = merged2018_2019.fillna(0)

# %%
merged2018_2019['gender'].unique()
# Out:
# array(['Male', 'Female', 0], dtype=object)

# %%
merged2018_2019['birthyear'].unique()
# Out:
# array([1988., 1984., 1989., 1983., 1994., 1998., 1990.,    0., 1992.,
#        1985., 1993., 1979., 1981., 1986., 1991., 1978., 1982., 1987.,
#        1962., 1960., 1980., 1959., 1972., 1966., 1975., 1974., 1976.,
#        2000., 1969., 1971., 1965., 1996., 1961., 1995., 1973., 1951.,
#        1940., 1970., 1967., 1953., 1950., 1963., 1997., 1977., 1955.,
#        1946., 1964., 1968., 1957., 1954., 1958., 1956., 1952., 1944.,
#        1999., 1918., 1948., 1949., 1921., 1939., 1906., 1942., 1923.,
#        1943., 1945., 2003., 1934., 1947., 1899., 2001., 1900., 1930.,
#        1916., 1931., 1941., 1933., 1938., 1901., 1909., 2002., 1922.,
#        1929., 1895., 1937., 2005., 1935., 2014., 1912., 1936., 1759.,
#        1790., 1911., 1905., 1904., 1910., 1928., 1888., 1889., 1920.,
#        1925., 1890.])

# %%
merged2018_2019.dtypes
# Out:
# trip_id                int64
# start_time            object
# end_time              object
# bikeid                 int64
# tripduration          object
# from_station_id        int64
# from_station_name     object
# to_station_id          int64
# to_station_name       object
# usertype              object
# gender                object
# birthyear            float64
# dtype: object

# %%
# Will check for rows that have one or the other as 0 (between gender and birthyear) because casual should have 0,0 and member should have non-0 values
# all values that don't pass thhis test will be deleted

# Will edit seperate object first to make sure this works properly

check = merged2018_2019
index = merged2018_2019[(merged2018_2019['gender'] == 0.0) & (merged2018_2019['birthyear'] != 0.0)].index
check.drop(index, inplace=True)

# %%
check
# Out:
#           trip_id           start_time             end_time  bikeid  \
# 0        17536702  2018-01-01 00:12:00  2018-01-01 00:17:23    3304
# 1        17536703  2018-01-01 00:41:35  2018-01-01 00:47:52    5367
# 2        17536704  2018-01-01 00:44:46  2018-01-01 01:33:10    4599
# 3        17536705  2018-01-01 00:53:10  2018-01-01 01:05:37    2302
# 4        17536706  2018-01-01 00:53:37  2018-01-01 00:56:40    3696
# ...           ...                  ...                  ...     ...
# 7421081  25962900  2019-12-31 23:56:13  2020-01-01 00:15:45    2196
# 7421082  25962901  2019-12-31 23:56:34  2020-01-01 00:22:08    4877
# 7421083  25962902  2019-12-31 23:57:05  2020-01-01 00:05:46     863
# 7421084  25962903  2019-12-31 23:57:11  2020-01-01 00:05:45    2637
# 7421085  25962904  2019-12-31 23:57:17  2019-12-31 23:59:18    5930
#
#         tripduration  from_station_id            from_station_name  \
# 0              323.0               69       Damen Ave & Pierce Ave
# ...

# %%
check[check['gender'] == 0].shape
# Out:
# (1093898, 12)

# %%
check[check['birthyear'] == 0].shape
# Out:
# (1093960, 12)

# %%
index2 = check[(merged2018_2019['gender'] != 0.0) & (check['birthyear'] == 0.0)].index
check.drop(index2, inplace=True)

# %%
check[check['gender'] == 0].shape
# Out:
# (1093898, 12)

# %%
check[check['birthyear'] == 0].shape
# Out:
# (1093898, 12)

# %%
check.isnull().sum()
# Out:
# trip_id              0
# start_time           0
# end_time             0
# bikeid               0
# tripduration         0
# from_station_id      0
# from_station_name    0
# to_station_id        0
# to_station_name      0
# usertype             0
# gender               0
# birthyear            0
# dtype: int64

# %%
merged2018_2019 = check

# %%
# Now that we know we have no rows left that provide incomplete information about our respective categories, we can move on
# to editting/adding rows and such

# splitting start_time and end_time into two columns
merged2018_2019[['start_date', 'start_time']] = merged2018_2019.start_time.str.split(" ", expand=True)
merged2018_2019[['end_date', 'end_time']] = merged2018_2019.end_time.str.split(" ", expand=True)

# %%
merged2018_2019
# Out:
#           trip_id start_time  end_time  bikeid tripduration  from_station_id  \
# 0        17536702   00:12:00  00:17:23    3304        323.0               69
# 1        17536703   00:41:35  00:47:52    5367        377.0              253
# 2        17536704   00:44:46  01:33:10    4599      2,904.0               98
# 3        17536705   00:53:10  01:05:37    2302        747.0              125
# 4        17536706   00:53:37  00:56:40    3696        183.0              129
# ...           ...        ...       ...     ...          ...              ...
# 7421081  25962900   23:56:13  00:15:45    2196      1,172.0              112
# 7421082  25962901   23:56:34  00:22:08    4877      1,533.0               90
# 7421083  25962902   23:57:05  00:05:46     863        520.0              623
# 7421084  25962903   23:57:11  00:05:45    2637        514.0              623
# 7421085  25962904   23:57:17  23:59:18    5930        120.0              256
#
# ...

# %%
# validate date formats
# now fix start_date and end_date so they are in a single format (and check to see if any values are invalid)
merged2018_2019['start_date'] = pd.to_datetime(merged2018_2019['start_date'])
merged2018_2019['end_date'] = pd.to_datetime(merged2018_2019['end_date'])

# %%
required_headers
# Out:
# Index(['trip_id', 'start_time', 'end_time', 'bikeid', 'tripduration',
#        'from_station_id', 'from_station_name', 'to_station_id',
#        'to_station_name', 'usertype', 'gender', 'birthyear', 'from_lat',
#        'from_long', 'to_lat', 'to_long', 'rideable_type', 'from_city',
#        'from_landmark', 'to_city', 'to_landmark', 'start_date', 'end_date',
#        'from_dpcapacity', 'to_dpcapacity'],
#       dtype='object')

# %%
merged2018_2019.columns
# Out:
# Index(['trip_id', 'start_time', 'end_time', 'bikeid', 'tripduration',
#        'from_station_id', 'from_station_name', 'to_station_id',
#        'to_station_name', 'usertype', 'gender', 'birthyear', 'start_date',
#        'end_date'],
#       dtype='object')

# %%
# 'from_lat', 'from_long', 'to_lat', 'to_long', 'rideable_type', 'from_city','from_landmark', 
# 'to_city', 'to_landmark'
# are all of our missing columns. To get these, we will merge with our from_city dataframe

# %%
merged2018_2019
# Out:
#           trip_id start_time  end_time  bikeid tripduration  from_station_id  \
# 0        17536702   00:12:00  00:17:23    3304        323.0               69
# 1        17536703   00:41:35  00:47:52    5367        377.0              253
# 2        17536704   00:44:46  01:33:10    4599      2,904.0               98
# 3        17536705   00:53:10  01:05:37    2302        747.0              125
# 4        17536706   00:53:37  00:56:40    3696        183.0              129
# ...           ...        ...       ...     ...          ...              ...
# 7421081  25962900   23:56:13  00:15:45    2196      1,172.0              112
# 7421082  25962901   23:56:34  00:22:08    4877      1,533.0               90
# 7421083  25962902   23:57:05  00:05:46     863        520.0              623
# 7421084  25962903   23:57:11  00:05:45    2637        514.0              623
# 7421085  25962904   23:57:17  23:59:18    5930        120.0              256
#
# ...

# %%
stations
# Out:
#       id                            name   latitude  longitude  dpcapacity  \
# 0      5          State St & Harrison St  41.873958 -87.627739          19
# 1     13      Wilton Ave & Diversey Pkwy  41.932500 -87.652681          19
# 2     14             Morgan St & 18th St  41.858086 -87.651073          15
# 3     15            Racine Ave & 18th St  41.858181 -87.656487          15
# 4     16             Wood St & North Ave  41.910329 -87.672516          15
# ..   ...                             ...        ...        ...         ...
# 581  622      California Ave & Cortez St  41.900363 -87.696704           0
# 582  623           Michigan Ave & 8th St  41.872773 -87.623981          23
# 583  624  Dearborn St & Van Buren St (*)  41.876268 -87.629155          16
# 584  625       Chicago Ave & Dempster St  42.041691 -87.680687          15
# 585  626        Delano Ct & Roosevelt Rd  41.867491 -87.632190          19
#
#      landmark      city
# 0        30.0   Chicago
# ...

# %%
# 'from_lat', 'from_long', 'from_city','from_landmark',
from_city = stations.rename(columns={'id' : 'from_station_id', 'name' : 'from_name','city' : 'from_city', 'latitude' : 'from_lat', 'longitude' : 'from_long', 'landmark' : 'from_landmark',})

#'to_lat', 'to_long', 'to_city', 'to_landmark'
to_city = stations.rename(columns={'id' : 'to_station_id', 'name' : 'to_name','city' : 'to_city', 'latitude' : 'to_lat', 'longitude' : 'to_long', 'landmark' : 'to_landmark',})

#'rideable_type' will be added at the end

# %%
display(from_city.columns)
display(to_city.columns)
# Out:
# Index(['from_station_id', 'from_name', 'from_lat', 'from_long', 'dpcapacity',
#        'from_landmark', 'from_city'],
#       dtype='object')
# Index(['to_station_id', 'to_name', 'to_lat', 'to_long', 'dpcapacity',
#        'to_landmark', 'to_city'],
#       dtype='object')

# %%
merged2018_2019
# Out:
#           trip_id start_time  end_time  bikeid tripduration  from_station_id  \
# 0        17536702   00:12:00  00:17:23    3304        323.0               69
# 1        17536703   00:41:35  00:47:52    5367        377.0              253
# 2        17536704   00:44:46  01:33:10    4599      2,904.0               98
# 3        17536705   00:53:10  01:05:37    2302        747.0              125
# 4        17536706   00:53:37  00:56:40    3696        183.0              129
# ...           ...        ...       ...     ...          ...              ...
# 7421081  25962900   23:56:13  00:15:45    2196      1,172.0              112
# 7421082  25962901   23:56:34  00:22:08    4877      1,533.0               90
# 7421083  25962902   23:57:05  00:05:46     863        520.0              623
# 7421084  25962903   23:57:11  00:05:45    2637        514.0              623
# 7421085  25962904   23:57:17  23:59:18    5930        120.0              256
#
# ...

# %%
k = pd.merge(merged2018_2019, from_city, on='from_station_id', how='left')

# %%
k
# Out:
#           trip_id start_time  end_time  bikeid tripduration  from_station_id  \
# 0        17536702   00:12:00  00:17:23    3304        323.0               69
# 1        17536703   00:41:35  00:47:52    5367        377.0              253
# 2        17536704   00:44:46  01:33:10    4599      2,904.0               98
# 3        17536705   00:53:10  01:05:37    2302        747.0              125
# 4        17536706   00:53:37  00:56:40    3696        183.0              129
# ...           ...        ...       ...     ...          ...              ...
# 7393206  25962900   23:56:13  00:15:45    2196      1,172.0              112
# 7393207  25962901   23:56:34  00:22:08    4877      1,533.0               90
# 7393208  25962902   23:57:05  00:05:46     863        520.0              623
# 7393209  25962903   23:57:11  00:05:45    2637        514.0              623
# 7393210  25962904   23:57:17  23:59:18    5930        120.0              256
#
# ...

# %%
k.isnull().sum()
# Out:
# trip_id                   0
# start_time                0
# end_time                  0
# bikeid                    0
# tripduration              0
# from_station_id           0
# from_station_name         0
# to_station_id             0
# to_station_name           0
# usertype                  0
# gender                    0
# birthyear                 0
# start_date                0
# end_date                  0
# from_name            147542
# from_lat             147542
# from_long            147542
# dpcapacity           147542
# from_landmark        147542
# from_city            147542
# dtype: int64

# %%
d = pd.merge(k, to_city, on='to_station_id', how='left')

# %%
d
# Out:
#           trip_id start_time  end_time  bikeid tripduration  from_station_id  \
# 0        17536702   00:12:00  00:17:23    3304        323.0               69
# 1        17536703   00:41:35  00:47:52    5367        377.0              253
# 2        17536704   00:44:46  01:33:10    4599      2,904.0               98
# 3        17536705   00:53:10  01:05:37    2302        747.0              125
# 4        17536706   00:53:37  00:56:40    3696        183.0              129
# ...           ...        ...       ...     ...          ...              ...
# 7393206  25962900   23:56:13  00:15:45    2196      1,172.0              112
# 7393207  25962901   23:56:34  00:22:08    4877      1,533.0               90
# 7393208  25962902   23:57:05  00:05:46     863        520.0              623
# 7393209  25962903   23:57:11  00:05:45    2637        514.0              623
# 7393210  25962904   23:57:17  23:59:18    5930        120.0              256
#
# ...

# %%
d['rideable_type'] = 'classic_bike'

# %%
d.columns
# Out:
# Index(['trip_id', 'start_time', 'end_time', 'bikeid', 'tripduration',
#        'from_station_id', 'from_station_name', 'to_station_id',
#        'to_station_name', 'usertype', 'gender', 'birthyear', 'start_date',
#        'end_date', 'from_name', 'from_lat', 'from_long', 'dpcapacity_x',
#        'from_landmark', 'from_city', 'to_name', 'to_lat', 'to_long',
#        'dpcapacity_y', 'to_landmark', 'to_city', 'rideable_type'],
#       dtype='object')

# %%
required_headers
# Out:
# Index(['trip_id', 'start_time', 'end_time', 'bikeid', 'tripduration',
#        'from_station_id', 'from_station_name', 'to_station_id',
#        'to_station_name', 'usertype', 'gender', 'birthyear', 'from_lat',
#        'from_long', 'to_lat', 'to_long', 'rideable_type', 'from_city',
#        'from_landmark', 'to_city', 'to_landmark', 'start_date', 'end_date',
#        'from_dpcapacity', 'to_dpcapacity'],
#       dtype='object')

# %%
print(len(d.columns))
print(len(required_headers))
# Out:
# 27
# 25

# %%
for i in range(len(d.columns)):
    if d.columns[i] not in required_headers:
        print(d.columns[i])
# Out:
# from_name
# dpcapacity_x
# to_name
# dpcapacity_y

# %%
# we can drop from_name and to_name
d = d.drop(['from_name', 'to_name'],axis=1)

# %%
for i in range(len(d.columns)):
    if d.columns[i] not in required_headers:
        print(d.columns[i])
# Out:
# dpcapacity_x
# dpcapacity_y

# %%
d
# Out:
#           trip_id start_time  end_time  bikeid tripduration  from_station_id  \
# 0        17536702   00:12:00  00:17:23    3304        323.0               69
# 1        17536703   00:41:35  00:47:52    5367        377.0              253
# 2        17536704   00:44:46  01:33:10    4599      2,904.0               98
# 3        17536705   00:53:10  01:05:37    2302        747.0              125
# 4        17536706   00:53:37  00:56:40    3696        183.0              129
# ...           ...        ...       ...     ...          ...              ...
# 7393206  25962900   23:56:13  00:15:45    2196      1,172.0              112
# 7393207  25962901   23:56:34  00:22:08    4877      1,533.0               90
# 7393208  25962902   23:57:05  00:05:46     863        520.0              623
# 7393209  25962903   23:57:11  00:05:45    2637        514.0              623
# 7393210  25962904   23:57:17  23:59:18    5930        120.0              256
#
# ...

# %%
d.isnull().sum()
# Out:
# trip_id                   0
# start_time                0
# end_time                  0
# bikeid                    0
# tripduration              0
# from_station_id           0
# from_station_name         0
# to_station_id             0
# to_station_name           0
# usertype                  0
# gender                    0
# birthyear                 0
# start_date                0
# end_date                  0
# from_lat             147542
# from_long            147542
# dpcapacity_x         147542
# from_landmark        147542
# from_city            147542
# to_lat               149108
# to_long              149108
# dpcapacity_y         149108
# to_landmark          149108
# to_city              149108
# rideable_type             0
# dtype: int64

# %%
merged2018_2019 = d

# %%
merged2018_2019.isnull().sum()
# Out:
# trip_id                   0
# start_time                0
# end_time                  0
# bikeid                    0
# tripduration              0
# from_station_id           0
# from_station_name         0
# to_station_id             0
# to_station_name           0
# usertype                  0
# gender                    0
# birthyear                 0
# start_date                0
# end_date                  0
# from_lat             147542
# from_long            147542
# dpcapacity_x         147542
# from_landmark        147542
# from_city            147542
# to_lat               149108
# to_long              149108
# dpcapacity_y         149108
# to_landmark          149108
# to_city              149108
# rideable_type             0
# dtype: int64

# %%
merged2018_2019[merged2018_2019['from_lat'].isnull()]
# Out:
#           trip_id start_time  end_time  bikeid tripduration  from_station_id  \
# 33365    17579217   17:15:36  17:20:24    3887        288.0              360
# 76584    17631707   14:35:41  14:44:44    6417        543.0              360
# 112266   17673576   15:33:02  15:37:34     836        272.0              360
# 123058   17687554   09:03:35  09:23:01    2922      1,166.0              360
# 129197   17695601   10:23:30  10:32:03    5653        513.0              360
# ...           ...        ...       ...     ...          ...              ...
# 7393106  25962789   21:27:23  21:29:37     389        133.0              627
# 7393155  25962845   23:05:47  23:16:54    4877        666.0              644
# 7393176  25962867   23:26:58  23:52:59    2609      1,560.0              641
# 7393196  25962890   23:46:19  23:53:51      41        451.0              641
# 7393203  25962897   23:51:19  23:55:33    5654        254.0              638
#
# ...

# %%
merged2018_2019 = merged2018_2019.drop(merged2018_2019[merged2018_2019['from_station_name'] == 'DIVVY Map Frame B/C Station'].index)
merged2018_2019 = merged2018_2019.drop(merged2018_2019[merged2018_2019['to_station_name'] == 'DIVVY Map Frame B/C Station'].index)

# %%
merged2018_2019[merged2018_2019['from_long'].isnull()]
# Out:
#           trip_id start_time  end_time  bikeid tripduration  from_station_id  \
# 207818   17788930   09:38:58  09:44:31    2351        333.0              512
# 207851   17788964   09:45:28  10:18:47    2351      1,999.0              512
# 208648   17789882   12:13:15  12:15:09    2351        114.0              512
# 208812   17790072   12:40:57  12:47:05    1259        368.0              363
# 208845   17790107   12:48:20  13:05:44    1259      1,044.0              512
# ...           ...        ...       ...     ...          ...              ...
# 7393106  25962789   21:27:23  21:29:37     389        133.0              627
# 7393155  25962845   23:05:47  23:16:54    4877        666.0              644
# 7393176  25962867   23:26:58  23:52:59    2609      1,560.0              641
# 7393196  25962890   23:46:19  23:53:51      41        451.0              641
# 7393203  25962897   23:51:19  23:55:33    5654        254.0              638
#
# ...

# %%
merged2018_2019 = merged2018_2019.drop(merged2018_2019[merged2018_2019['from_station_name'] == 'BBB ~ Divvy Parts Testing'].index)
merged2018_2019 = merged2018_2019.drop(merged2018_2019[merged2018_2019['to_station_name'] == 'BBB ~ Divvy Parts Testing'].index)

# %%
merged2018_2019.isnull().sum()
# Out:
# trip_id                   0
# start_time                0
# end_time                  0
# bikeid                    0
# tripduration              0
# from_station_id           0
# from_station_name         0
# to_station_id             0
# to_station_name           0
# usertype                  0
# gender                    0
# birthyear                 0
# start_date                0
# end_date                  0
# from_lat             147436
# from_long            147436
# dpcapacity_x         147436
# from_landmark        147436
# from_city            147436
# to_lat               148743
# to_long              148743
# dpcapacity_y         148743
# to_landmark          148743
# to_city              148743
# rideable_type             0
# dtype: int64

# %%
merged2018_2019[merged2018_2019['from_long'].isnull()]
# Out:
#           trip_id start_time  end_time  bikeid tripduration  from_station_id  \
# 250958   17840267   15:47:51  15:57:38    1938        587.0              627
# 251697   17841115   17:04:55  17:14:10    3024        555.0              627
# 251840   17841265   17:13:33  17:23:31    5218        598.0              627
# 251969   17841402   17:20:59  17:30:47    3171        588.0              627
# 252092   17841544   17:30:25  17:38:25    3888        480.0              627
# ...           ...        ...       ...     ...          ...              ...
# 7393106  25962789   21:27:23  21:29:37     389        133.0              627
# 7393155  25962845   23:05:47  23:16:54    4877        666.0              644
# 7393176  25962867   23:26:58  23:52:59    2609      1,560.0              641
# 7393196  25962890   23:46:19  23:53:51      41        451.0              641
# 7393203  25962897   23:51:19  23:55:33    5654        254.0              638
#
# ...

# %%
merged2018_2019[merged2018_2019['from_station_id'] == 627]
# Out:
#           trip_id start_time  end_time  bikeid tripduration  from_station_id  \
# 250958   17840267   15:47:51  15:57:38    1938        587.0              627
# 251697   17841115   17:04:55  17:14:10    3024        555.0              627
# 251840   17841265   17:13:33  17:23:31    5218        598.0              627
# 251969   17841402   17:20:59  17:30:47    3171        588.0              627
# 252092   17841544   17:30:25  17:38:25    3888        480.0              627
# ...           ...        ...       ...     ...          ...              ...
# 7392468  25962103   15:50:07  15:53:21    2076        193.0              627
# 7393015  25962691   19:34:00  21:07:06    1034      5,586.0              627
# 7393071  25962752   20:31:30  20:58:24     389      1,613.0              627
# 7393098  25962781   21:19:55  21:27:13     389        438.0              627
# 7393106  25962789   21:27:23  21:29:37     389        133.0              627
#
# ...

# %%
set(merged2018_2019[merged2018_2019['from_station_id'] == 627]['from_long'].values)
# Out:
# {nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
# ...

# %%
merged2018_2019.loc[merged2018_2019['from_station_id'] == 627, 'from_lat'] = 41.894859
merged2018_2019.loc[merged2018_2019['from_station_id'] == 627, 'from_long'] = -87.632375
merged2018_2019.loc[merged2018_2019['from_station_id'] == 627, 'dpcapacity_x'] = 19
merged2018_2019.loc[merged2018_2019['from_station_id'] == 627, 'from_city'] = 'Chicago'

merged2018_2019.loc[merged2018_2019['to_station_id'] == 627, 'to_lat'] = 41.894859
merged2018_2019.loc[merged2018_2019['to_station_id'] == 627, 'to_long'] = -87.632375
merged2018_2019.loc[merged2018_2019['to_station_id'] == 627, 'dpcapacity_y'] = 19
merged2018_2019.loc[merged2018_2019['to_station_id'] == 627, 'to_city'] = 'Chicago'

# %%
merged2018_2019[merged2018_2019['from_station_id'] == 627]
# Out:
#           trip_id start_time  end_time  bikeid tripduration  from_station_id  \
# 250958   17840267   15:47:51  15:57:38    1938        587.0              627
# 251697   17841115   17:04:55  17:14:10    3024        555.0              627
# 251840   17841265   17:13:33  17:23:31    5218        598.0              627
# 251969   17841402   17:20:59  17:30:47    3171        588.0              627
# 252092   17841544   17:30:25  17:38:25    3888        480.0              627
# ...           ...        ...       ...     ...          ...              ...
# 7392468  25962103   15:50:07  15:53:21    2076        193.0              627
# 7393015  25962691   19:34:00  21:07:06    1034      5,586.0              627
# 7393071  25962752   20:31:30  20:58:24     389      1,613.0              627
# 7393098  25962781   21:19:55  21:27:13     389        438.0              627
# 7393106  25962789   21:27:23  21:29:37     389        133.0              627
#
# ...

# %%
merged2018_2019[merged2018_2019['from_station_id'] == 627].isnull().sum()
# Out:
# trip_id                  0
# start_time               0
# end_time                 0
# bikeid                   0
# tripduration             0
# from_station_id          0
# from_station_name        0
# to_station_id            0
# to_station_name          0
# usertype                 0
# gender                   0
# birthyear                0
# start_date               0
# end_date                 0
# from_lat                 0
# from_long                0
# dpcapacity_x             0
# from_landmark        18157
# from_city                0
# to_lat                 313
# to_long                313
# dpcapacity_y           313
# to_landmark            791
# to_city                313
# rideable_type            0
# dtype: int64

# %%
merged2018_2019.loc[merged2018_2019['from_station_id'] == 627, 'from_landmark'] = 0.0
merged2018_2019.loc[merged2018_2019['to_station_id'] == 627, 'to_landmark'] = 0.0

# %%
merged2018_2019.isnull().sum()
# Out:
# trip_id                   0
# start_time                0
# end_time                  0
# bikeid                    0
# tripduration              0
# from_station_id           0
# from_station_name         0
# to_station_id             0
# to_station_name           0
# usertype                  0
# gender                    0
# birthyear                 0
# start_date                0
# end_date                  0
# from_lat             129279
# from_long            129279
# dpcapacity_x         129279
# from_landmark        129279
# from_city            129279
# to_lat               131967
# to_long              131967
# dpcapacity_y         131967
# to_landmark          131967
# to_city              131967
# rideable_type             0
# dtype: int64

# %%
merged2018_2019[merged2018_2019['from_lat'].isnull()]
# Out:
#           trip_id start_time  end_time  bikeid tripduration  from_station_id  \
# 579650   18233184   16:01:25  16:09:15    6454        470.0              621
# 581316   18235096   17:04:16  17:24:33    6417      1,217.0              621
# 581417   18235212   17:06:34  17:21:51    2208        917.0              621
# 582736   18236661   17:39:28  18:13:46    3119      2,058.0              621
# 582950   18236889   17:45:45  17:49:30    5926        225.0              621
# ...           ...        ...       ...     ...          ...              ...
# 7393029  25962705   19:44:54  20:10:37    4767      1,542.0              657
# 7393155  25962845   23:05:47  23:16:54    4877        666.0              644
# 7393176  25962867   23:26:58  23:52:59    2609      1,560.0              641
# 7393196  25962890   23:46:19  23:53:51      41        451.0              641
# 7393203  25962897   23:51:19  23:55:33    5654        254.0              638
#
# ...

# %%
# id 621: 15 dpcacpacity, 'Chicago', lat = 41.884100, long = -87.654286

merged2018_2019.loc[merged2018_2019['from_station_id'] == 621, 'from_lat'] = 41.884100
merged2018_2019.loc[merged2018_2019['from_station_id'] == 621, 'from_long'] = -87.654286
merged2018_2019.loc[merged2018_2019['from_station_id'] == 621, 'dpcapacity_x'] = 15
merged2018_2019.loc[merged2018_2019['from_station_id'] == 621, 'from_city'] = 'Chicago'

merged2018_2019.loc[merged2018_2019['to_station_id'] == 621, 'to_lat'] = 41.884100
merged2018_2019.loc[merged2018_2019['to_station_id'] == 621, 'to_long'] = -87.654286
merged2018_2019.loc[merged2018_2019['to_station_id'] == 621, 'dpcapacity_y'] = 15
merged2018_2019.loc[merged2018_2019['to_station_id'] == 621, 'to_city'] = 'Chicago'

merged2018_2019.loc[merged2018_2019['from_station_id'] == 621, 'from_landmark'] = 0.0
merged2018_2019.loc[merged2018_2019['to_station_id'] == 621, 'to_landmark'] = 0.0

# %%
merged2018_2019[merged2018_2019['from_station_id'] == 621]
# Out:
#           trip_id start_time  end_time  bikeid tripduration  from_station_id  \
# 579650   18233184   16:01:25  16:09:15    6454        470.0              621
# 581316   18235096   17:04:16  17:24:33    6417      1,217.0              621
# 581417   18235212   17:06:34  17:21:51    2208        917.0              621
# 582736   18236661   17:39:28  18:13:46    3119      2,058.0              621
# 582950   18236889   17:45:45  17:49:30    5926        225.0              621
# ...           ...        ...       ...     ...          ...              ...
# 7392271  25961898   14:54:50  15:07:07    1048        737.0              621
# 7392462  25962096   15:49:11  15:54:09    3794        297.0              621
# 7392810  25962466   17:29:56  17:34:37    3882        280.0              621
# 7392812  25962468   17:29:56  17:34:40    5010        283.0              621
# 7392813  25962469   17:30:01  17:34:39    1438        278.0              621
#
# ...

# %%
merged2018_2019[merged2018_2019['from_lat'].isnull()]
# Out:
#           trip_id start_time  end_time  bikeid tripduration  from_station_id  \
# 988012   18709613   06:19:57  06:41:50    6222      1,313.0              361
# 989304   18711125   07:45:56  08:13:31    4623      1,655.0              361
# 1235969  19000213   00:21:17  00:27:26    6029        369.0              361
# 1238531  19003174   10:42:20  11:41:34    5743      3,554.0              361
# 1245338  19010926   17:42:41  17:57:41    5463        900.0              361
# ...           ...        ...       ...     ...          ...              ...
# 7393029  25962705   19:44:54  20:10:37    4767      1,542.0              657
# 7393155  25962845   23:05:47  23:16:54    4877        666.0              644
# 7393176  25962867   23:26:58  23:52:59    2609      1,560.0              641
# 7393196  25962890   23:46:19  23:53:51      41        451.0              641
# 7393203  25962897   23:51:19  23:55:33    5654        254.0              638
#
# ...

# %%
merged2018_2019[merged2018_2019['from_station_id'] == 361]
# Out:
#           trip_id start_time  end_time  bikeid tripduration  from_station_id  \
# 988012   18709613   06:19:57  06:41:50    6222      1,313.0              361
# 989304   18711125   07:45:56  08:13:31    4623      1,655.0              361
# 1235969  19000213   00:21:17  00:27:26    6029        369.0              361
# 1238531  19003174   10:42:20  11:41:34    5743      3,554.0              361
# 1245338  19010926   17:42:41  17:57:41    5463        900.0              361
# ...           ...        ...       ...     ...          ...              ...
# 3222980  21296853   12:53:27  12:59:19    2332        352.0              361
# 3567730  21707034   13:33:15  13:35:27     444        132.0              361
# 4170681  22427587   10:42:14  10:44:03    5018        109.0              361
# 4171907  22429216   13:23:58  13:35:41    5162        703.0              361
# 4440171  22748577   13:23:27  13:30:51      89        444.0              361
#
# ...

# %%
# id 621: 15 dpcacpacity, 'Chicago', lat = 41.880958 long = -87.616743

merged2018_2019.loc[merged2018_2019['from_station_id'] == 361, 'from_lat'] = 41.884100
merged2018_2019.loc[merged2018_2019['from_station_id'] == 361, 'from_long'] = -87.654286
merged2018_2019.loc[merged2018_2019['from_station_id'] == 361, 'dpcapacity_x'] = 0
merged2018_2019.loc[merged2018_2019['from_station_id'] == 361, 'from_city'] = 'Chicago'

merged2018_2019.loc[merged2018_2019['to_station_id'] == 361, 'to_lat'] = 41.884100
merged2018_2019.loc[merged2018_2019['to_station_id'] == 361, 'to_long'] = -87.654286
merged2018_2019.loc[merged2018_2019['to_station_id'] == 361, 'dpcapacity_y'] = 0
merged2018_2019.loc[merged2018_2019['to_station_id'] == 361, 'to_city'] = 'Chicago'

merged2018_2019.loc[merged2018_2019['from_station_id'] == 361, 'from_landmark'] = 0.0
merged2018_2019.loc[merged2018_2019['to_station_id'] == 361, 'to_landmark'] = 0.0

# %%
merged2018_2019.isnull().sum()
# Out:
# trip_id                   0
# start_time                0
# end_time                  0
# bikeid                    0
# tripduration              0
# from_station_id           0
# from_station_name         0
# to_station_id             0
# to_station_name           0
# usertype                  0
# gender                    0
# birthyear                 0
# start_date                0
# end_date                  0
# from_lat             112167
# from_long            112167
# dpcapacity_x         112167
# from_landmark        112167
# from_city            112167
# to_lat               114550
# to_long              114550
# dpcapacity_y         114550
# to_landmark          114550
# to_city              114550
# rideable_type             0
# dtype: int64

# %%
merged2018_2019[merged2018_2019['from_lat'].isnull()]
# Out:
#           trip_id start_time  end_time  bikeid tripduration  from_station_id  \
# 2461289  20413626   12:43:58  13:07:11    1733      1,393.0              631
# 2461295  20413634   12:44:20  12:49:13     898        293.0              631
# 2461384  20413729   12:51:55  12:58:05    1740        370.0              631
# 2461731  20414169   13:24:20  13:40:52    1740        992.0              631
# 2461761  20414204   13:26:21  13:39:30    5087        789.0              631
# ...           ...        ...       ...     ...          ...              ...
# 7393029  25962705   19:44:54  20:10:37    4767      1,542.0              657
# 7393155  25962845   23:05:47  23:16:54    4877        666.0              644
# 7393176  25962867   23:26:58  23:52:59    2609      1,560.0              641
# 7393196  25962890   23:46:19  23:53:51      41        451.0              641
# 7393203  25962897   23:51:19  23:55:33    5654        254.0              638
#
# ...

# %%
def fix_nulls(station_id=int,dpcapacity=int,lat_long=[],city=str,landmark=0):
    
    lat = lat_long[0]
    lng = lat_long[1]
    
    from_point = merged2018_2019['from_station_id'] == station_id
    to_point = merged2018_2019['to_station_id'] == station_id
    
    merged2018_2019.loc[from_point, 'from_lat'] = lat
    merged2018_2019.loc[from_point, 'from_long'] = lng
    merged2018_2019.loc[from_point, 'dpcapacity_x'] = dpcapacity
    merged2018_2019.loc[from_point, 'from_city'] = 'Chicago'
    merged2018_2019.loc[from_point, 'from_landmark'] = landmark
    
    merged2018_2019.loc[to_point, 'to_lat'] = lat
    merged2018_2019.loc[to_point, 'to_long'] = lng
    merged2018_2019.loc[to_point, 'dpcapacity_y'] = dpcapacity
    merged2018_2019.loc[to_point, 'to_city'] = 'Chicago'
    merged2018_2019.loc[to_point, 'to_landmark'] = landmark

    
fix_nulls(631, 17, [41.87763299333187, -87.67389247653337], 'Chicago')

# %%
merged2018_2019[merged2018_2019['from_lat'].isnull()]
# Out:
#           trip_id start_time  end_time  bikeid tripduration  from_station_id  \
# 2550082  20516248   15:02:42  15:19:43    2459      1,021.0              630
# 2553025  20519633   06:36:27  07:07:40     236      1,873.0              630
# 2571563  20541321   08:19:21  08:24:46    4507        325.0              630
# 2592257  20565763   21:43:13  22:06:26    1901      1,393.0              630
# 2594501  20568301   07:42:01  07:47:11    2935        310.0              630
# ...           ...        ...       ...     ...          ...              ...
# 7393029  25962705   19:44:54  20:10:37    4767      1,542.0              657
# 7393155  25962845   23:05:47  23:16:54    4877        666.0              644
# 7393176  25962867   23:26:58  23:52:59    2609      1,560.0              641
# 7393196  25962890   23:46:19  23:53:51      41        451.0              641
# 7393203  25962897   23:51:19  23:55:33    5654        254.0              638
#
# ...

# %%
fix_nulls(630, 15, [41.96109534681988, -87.73570245324244], 'Chicago')

# %%
merged2018_2019[merged2018_2019['from_lat'].isnull()]
# Out:
#           trip_id start_time  end_time  bikeid tripduration  from_station_id  \
# 2673245  20659813   15:59:06  16:07:19     292        493.0              659
# 2682729  20670211   06:18:29  06:29:56     156        687.0              657
# 2683696  20671291   07:23:04  07:28:00    1446        296.0              657
# 2683757  20671366   07:26:10  07:30:44    1877        274.0              657
# 2684569  20672250   07:54:09  07:57:16    2806        187.0              657
# ...           ...        ...       ...     ...          ...              ...
# 7393029  25962705   19:44:54  20:10:37    4767      1,542.0              657
# 7393155  25962845   23:05:47  23:16:54    4877        666.0              644
# 7393176  25962867   23:26:58  23:52:59    2609      1,560.0              641
# 7393196  25962890   23:46:19  23:53:51      41        451.0              641
# 7393203  25962897   23:51:19  23:55:33    5654        254.0              638
#
# ...

# %%
merged2018_2019[merged2018_2019['from_station_name']=='Leavitt St & Chicago Ave']
# Out:
#           trip_id start_time  end_time  bikeid tripduration  from_station_id  \
# 2673245  20659813   15:59:06  16:07:19     292        493.0              659
# 2685746  20673622   08:30:16  08:58:05    4460      1,669.0              659
# 2688166  20676643   11:37:19  11:53:38    5344        979.0              659
# 2690388  20679124   14:37:06  14:44:48    4110        462.0              659
# 2692621  20681745   16:39:13  17:02:46    3469      1,413.0              659
# ...           ...        ...       ...     ...          ...              ...
# 7387864  25957289   06:06:39  06:21:59    2007        919.0              659
# 7388292  25957734   08:17:01  08:22:21     719        319.0              659
# 7391119  25960696   06:29:14  06:47:48    3739      1,113.0              659
# 7391177  25960756   07:11:09  07:35:42    3499      1,473.0              659
# 7391354  25960942   08:28:46  08:47:15    2076      1,108.0              659
#
# ...

# %%
fix_nulls(659, 15, [41.895485, -87.682008], 'Chicago')

# %%
merged2018_2019[merged2018_2019['from_lat'].isnull()]
# Out:
#           trip_id start_time  end_time  bikeid tripduration  from_station_id  \
# 2682729  20670211   06:18:29  06:29:56     156        687.0              657
# 2683696  20671291   07:23:04  07:28:00    1446        296.0              657
# 2683757  20671366   07:26:10  07:30:44    1877        274.0              657
# 2684569  20672250   07:54:09  07:57:16    2806        187.0              657
# 2684783  20672490   08:00:36  08:12:00    3819        684.0              657
# ...           ...        ...       ...     ...          ...              ...
# 7393029  25962705   19:44:54  20:10:37    4767      1,542.0              657
# 7393155  25962845   23:05:47  23:16:54    4877        666.0              644
# 7393176  25962867   23:26:58  23:52:59    2609      1,560.0              641
# 7393196  25962890   23:46:19  23:53:51      41        451.0              641
# %%
merged2018_2019[merged2018_2019['from_lat'].isnull()]
# Out:
#           trip_id start_time  end_time  bikeid tripduration  from_station_id  \
# 4440317  22748777   14:01:05  14:10:20    1741        555.0                1
# 4832700  23207817   13:54:49  13:57:19    6206        150.0              669
# 5319142  23775344   14:27:52  14:31:10    2540        198.0              671
# 5452340  23916262   16:52:58  16:57:05    4198        247.0              671
# 5931358  24423222   18:15:00  18:20:27    1404        326.0              671
# 6009558  24506080   16:04:53  16:10:55    4835        361.0              671
# 6057227  24556354   19:03:03  19:05:28    4295        145.0              671
# 6106963  24608963   18:11:38  18:40:23    5677      1,725.0              671
# 6144665  24648419   18:32:53  18:36:21    6258        208.0              671
# 6815619  25351470   10:26:36  10:48:58    3904      1,341.0              671
# 6916337  25456596   14:18:34  14:47:15    1519      1,721.0              671
# ...

# %%
# Now delete all of these

merged2018_2019 = merged2018_2019.drop(merged2018_2019[merged2018_2019['from_station_name'] == 'HUBBARD ST BIKE CHECKING (LBS-WH-TEST)'].index)
merged2018_2019 = merged2018_2019.drop(merged2018_2019[merged2018_2019['to_station_name'] == 'HUBBARD ST BIKE CHECKING (LBS-WH-TEST)'].index)

merged2018_2019 = merged2018_2019.drop(merged2018_2019[merged2018_2019['from_station_name'] == 'Special Events'].index)
merged2018_2019 = merged2018_2019.drop(merged2018_2019[merged2018_2019['to_station_name'] == 'Special Events'].index)

merged2018_2019 = merged2018_2019.drop(merged2018_2019[merged2018_2019['from_station_name'] == 'LBS - BBB La Magie'].index)
merged2018_2019 = merged2018_2019.drop(merged2018_2019[merged2018_2019['to_station_name'] == 'LBS - BBB La Magie'].index)

# %%
merged2018_2019[merged2018_2019['from_lat'].isnull()]
# Out:
# Empty DataFrame
# Columns: [trip_id, start_time, end_time, bikeid, tripduration, from_station_id, from_station_name, to_station_id, to_station_name, usertype, gender, birthyear, start_date, end_date, from_lat, from_long, dpcapacity_x, from_landmark, from_city, to_lat, to_long, dpcapacity_y, to_landmark, to_city, rideable_type]
# Index: []
#
# [0 rows x 25 columns]

# %%
merged2018_2019[merged2018_2019['to_lat'].isnull()]
# Out:
#           trip_id start_time  end_time  bikeid tripduration  from_station_id  \
# 4417203  22721057   10:27:00  10:39:03    2191        723.0              410
# 4417328  22721199   10:43:33  10:48:51    4732        318.0              279
#
#                 from_station_name  to_station_id           to_station_name  \
# 4417203     Prairie Ave & 43rd St            363  TS ~ DIVVY PARTS TESTING
# 4417328  Halsted St & 35th St (*)            363  TS ~ DIVVY PARTS TESTING
#
#         usertype  ...  from_long  dpcapacity_x from_landmark from_city  \
# 4417203   casual  ... -87.619412          19.0         452.0   Chicago
# 4417328   member  ... -87.647172          15.0         413.0   Chicago
#
#          to_lat  to_long  dpcapacity_y  to_landmark to_city  rideable_type
# 4417203     NaN      NaN           NaN          NaN     NaN   classic_bike
# 4417328     NaN      NaN           NaN          NaN     NaN   classic_bike
#
# [2 rows x 25 columns]

# %%
merged2018_2019 = merged2018_2019.drop(merged2018_2019[merged2018_2019['from_station_name'] == 'TS ~ DIVVY PARTS TESTING'].index)
merged2018_2019 = merged2018_2019.drop(merged2018_2019[merged2018_2019['to_station_name'] == 'TS ~ DIVVY PARTS TESTING'].index)

# %%
merged2018_2019[merged2018_2019['to_lat'].isnull()]
# Out:
# Empty DataFrame
# Columns: [trip_id, start_time, end_time, bikeid, tripduration, from_station_id, from_station_name, to_station_id, to_station_name, usertype, gender, birthyear, start_date, end_date, from_lat, from_long, dpcapacity_x, from_landmark, from_city, to_lat, to_long, dpcapacity_y, to_landmark, to_city, rideable_type]
# Index: []
#
# [0 rows x 25 columns]

# %%
merged2018_2019.isnull().sum()
# Out:
# trip_id              0
# start_time           0
# end_time             0
# bikeid               0
# tripduration         0
# from_station_id      0
# from_station_name    0
# to_station_id        0
# to_station_name      0
# usertype             0
# gender               0
# birthyear            0
# start_date           0
# end_date             0
# from_lat             0
# from_long            0
# dpcapacity_x         0
# from_landmark        0
# from_city            0
# to_lat               0
# to_long              0
# dpcapacity_y         0
# to_landmark          0
# to_city              0
# rideable_type        0
# dtype: int64

# %%
merged2018_2019.shape
# Out:
# (7392597, 25)

# %%
# making sure no test Values are left
merged2018_2019 = merged2018_2019.drop(merged2018_2019[merged2018_2019['from_station_name'].str.lower().str.contains("test", regex=False, na=False) == True].index)
merged2018_2019 = merged2018_2019.drop(merged2018_2019[merged2018_2019['to_station_name'].str.lower().str.contains("test", regex=False, na=False) == True].index)

# %%
merged2018_2019.shape
# Out:
# (7392597, 25)

# %%
hi = sorted(list(set(merged2018_2019['from_station_name'].values)))

for i in range(len(hi)):
    print(hi[i])
# Out:
# 2112 W Peterson Ave
# 63rd St Beach
# 900 W Harrison St
# Aberdeen St & Jackson Blvd
# Aberdeen St & Monroe St
# Aberdeen St & Randolph St
# Ada St & Washington Blvd
# Adler Planetarium
# Albany Ave & 26th St
# Albany Ave & Bloomingdale Ave
# Albany Ave & Montrose Ave
# Archer (Damen) Ave & 37th St
# Archer (Damen) Ave & 37th St (*)
# Artesian Ave & Hubbard St
# Ashland Ave & 13th St
# Ashland Ave & 21st St
# Ashland Ave & 50th St
# Ashland Ave & 63rd St
# Ashland Ave & 66th St
# Ashland Ave & 69th St
# Ashland Ave & Archer Ave
# Ashland Ave & Augusta Blvd
# Ashland Ave & Belle Plaine Ave
# Ashland Ave & Blackhawk St
# Ashland Ave & Chicago Ave
# Ashland Ave & Division St
# Ashland Ave & Garfield Blvd
# Ashland Ave & Grace St
# Ashland Ave & Grand Ave
# Ashland Ave & Harrison St
# Ashland Ave & Lake St
# Ashland Ave & Lake St (Temp)
# Ashland Ave & McDowell Ave
# Ashland Ave & Pershing Rd
# Ashland Ave & Wellington Ave
# Ashland Ave & Wrightwood Ave
# Austin Blvd & Chicago Ave
# ...

# %%
# DIVVY CASSETTE REPAIR MOBILE STATION , 

merged2018_2019 = merged2018_2019.drop(merged2018_2019[merged2018_2019['from_station_name'] == 'TS ~ DIVVY PARTS TESTING'].index)
merged2018_2019 = merged2018_2019.drop(merged2018_2019[merged2018_2019['to_station_name'] == 'TS ~ DIVVY PARTS TESTING'].index)

# some values with (Temp) or (*) at the end of the station names can be combined with non-temp or non-* values, will keep this
# in mind for later during final cleaning.

# %%
l1 = list(merged2018_2019[merged2018_2019['from_station_name'] == 'DIVVY CASSETTE REPAIR MOBILE STATION'].index)
l2 = list(merged2018_2019[merged2018_2019['to_station_name'] == 'DIVVY CASSETTE REPAIR MOBILE STATION'].index)

overlap = list(set(l1) & set(l2))
merged2018_2019 = merged2018_2019.drop(overlap)

# %%
merged2018_2019 = merged2018_2019.reset_index()

# %%
merged2018_2019.to_csv('merged2018_2019.csv')
