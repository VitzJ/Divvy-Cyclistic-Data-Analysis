# %%
import pandas as pd

# %%
merged2013_2017 = pd.read_csv('merged2013_2017.csv')

# %%
merged2013_2017.head()
# Out:
#    Unnamed: 0  trip_id start_time end_time  bikeid  tripduration  \
# 0           0     9651      00:00    00:09     478           487
# 1           1    19385      00:00    00:06     893           359
# 2           2    29952      00:00    00:27     311          1623
# 3           3    37222      00:00    00:44     420          2639
# 4           4    59638      00:00    00:25     187          1479
#
#    from_station_id             from_station_name  to_station_id  \
# 0               34     Cannon Dr & Fullerton Ave             67
# 1               20  Sheffield Ave & Kingsbury St             60
# 2               59     Wabash Ave & Roosevelt Rd             97
# 3               76     Lake Shore Dr & Monroe St             76
# 4               27       Larrabee St & North Ave             24
#
#                  to_station_name  ... Unnamed: 0.2 rideable_type  from_city  \
# 0  Sheffield Ave & Fullerton Ave  ...          0.0  classic_bike    Chicago
# ...

# %%
merged2013_2017.drop('Unnamed: 0', axis=1, inplace=True)

# %%
merged2018_2019 = pd.read_csv('merged2018_2019.csv')

# %%
merged2018_2019.head()
# Out:
#    Unnamed: 0  index   trip_id start_time  end_time  bikeid tripduration  \
# 0           0      0  17536702   00:12:00  00:17:23    3304        323.0
# 1           1      1  17536703   00:41:35  00:47:52    5367        377.0
# 2           2      2  17536704   00:44:46  01:33:10    4599      2,904.0
# 3           3      3  17536705   00:53:10  01:05:37    2302        747.0
# 4           4      4  17536706   00:53:37  00:56:40    3696        183.0
#
#    from_station_id            from_station_name  to_station_id  ...  \
# 0               69       Damen Ave & Pierce Ave            159  ...
# 1              253  Winthrop Ave & Lawrence Ave            325  ...
# 2               98   LaSalle St & Washington St            509  ...
# 3              125         Rush St & Hubbard St            364  ...
# 4              129    Blue Island Ave & 18th St            205  ...
#
#    from_long dpcapacity_x from_landmark  from_city     to_lat    to_long  \
# ...

# %%
merged2018_2019.drop(['Unnamed: 0', 'index'], axis=1, inplace=True)

# %%
merged2018_2019.rename(columns={'dpcapacity_x':'from_dpcapacity', 'dpcapacity_y':'to_dpcapacity'}, inplace=True)

# %%
merged2020_2022 = pd.read_csv('merged2020_2022.csv')

# %%
merged2020_2022.head()
# Out:
#    Unnamed: 0           trip_id rideable_type start_time  end_time  \
# 0           0  EACB19130B0CDA4A   docked_bike   20:06:59  20:14:30
# 1           1  8FED874C809DC021   docked_bike   14:22:39  14:26:22
# 2           2  789F3C21E472CA96   docked_bike   19:29:26  19:32:17
# 3           3  C9A388DAC6ABF313   docked_bike   16:17:07  16:25:56
# 4           4  943BC3CBECCFD662   docked_bike   08:37:16  08:42:48
#
#           from_station_name from_station_id                 to_station_name  \
# 0  Western Ave & Leland Ave           239.0           Clark St & Leland Ave
# 1   Clark St & Montrose Ave           234.0  Southport Ave & Irving Park Rd
# 2    Broadway & Belmont Ave           296.0        Wilton Ave & Belmont Ave
# 3    Clark St & Randolph St            51.0        Fairbanks Ct & Grand Ave
# 4      Clinton St & Lake St            66.0           Wells St & Hubbard St
#
#   end_station_id  start_lat  ...  usertype  start_date    end_date  \
# ...

# %%
merged2020_2022.drop('Unnamed: 0', axis=1, inplace=True)

# %%
sorted(set(list(merged2013_2017.columns))) == sorted(set(list(merged2018_2019.columns)))
# Out:
# False

# %%
list_1 = sorted(set(list(merged2020_2022.columns)))
list_2 = sorted(set(list(merged2013_2017.columns)))

[item for item in list_2 if item not in list_1]
# Out:
# ['Unnamed: 0.2',
#  'bikeid',
#  'birthyear',
#  'from_dpcapacity',
#  'from_lat',
#  'from_long',
#  'gender',
#  'to_dpcapacity',
#  'to_lat',
#  'to_long',
#  'to_station_id']

# %%
merged2013_2017.rename(columns = {'to_station_id':'end_station_id', 'from_station_id':'start_station_id',
                                  'from_dpcapacity':'start_dpcapacity', 'to_dpcapacity':'end_dpcapacity', 
                                  'from_lat':'start_lat', 'from_long':'start_lng', 'to_lat':'end_lat', 
                                  'to_long':'end_lng'}, inplace=True)                                                 
merged2018_2019.rename(columns = {'to_station_id':'end_station_id', 'from_station_id':'start_station_id',
                                  'from_dpcapacity':'start_dpcapacity', 'to_dpcapacity':'end_dpcapacity',
                                  'from_lat':'start_lat', 'from_long':'start_lng', 'to_lat':'end_lat', 
                                  'to_long':'end_lng'}, inplace=True)
merged2020_2022.rename(columns = {'from_station_id':'start_station_id'}, inplace=True)

# %%
merged2013_2017.rename(columns={'from_station_name':'start_station_name', 'to_station_name':'end_station_name',
                                'from_city':'start_city', 'to_city':'end_city', 'from_landmark':'start_landmark',
                                'to_landmark':'end_landmark'}, inplace=True)
merged2018_2019.rename(columns={'from_station_name':'start_station_name', 'to_station_name':'end_station_name',
                                'from_city':'start_city', 'to_city':'end_city', 'from_landmark':'start_landmark',
                                'to_landmark':'end_landmark'}, inplace=True)
merged2020_2022.rename(columns={'from_station_name':'start_station_name', 'to_station_name':'end_station_name',
                                'from_city':'start_city', 'to_city':'end_city', 'from_landmark':'start_landmark',
                                'to_landmark':'end_landmark'}, inplace=True)

# %%
list_1 = sorted(set(list(merged2020_2022.columns)))
list_2 = sorted(set(list(merged2013_2017.columns)))

[item for item in list_2 if item not in list_1]
# Out:
# ['Unnamed: 0.2', 'bikeid', 'birthyear', 'gender']

# %%
# dropping bikeid because it is not present in 2020-2022
merged2013_2017.drop('bikeid', axis=1, inplace=True)
merged2018_2019.drop('bikeid', axis=1, inplace=True)

# %%
list_1 = sorted(set(list(merged2020_2022.columns)))
list_2 = sorted(set(list(merged2013_2017.columns)))

[item for item in list_2 if item not in list_1]
# Out:
# ['Unnamed: 0.2', 'birthyear', 'gender']

# %%
merged2020_2022.shape[0]
# Out:
# 11942201

# %%
# birthyear and gender will be added to merged2020_2022, however it will simply
# be added in a way that makes it easy to figure out that the values are
# basically invalids
merged2020_2022['birthyear'] = [0] * merged2020_2022.shape[0]
merged2020_2022['gender'] = [-1] * merged2020_2022.shape[0]

# %%
list_1 = sorted(set(list(merged2020_2022.columns)))
list_2 = sorted(set(list(merged2013_2017.columns)))

[item for item in list_2 if item not in list_1]
# Out:
# ['Unnamed: 0.2']

# %%
merged2013_2022 = pd.concat([merged2013_2017, merged2018_2019, merged2020_2022])

# %%
del(merged2013_2017)
del(merged2018_2019)
del(merged2020_2022)

# %%
merged2013_2022.to_csv('backup_merged2013_2022_incase_from_1FullDivvyDataframept1unifinished')

# %%
merged2013_2022.head()
# Out:
#   trip_id start_time end_time tripduration start_station_id  \
# 0    9651      00:00    00:09          487               34
# 1   19385      00:00    00:06          359               20
# 2   29952      00:00    00:27         1623               59
# 3   37222      00:00    00:44         2639               76
# 4   59638      00:00    00:25         1479               27
#
#              start_station_name end_station_id               end_station_name  \
# 0     Cannon Dr & Fullerton Ave             67  Sheffield Ave & Fullerton Ave
# 1  Sheffield Ave & Kingsbury St             60          Dayton St & North Ave
# 2     Wabash Ave & Roosevelt Rd             97                  Museum Campus
# 3     Lake Shore Dr & Monroe St             76      Lake Shore Dr & Monroe St
# 4       Larrabee St & North Ave             24       Fairbanks Ct & Grand Ave
#
#   usertype gender  ...  Unnamed: 0.2  rideable_type  start_city  \
# 0   casual      0  ...           0.0   classic_bike     Chicago
# ...

# %%
merged2013_2022.drop(['Unnamed: 0.2'], axis=1, inplace=True)

# %%
merged2013_2022.sort_values(by=['start_date', 'start_time'], inplace=True)

# %%
merged2013_2022.head(60)
# Out:
#          trip_id start_time end_time tripduration start_station_id  \
# 46240       3940      01:06    09:46        31177               91
# 2032644     4113      11:09    11:11          140               88
# 2064015     4119      11:12    11:13           87               88
# 2195196     4134      11:24    14:38        11674               17
# 2373269     4162      11:39    16:01        15758               88
# 2733131     4095      12:06    12:11          301               85
# 2802172     4118      12:11    12:16          316               85
# 2857028     4192      12:15    12:16           60               28
# 3477277     4216      13:00    13:03          171               45
# 3732005     4255      13:18    19:34        22549               45
# 4854214     4263      14:39    14:40           62               61
# 4922947     4275      14:44    14:45           64               32
# 5089662     4288      14:56    14:57           66               68
# ...

# %%
merged2013_2022.reset_index(inplace=True)

# %%
merged2013_2022.head(60)
# Out:
#        index trip_id start_time end_time tripduration start_station_id  \
# 0      46240    3940      01:06    09:46        31177               91
# 1    2032644    4113      11:09    11:11          140               88
# 2    2064015    4119      11:12    11:13           87               88
# 3    2195196    4134      11:24    14:38        11674               17
# 4    2373269    4162      11:39    16:01        15758               88
# 5    2733131    4095      12:06    12:11          301               85
# 6    2802172    4118      12:11    12:16          316               85
# 7    2857028    4192      12:15    12:16           60               28
# 8    3477277    4216      13:00    13:03          171               45
# 9    3732005    4255      13:18    19:34        22549               45
# 10   4854214    4263      14:39    14:40           62               61
# 11   4922947    4275      14:44    14:45           64               32
# ...

# %%
# Now I will bring functions from previous seperate cleanings in, to filter out improper data and time values. Once we are done
# filtering out all of the invalid dates, we can filter out invalid times

def leap_year_check(year):
    if year % 4 == 0:
        
        if year % 100 != 0:
            if year % 400 == 0:
                return True
        else:
            return False
        
        return True
    
    else:
        return False
        


# this function takes start and end date combinations and checks if they are valid. It returns the index position of all invalid
# date combinations so that they can be dropped.
def date_checker(test_start_dates=[],test_end_dates=[]):
    
    month_max_days = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
    date_invalid_check = []
    
    for i in range(len(test_start_dates)):
    
        start_d_test = test_start_dates[i].split('-')
        end_d_test = test_end_dates[i].split('-')
        
        # These are our years
        st_year = int(start_d_test[0])
        ed_year = int(end_d_test[0])
        
        # These are our months
        st_month = int(start_d_test[1])
        ed_month = int(end_d_test[1])

        # These are our days
        st_day = int(start_d_test[2])
        ed_day = int(end_d_test[2])
        
        # if the years of the dates are not the same        
        
        if st_year + 1 == ed_year and st_month == 12 and ed_month == 1 and ed_day == 1: 
                #print('Start Month end to Next month beginning: ', i)
                month_max = month_max_days[st_month - 1]

                # accounting for february leap years
                if leap_year_check(st_year) and st_month == 2:
                    #print('February: ', i)
                    month_max = 29
                
                # if our st_day is not the last day of the respective st_month, the date is invalid
                if st_day - month_max != 0:
                    #print('Start Month not ended yet, or day does not exist: ', i)
                    date_invalid_check.append(i)
        
        elif st_year != ed_year:
            #print('Year: ', i)
            date_invalid_check.append(i)

        # If st_month is after ed_month
        elif st_month > ed_month:
            #print(st_month == ed_month)
            #print('Start Month occurs after end month: ', i)
            date_invalid_check.append(i)
        
        # if st_month is more than 1 month before ed_month
        elif ed_month - st_month > 1:    
            #print(st_month == ed_month)
            #print('Start Month is too far from end month: ', i)
            date_invalid_check.append(i)
        
        elif ed_month == st_month + 1 and ed_day != 1:
            date_invalid_check.append(i)
        
        # If the ed_day is more than one day after the st_day, this works regardless of month
        elif ed_day - st_day > 1:
            #print('Day: ', i)
            date_invalid_check.append(i)
        
        # if ed_day - st_day is negative, we have to examine why, because we don't want to delete all overnight ride rentals
        # just because the person rented at the very end of the month
        elif ed_day - st_day < 0:
            #print('Day difference Negative: ', i)
            
            # if the month is the same, this chronological difference make no sense
            if ed_month == st_month:
                #print('Month is same: ', i)
                date_invalid_check.append(i)
            
            # if the st_month is the month before ed_month and it is the first day of ed_month
            elif ed_month == st_month + 1 and ed_day == 1:
                #print('Start Month end to Next month beginning: ', i)
                month_max = month_max_days[st_month - 1]

                # accounting for february leap years
                if leap_year_check(st_year) and st_month == 2:
                    #print('February: ', i)
                    month_max = 29
                
                # if our st_day is not the last day of the respective st_month, the date is invalid
                if st_day - month_max != 0:
                    #print('Start Month not ended yet, or day does not exist: ', i)
                    date_invalid_check.append(i)

    return date_invalid_check


drop_these_rows = date_checker(merged2013_2022['start_date'].values, merged2013_2022['end_date'].values)

# %%
len(drop_these_rows)
# Out:
# 2194

# %%
merged2013_2022.loc[drop_these_rows]
# Out:
#             index   trip_id start_time  end_time tripduration  \
# 13820678        9  17536711   01:07:54  10:04:02    464,168.0
# 13830902    10233  17550955   23:29:38  14:29:05    399,567.0
# 13834182    13514  17555348   15:18:27  20:58:25    193,198.0
# 13841011    20342  17563555   18:18:46  09:53:44    574,498.0
# 13856145    35476  17581977   01:35:05  19:16:20    236,475.0
# ...           ...       ...        ...       ...          ...
# 21204799  7384131  25953956   11:48:34  14:50:36    183,721.0
# 21206413  7385743  25955666   15:32:46  12:21:38    334,131.0
# 21211610  7390942  25961153   10:02:20  18:33:31    203,471.0
# 21212326  7391657  25961900   14:56:05  11:59:00    162,175.0
# 21212327  7391658  25961901   14:56:20  11:58:36    162,136.0
#
#          start_station_id           start_station_name end_station_id  \
# 13820678               99      Lake Shore Dr & Ohio St             99
# 13830902              125         Rush St & Hubbard St            133
# ...

# %%
merged2013_2022.drop(drop_these_rows, inplace=True)

# %%
merged2013_2022.dtypes
# Out:
# index                   int64
# trip_id                object
# start_time             object
# end_time               object
# tripduration           object
# start_station_id       object
# start_station_name     object
# end_station_id         object
# end_station_name       object
# usertype               object
# gender                 object
# birthyear             float64
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# rideable_type          object
# start_city             object
# start_landmark        float64
# end_city               object
# end_landmark          float64
# start_date             object
# end_date               object
# start_dpcapacity      float64
# end_dpcapacity        float64
# dtype: object

# %%
# If this is true, we don't have to drop on subset = 'trip_id'
len(set(merged2013_2022['trip_id'].values)) == len(merged2013_2022['trip_id'].values)
# Out:
# True

# %%
# don't need 'trip_id' anymore, as it was used to remove duplicates
merged2013_2022.drop('trip_id', axis=1, inplace=True)

# %%
merged2013_2022.reset_index(inplace=True)

# %%
merged2013_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33153270 entries, 0 to 33153269
# Data columns (total 25 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   level_0             int64
#  1   index               int64
#  2   start_time          object
#  3   end_time            object
#  4   tripduration        object
#  5   start_station_id    object
#  6   start_station_name  object
#  7   end_station_id      object
#  8   end_station_name    object
#  9   usertype            object
#  10  gender              object
#  11  birthyear           float64
#  12  start_lat           float64
#  13  start_lng           float64
#  14  end_lat             float64
#  15  end_lng             float64
#  16  rideable_type       object
#  17  start_city          object
#  18  start_landmark      float64
#  19  end_city            object
#  20  end_landmark        float64
#  21  start_date          object
#  22  end_date            object
# ...

# %%
merged2013_2022.head()
# Out:
#    level_0    index start_time end_time tripduration start_station_id  \
# 0        0    46240      01:06    09:46        31177               91
# 1        1  2032644      11:09    11:11          140               88
# 2        2  2064015      11:12    11:13           87               88
# 3        3  2195196      11:24    14:38        11674               17
# 4        4  2373269      11:39    16:01        15758               88
#
#              start_station_name end_station_id            end_station_name  \
# 0  Clinton St & Washington Blvd             48  Larrabee St & Kingsbury St
# 1          May St & Randolph St             88        May St & Randolph St
# 2          May St & Randolph St             88        May St & Randolph St
# 3         Wood St & Division St             61     Wood St & Milwaukee Ave
# 4          May St & Randolph St             34   Cannon Dr & Fullerton Ave
#
#   usertype  ...    end_lng  rideable_type  start_city  start_landmark  \
# ...

# %%
merged2013_2022.columns
# Out:
# Index(['level_0', 'index', 'start_time', 'end_time', 'tripduration',
#        'start_station_id', 'start_station_name', 'end_station_id',
#        'end_station_name', 'usertype', 'gender', 'birthyear', 'start_lat',
#        'start_lng', 'end_lat', 'end_lng', 'rideable_type', 'start_city',
#        'start_landmark', 'end_city', 'end_landmark', 'start_date', 'end_date',
#        'start_dpcapacity', 'end_dpcapacity'],
#       dtype='object')

# %%
merged2013_2022.drop(['level_0', 'index'], axis=1, inplace=True)

# %%
# Changing start/end city to int values

merged2013_2022.loc[merged2013_2022['start_city'] == 'Chicago', 'start_city'] = 0
merged2013_2022.loc[merged2013_2022['start_city'] == 'Evanston', 'start_city'] = 1
merged2013_2022.loc[merged2013_2022['start_city'] == 'Oak Park', 'start_city'] = 2

merged2013_2022.loc[merged2013_2022['end_city'] == 'Chicago', 'end_city'] = 0
merged2013_2022.loc[merged2013_2022['end_city'] == 'Evanston', 'end_city'] = 1
merged2013_2022.loc[merged2013_2022['end_city'] == 'Oak Park', 'end_city'] = 2

# %%
merged2013_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33153270 entries, 0 to 33153269
# Data columns (total 23 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   start_time          object
#  1   end_time            object
#  2   tripduration        object
#  3   start_station_id    object
#  4   start_station_name  object
#  5   end_station_id      object
#  6   end_station_name    object
#  7   usertype            object
#  8   gender              object
#  9   birthyear           float64
#  10  start_lat           float64
#  11  start_lng           float64
#  12  end_lat             float64
#  13  end_lng             float64
#  14  rideable_type       object
#  15  start_city          object
#  16  start_landmark      float64
#  17  end_city            object
#  18  end_landmark        float64
#  19  start_date          object
#  20  end_date            object
#  21  start_dpcapacity    float64
#  22  end_dpcapacity      float64
# ...

# %%
merged2013_2022['end_city'].unique()
# Out:
# array([0, 2, 1], dtype=object)

# %%
merged2013_2022['end_city'] = merged2013_2022['end_city'].astype('int64')

# %%
merged2013_2022['start_city'].unique()
# Out:
# array([0, 2, 1], dtype=object)

# %%
merged2013_2022['start_city'] = merged2013_2022['start_city'].astype('int64')

# %%
merged2013_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33153270 entries, 0 to 33153269
# Data columns (total 23 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   start_time          object
#  1   end_time            object
#  2   tripduration        object
#  3   start_station_id    object
#  4   start_station_name  object
#  5   end_station_id      object
#  6   end_station_name    object
#  7   usertype            object
#  8   gender              object
#  9   birthyear           float64
#  10  start_lat           float64
#  11  start_lng           float64
#  12  end_lat             float64
#  13  end_lng             float64
#  14  rideable_type       object
#  15  start_city          int64
#  16  start_landmark      float64
#  17  end_city            int64
#  18  end_landmark        float64
#  19  start_date          object
#  20  end_date            object
#  21  start_dpcapacity    float64
#  22  end_dpcapacity      float64
# ...

# %%
merged2013_2022['start_landmark'] = merged2013_2022['start_landmark'].astype('int64')

# %%
merged2013_2022['end_landmark'] = merged2013_2022['end_landmark'].astype('int64')

# %%
merged2013_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33153270 entries, 0 to 33153269
# Data columns (total 23 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   start_time          object
#  1   end_time            object
#  2   tripduration        object
#  3   start_station_id    object
#  4   start_station_name  object
#  5   end_station_id      object
#  6   end_station_name    object
#  7   usertype            object
#  8   gender              object
#  9   birthyear           float64
#  10  start_lat           float64
#  11  start_lng           float64
#  12  end_lat             float64
#  13  end_lng             float64
#  14  rideable_type       object
#  15  start_city          int64
#  16  start_landmark      int64
#  17  end_city            int64
#  18  end_landmark        int64
#  19  start_date          object
#  20  end_date            object
#  21  start_dpcapacity    float64
#  22  end_dpcapacity      float64
# ...

# %%
merged2013_2022['start_dpcapacity'] = merged2013_2022['start_dpcapacity'].astype('int64')
merged2013_2022['end_dpcapacity'] = merged2013_2022['end_dpcapacity'].astype('int64')

# %%
merged2013_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33153270 entries, 0 to 33153269
# Data columns (total 23 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   start_time          object
#  1   end_time            object
#  2   tripduration        object
#  3   start_station_id    object
#  4   start_station_name  object
#  5   end_station_id      object
#  6   end_station_name    object
#  7   usertype            object
#  8   gender              object
#  9   birthyear           float64
#  10  start_lat           float64
#  11  start_lng           float64
#  12  end_lat             float64
#  13  end_lng             float64
#  14  rideable_type       object
#  15  start_city          int64
#  16  start_landmark      int64
#  17  end_city            int64
#  18  end_landmark        int64
#  19  start_date          object
#  20  end_date            object
#  21  start_dpcapacity    int64
#  22  end_dpcapacity      int64
# ...

# %%
merged2013_2022['rideable_type'].unique()
# Out:
# array(['classic_bike', 'docked_bike', 'electric_bike'], dtype=object)

# %%
# Changing rideable_type to int values

merged2013_2022.loc[merged2013_2022['rideable_type'] == 'classic_bike', 'rideable_type'] = 0
merged2013_2022.loc[merged2013_2022['rideable_type'] == 'docked_bike', 'rideable_type'] = 1
merged2013_2022.loc[merged2013_2022['rideable_type'] == 'electric_bike', 'rideable_type'] = 2

# %%
merged2013_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33153270 entries, 0 to 33153269
# Data columns (total 23 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   start_time          object
#  1   end_time            object
#  2   tripduration        object
#  3   start_station_id    object
#  4   start_station_name  object
#  5   end_station_id      object
#  6   end_station_name    object
#  7   usertype            object
#  8   gender              object
#  9   birthyear           float64
#  10  start_lat           float64
#  11  start_lng           float64
#  12  end_lat             float64
#  13  end_lng             float64
#  14  rideable_type       object
#  15  start_city          int64
#  16  start_landmark      int64
#  17  end_city            int64
#  18  end_landmark        int64
#  19  start_date          object
#  20  end_date            object
#  21  start_dpcapacity    int64
#  22  end_dpcapacity      int64
# ...

# %%
merged2013_2022['rideable_type'] = merged2013_2022['rideable_type'].astype('int64')

# %%
merged2013_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33153270 entries, 0 to 33153269
# Data columns (total 23 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   start_time          object
#  1   end_time            object
#  2   tripduration        object
#  3   start_station_id    object
#  4   start_station_name  object
#  5   end_station_id      object
#  6   end_station_name    object
#  7   usertype            object
#  8   gender              object
#  9   birthyear           float64
#  10  start_lat           float64
#  11  start_lng           float64
#  12  end_lat             float64
#  13  end_lng             float64
#  14  rideable_type       int64
#  15  start_city          int64
#  16  start_landmark      int64
#  17  end_city            int64
#  18  end_landmark        int64
#  19  start_date          object
#  20  end_date            object
#  21  start_dpcapacity    int64
#  22  end_dpcapacity      int64
# ...

# %%
merged2013_2022['gender'].unique()
# Out:
# array(['Male', '0', 'Female', -1], dtype=object)

# %%
merged2013_2022.loc[merged2013_2022['gender'] == 'Male', 'gender'] = 0
merged2013_2022.loc[merged2013_2022['gender'] == '0', 'gender'] = -1
merged2013_2022.loc[merged2013_2022['gender'] == 'Female', 'gender'] = 1

# %%
merged2013_2022['gender'] = merged2013_2022['gender'].astype('int64')

# %%
merged2013_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33153270 entries, 0 to 33153269
# Data columns (total 23 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   start_time          object
#  1   end_time            object
#  2   tripduration        object
#  3   start_station_id    object
#  4   start_station_name  object
#  5   end_station_id      object
#  6   end_station_name    object
#  7   usertype            object
#  8   gender              int64
#  9   birthyear           float64
#  10  start_lat           float64
#  11  start_lng           float64
#  12  end_lat             float64
#  13  end_lng             float64
#  14  rideable_type       int64
#  15  start_city          int64
#  16  start_landmark      int64
#  17  end_city            int64
#  18  end_landmark        int64
#  19  start_date          object
#  20  end_date            object
#  21  start_dpcapacity    int64
#  22  end_dpcapacity      int64
# ...

# %%
merged2013_2022['usertype'].unique()
# Out:
# array(['member', 'casual'], dtype=object)

# %%
merged2013_2022.loc[merged2013_2022['usertype'] == 'casual', 'usertype'] = 0
merged2013_2022.loc[merged2013_2022['usertype'] == 'member', 'usertype'] = 1

# %%
merged2013_2022['usertype'] = merged2013_2022['usertype'].astype('int64')

# %%
merged2013_2022['birthyear'] = merged2013_2022['birthyear'].astype('int64')

# %%
merged2013_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33153270 entries, 0 to 33153269
# Data columns (total 23 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   start_time          object
#  1   end_time            object
#  2   tripduration        object
#  3   start_station_id    object
#  4   start_station_name  object
#  5   end_station_id      object
#  6   end_station_name    object
#  7   usertype            int64
#  8   gender              int64
#  9   birthyear           int64
#  10  start_lat           float64
#  11  start_lng           float64
#  12  end_lat             float64
#  13  end_lng             float64
#  14  rideable_type       int64
#  15  start_city          int64
#  16  start_landmark      int64
#  17  end_city            int64
#  18  end_landmark        int64
#  19  start_date          object
#  20  end_date            object
#  21  start_dpcapacity    int64
#  22  end_dpcapacity      int64
# ...

# %%
new_column = []
trip_dur = merged2013_2022['tripduration'].values

# %%
for i in range(len(trip_dur)):
    try:
        new_column.append(int(float(trip_dur[i])))
    except ValueError:
        new_column.append(int(float(trip_dur[i].replace(',',''))))

# %%
merged2013_2022.shape
# Out:
# (33153270, 23)

# %%
trip_dur[:10]
# Out:
# array([31177, 140, 87, 11674, 15758, 301, 316, 60, 171, 22549],
#       dtype=object)

# %%
new_column[:10]
# Out:
# [31177, 140, 87, 11674, 15758, 301, 316, 60, 171, 22549]

# %%
merged2013_2022['tripduration'] = new_column

# %%
merged2013_2022['tripduration'] = merged2013_2022['tripduration'].astype('int64')

# %%
merged2013_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33153270 entries, 0 to 33153269
# Data columns (total 23 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   start_time          object
#  1   end_time            object
#  2   tripduration        int64
#  3   start_station_id    object
#  4   start_station_name  object
#  5   end_station_id      object
#  6   end_station_name    object
#  7   usertype            int64
#  8   gender              int64
#  9   birthyear           int64
#  10  start_lat           float64
#  11  start_lng           float64
#  12  end_lat             float64
#  13  end_lng             float64
#  14  rideable_type       int64
#  15  start_city          int64
#  16  start_landmark      int64
#  17  end_city            int64
#  18  end_landmark        int64
#  19  start_date          object
#  20  end_date            object
#  21  start_dpcapacity    int64
#  22  end_dpcapacity      int64
# ...

# %%
change_times_st = merged2013_2022['start_time'].values
change_times_ed = merged2013_2022['end_time'].values

new_st_times = []
new_ed_times = []

for i in range(len(change_times_st)):
    if len(change_times_st[i]) == 4:
        new_st_times.append('0' + change_times_st[i] + ':00')
    elif len(change_times_st[i]) == 5:
        new_st_times.append(change_times_st[i] + ':00')
    else:
        new_st_times.append(change_times_st[i])
    
    if len(change_times_ed[i]) == 4:
        new_ed_times.append('0' + change_times_ed[i] + ':00')
    elif len(change_times_ed[i]) == 5:
        new_ed_times.append(change_times_ed[i] + ':00')
    else:
        new_ed_times.append(change_times_ed[i])

# %%
len(new_st_times) == len(new_ed_times)
# Out:
# True

# %%
len(new_st_times)
# Out:
# 33153270

# %%
merged2013_2022['start_time'] = new_st_times
merged2013_2022['end_time'] = new_ed_times

# %%
def time_check(start_time=[],end_time=[],test_start_dates=[],test_end_dates=[]):
    time_invalid = []
    for i in range(len(start_time)):
        
        # if start_time is after end time on the same day, then the entry is invalid
        if test_start_dates[i] == test_end_dates[i]:
            if start_time[i] > end_time[i]:
                time_invalid.append(i)

    return time_invalid


remove_times = time_check(merged2013_2022['start_time'].values, merged2013_2022['end_time'].values, merged2013_2022['start_date'].values, merged2013_2022['end_date'].values)

# %%
len(remove_times)
# Out:
# 10304

# %%
merged2013_2022.loc[remove_times]
# Out:
#          start_time  end_time  tripduration start_station_id  \
# 13535378   01:24:00  01:04:00          2385              144
# 13535389   01:29:00  01:05:00          2158              144
# 13535427   01:47:00  01:04:00          1028              210
# 13535435   01:51:00  01:07:00           932              349
# 13535436   01:54:00  01:06:00           716              321
# ...             ...       ...           ...              ...
# 32349689   18:00:55  18:00:32         86376     chargingstx5
# 32451336   17:47:44  17:47:34         86389     chargingstx5
# 32733633   17:27:30  17:27:26         86395     TA1307000121
# 32774785   08:55:01  08:54:45         86383             E008
# 32921028   14:42:10  11:53:28         76277     chargingstx0
#
#                    start_station_name end_station_id  \
# 13535378    Larrabee St & Webster Ave             76
# 13535389    Larrabee St & Webster Ave             76
# 13535427    Ashland Ave & Division St            274
# ...

# %%
merged2013_2022.drop(remove_times, inplace=True)

# %%
remove_time_df = pd.DataFrame(remove_times)

# %%
remove_time_df.to_csv('remove times.csv')

# %%
merged2013_2022.isnull().sum()
# Out:
# start_time            0
# end_time              0
# tripduration          0
# start_station_id      0
# start_station_name    0
# end_station_id        0
# end_station_name      0
# usertype              0
# gender                0
# birthyear             0
# start_lat             0
# start_lng             0
# end_lat               0
# end_lng               0
# rideable_type         0
# start_city            0
# start_landmark        0
# end_city              0
# end_landmark          0
# start_date            0
# end_date              0
# start_dpcapacity      0
# end_dpcapacity        0
# dtype: int64

# %%
merged2013_2022.to_csv('1 Full Divvy Dataframe pt1.csv')
