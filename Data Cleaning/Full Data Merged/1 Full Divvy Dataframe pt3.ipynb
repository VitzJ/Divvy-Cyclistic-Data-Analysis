# %%
import pandas as pd

# %%
merged2013_2022 = pd.read_csv('1 Full Divvy Dataframe pt2.csv')

# %%
merged2013_2022.head()
# Out:
#    Unnamed: 0  index start_time  end_time  tripduration start_station_id  \
# 0           0      0   00:00:00  00:09:00           487               34
# 1           1      1   00:00:00  00:06:00           359               20
# 2           2      2   00:00:00  00:27:00          1623     TA1305000002
# 3           3      3   00:00:00  00:44:00          2639               76
# 4           4      4   00:00:00  00:25:00          1479     TA1306000008
#
#              start_station_name end_station_id               end_station_name  \
# 0     Cannon Dr & Fullerton Ave   TA1306000016  Sheffield Ave & Fullerton Ave
# 1  Sheffield Ave & Kingsbury St             60          Dayton St & North Ave
# 2     Wabash Ave & Roosevelt Rd             97                   Field Museum
# 3     Lake Shore Dr & Monroe St             76      Lake Shore Dr & Monroe St
# 4       Larrabee St & North Ave   TA1305000003       Fairbanks Ct & Grand Ave
#
# ...

# %%
merged2013_2022.drop(['Unnamed: 0', 'index'], axis=1, inplace=True)

# %%
merged2013_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33142958 entries, 0 to 33142957
# Data columns (total 23 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   start_time          object
#  1   end_time            object
#  2   tripduration        int64
#  3   start_station_id    object
#  4   start_station_name  object
#  5   end_station_id      object
#  6   end_station_name    object
#  7   usertype            int64
#  8   gender              int64
#  9   birthyear           int64
#  10  start_lat           float64
#  11  start_lng           float64
#  12  end_lat             float64
#  13  end_lng             float64
#  14  rideable_type       int64
#  15  start_city          int64
#  16  start_landmark      int64
#  17  end_city            int64
#  18  end_landmark        int64
#  19  start_date          object
#  20  end_date            object
#  21  start_dpcapacity    int64
#  22  end_dpcapacity      int64
# ...

# %%
merged2013_2022[merged2013_2022['start_dpcapacity'] == 0]
# Out:
#          start_time  end_time  tripduration start_station_id  \
# 1391       00:00:00  00:08:00           500              512
# 1475       00:00:00  00:32:24          1944     TA1305000011
# 1478       00:00:00  00:13:06           786     TA1309000033
# 1479       00:00:00  00:07:38           458     TA1305000014
# 1480       00:00:00  01:26:42          5202                2
# ...             ...       ...           ...              ...
# 33142953   23:59:59  00:16:03           963     chargingstx5
# 33142954   23:59:59  00:09:54           594     TA1307000134
# 33142955   23:59:59  00:09:32           572     TA1305000035
# 33142956   23:59:59  00:26:49          1609     TA1307000038
# 33142957   23:59:59  00:15:08           908            13053
#
#                                 start_station_name end_station_id  \
# 1391      Public Rack - California Ave & Cortez St            502
# 1475                        Michigan Ave & Lake St            LP-
# ...

# %%
# The function is to change dp_capacity values of a given a station name. The list is for verifying city
confirmed_list = []
def fix_dpcapacity(station_name='', dp_capacity=int):
    confirmed_list.append(station_name)
    
    merged2013_2022.loc[merged2013_2022['start_station_name'] == station_name, 'start_dpcapacity'] = dp_capacity
    merged2013_2022.loc[merged2013_2022['end_station_name'] == station_name, 'end_dpcapacity'] = dp_capacity

# %%
fix_dpcapacity('Kingsbury St & Kinzie St', 30)

# %%
fix_dpcapacity('Wood St & Milwaukee Ave', 17)

# %%
fix_dpcapacity('Leavitt St & Armitage Ave', 11)

# %%
fix_dpcapacity('Damen Ave & Charleston St', 11)
fix_dpcapacity('Rush St & Cedar St', 10)

# %%
fix_dpcapacity('Larrabee St & Webster Ave', 19)
fix_dpcapacity('Aberdeen St & Randolph St', 13)
fix_dpcapacity('Wilton Ave & Belmont Ave', 26)
fix_dpcapacity('Franklin St & Lake St', 26)
fix_dpcapacity('Sangamon St & Washington Blvd', 14)
fix_dpcapacity('Noble St & Milwaukee Ave', 13)
fix_dpcapacity('Halsted St & Roscoe St', 11)
fix_dpcapacity('Franklin St & Chicago Ave', 22)
fix_dpcapacity('Lakefront Trail & Bryn Mawr Ave', 18)

# %%
fix_dpcapacity('Sheffield Ave & Webster Ave', 19)
fix_dpcapacity('Fairbanks Ct & Grand Ave', 14)
fix_dpcapacity('Leavitt St & Addison St', 15)
fix_dpcapacity('Racine Ave & Randolph St', 19)
fix_dpcapacity('Fairbanks Ct & Grand Ave', 14)
fix_dpcapacity('Montrose Harbor', 31)
fix_dpcapacity('Clark St & Lake St', 42)
fix_dpcapacity('Lakeview Ave & Fullerton Pkwy', 18)
fix_dpcapacity('State St & Randolph St', 23)
fix_dpcapacity('Franklin St & Monroe St', 31)

# %%
fix_dpcapacity('900 W Harrison St', 19)
fix_dpcapacity('Ogden Ave & Congress Pkwy', 14)
fix_dpcapacity('Clinton St & Roosevelt Rd', 14)
fix_dpcapacity('DuSable Museum', 11)
fix_dpcapacity('Adler Planetarium', 39)
fix_dpcapacity('Michigan Ave & Pearson St', 20)
fix_dpcapacity('Daley Center Plaza', 39)
fix_dpcapacity('N Green St & W Lake St', 8)

# %%
fix_dpcapacity('Racine Ave & 18th St', 12)
fix_dpcapacity('Mies van der Rohe Way & Chicago Ave', 13)
fix_dpcapacity('Clinton St & Madison St', 27)
fix_dpcapacity('Wells St & Concord Ln', 10)
fix_dpcapacity('Leavitt St & Belmont Ave', 14)
fix_dpcapacity('Halsted St & Clybourn Ave', 25)
fix_dpcapacity('Franklin St & Jackson Blvd', 38)
fix_dpcapacity('Halsted St & 18th St', 15)

# %%
fix_dpcapacity('Kimbark Ave & 53rd St', 18)
fix_dpcapacity('State St & Chicago Ave', 14)
fix_dpcapacity('Emerald Ave & 31st St', 8)
fix_dpcapacity('Wells St & Polk St', 18)
fix_dpcapacity('DuSable Lake Shore Dr & North Blvd', 39)

# %%
fix_dpcapacity('Shore Dr & 55th St', 19)
fix_dpcapacity('DuSable Lake Shore Dr & Monroe St', 37)
fix_dpcapacity('Southport Ave & Clark St', 11)
fix_dpcapacity('Ashland Ave & Division St', 26)
fix_dpcapacity('Orleans St & Chestnut St (NEXT Apts)', 12)
fix_dpcapacity('Sheffield Ave & Willow St', 15)
fix_dpcapacity('Ashland Ave & Blackhawk St', 13)
fix_dpcapacity('Racine Ave & Wrightwood Ave', 14)

# %%
fix_dpcapacity('Clark St & Wrightwood Ave', 15)
fix_dpcapacity('Calumet Ave & 21st St', 14)
fix_dpcapacity('Clinton St & Lake St', 22)
fix_dpcapacity('Theater on the Lake', 31)
fix_dpcapacity('Lincoln Ave & Diversey Pkwy', 14)
fix_dpcapacity('Damen Ave & Division St', 17)
fix_dpcapacity('Millennium Park', 45)

# %%
fix_dpcapacity('Hermitage Ave & Polk St', 13)
fix_dpcapacity('Clark St & Winnemac Ave', 19)
fix_dpcapacity('Sedgwick St & Huron St', 25)
fix_dpcapacity('Ogden Ave & Chicago Ave', 19)
fix_dpcapacity('N Sheffield Ave & W Wellington Ave', 6)
fix_dpcapacity('Eckhart Park', 13)
fix_dpcapacity('Broadway & Sheridan Rd', 13)

# %%
fix_dpcapacity('Ogden Ave & Roosevelt Rd', 19 )
fix_dpcapacity('DuSable Lake Shore Dr & Wellington Ave', 14)
fix_dpcapacity('Wentworth Ave & 33rd St', 12)
fix_dpcapacity('Sheffield Ave & Waveland Ave', 27)
fix_dpcapacity('Dusable Harbor', 37)
fix_dpcapacity('Pine Grove Ave & Waveland Ave', 22)
fix_dpcapacity('State St & 79th St', 11)

# %%
fix_dpcapacity('Racine Ave & Congress Pkwy', 19)
fix_dpcapacity('Morgan St & Lake St*', 20)
fix_dpcapacity('LaSalle St & Washington St', 15)
fix_dpcapacity('Fort Dearborn Dr & 31st St', 27)
fix_dpcapacity('State St & Pearson St', 27)

# %%
fix_dpcapacity('Calumet Ave & 18th St', 13)
fix_dpcapacity('DuSable Lake Shore Dr & Diversey Pkwy', 23)
fix_dpcapacity('Southport Ave & Wellington Ave', 19)
fix_dpcapacity('Larrabee St & Menomonee St', 15)
fix_dpcapacity('Desplaines St & Jackson Blvd', 24)

# %%
fix_dpcapacity('Western Ave & Winnebago Ave', 14)
fix_dpcapacity('Larrabee St & North Ave', 16)
fix_dpcapacity('Damen Ave & Grand Ave', 21)
fix_dpcapacity('Michigan Ave & Lake St', 34)
fix_dpcapacity('Federal St & Polk St', 17)
fix_dpcapacity('State St & 29th St', 9)
fix_dpcapacity('State St & 35th St', 18)
fix_dpcapacity('Lincoln Ave & Belle Plaine Ave', 15)

# %%
fix_dpcapacity('Ogden Ave & Race Ave', 11)
fix_dpcapacity('Broadway & Cornelia Ave', 22)
fix_dpcapacity('LaSalle Dr & Huron St', 16)
fix_dpcapacity('Halsted St & Willow St', 18)
fix_dpcapacity('Cottage Grove Ave & 63rd St', 15)
fix_dpcapacity('Marine Dr & Ainslie St', 23)
fix_dpcapacity('Campbell Ave & Fullerton Ave', 14)

# %%
fix_dpcapacity('Morgan St & Polk St', 19)
fix_dpcapacity('Ritchie Ct & Banks St', 14)
fix_dpcapacity('Damen Ave & Chicago Ave', 13)
fix_dpcapacity('Wells St & Huron St', 25)
fix_dpcapacity('Wells St & Evergreen Ave', 11)
fix_dpcapacity('Clark St & Ida B Wells Dr', 35)

# %%
fix_dpcapacity('Southport Ave & Waveland Ave', 22)
fix_dpcapacity('St Clair St & Erie St', 17)
fix_dpcapacity('Wabash Ave & Grand Ave', 27)
fix_dpcapacity('Sheridan Rd & Argyle St', 15)

# %%
# Need to check Buckingham Fountain again at the end of this.

fix_dpcapacity('Buckingham Fountain', -1)
fix_dpcapacity('Wacker Dr & Washington St', 15)
fix_dpcapacity('California Ave & Altgeld St', 14)
fix_dpcapacity('Lincoln Ave & Belmont Ave', 15)
fix_dpcapacity('Lincoln Park Conservatory', 13)
fix_dpcapacity('Michigan Ave & 18th St', 19)
fix_dpcapacity('Desplaines St & Randolph St', 22)

# %%
fix_dpcapacity('Clinton St & Washington Blvd', 29)
fix_dpcapacity('Financial Pl & Ida B Wells Dr', 30)
fix_dpcapacity('Morgan St & 31st St', 6)
fix_dpcapacity('Western Ave & Fillmore St', 10)

# %%
fix_dpcapacity('LaSalle St & Jackson Blvd', 35)
fix_dpcapacity('Wood St & 35th St', 8)
fix_dpcapacity('Wabash Ave & 9th St', 17)
fix_dpcapacity('Halsted St & Polk St', 19)
fix_dpcapacity('Dearborn St & Monroe St', 38)
fix_dpcapacity('Clark St & Newport St', 12)
fix_dpcapacity('Broadway & Barry Ave', 18)
fix_dpcapacity('Orleans St & Elm St', 15)
fix_dpcapacity('Halsted St & 35th St', 11)

# %%
fix_dpcapacity('Campbell Ave & North Ave', 15)
fix_dpcapacity('Clark St & Montrose Ave', 16)
fix_dpcapacity('Michigan Ave & 14th St', 16)
fix_dpcapacity('Public Rack - Ashland Ave & 63rd St', 1)
fix_dpcapacity('Halsted St & Maxwell St', 12)
fix_dpcapacity('Clybourn Ave & Division St', 12)
fix_dpcapacity('Cherry Ave & Blackhawk St', 12)

# %%
fix_dpcapacity('Ada St & Washington Blvd', 15)
fix_dpcapacity('N Carpenter St & W Lake St', 6)
fix_dpcapacity('Damen Ave & Pierce Ave', 21)
fix_dpcapacity('Racine Ave & Belmont Ave', 14)
fix_dpcapacity('Racine Ave & Washington Blvd', 11)
fix_dpcapacity('Desplaines St & Kinzie St', 24)

# %%
fix_dpcapacity('N Shore Channel Trail & Argyle St', 9)
fix_dpcapacity('Lake Park Ave & 53rd St', 14)
fix_dpcapacity('Ashland Ave & Grand Ave', 13)
fix_dpcapacity('Carpenter St & Huron St', 17)
fix_dpcapacity('Spaulding Ave & Armitage Ave', 14)
fix_dpcapacity('Clark St & Armitage Ave', 28)
fix_dpcapacity('Michigan Ave & Oak St', 2)
fix_dpcapacity('Larrabee St & Kingsbury St', 43)
fix_dpcapacity('Sheridan Rd & Montrose Ave', 22)

# %%
fix_dpcapacity('Indiana Ave & Roosevelt Rd', 37)
fix_dpcapacity('Canal St & Adams St', 47)
fix_dpcapacity('Broadway & Waveland Ave', 15)
fix_dpcapacity('Manor Ave & Leland Ave', 11)
fix_dpcapacity('Walsh Park', 22)
fix_dpcapacity('Clark St & Wellington Ave', 14)
fix_dpcapacity('Claremont Ave & Hirsch St', 11)
fix_dpcapacity('Rush St & Hubbard St', 23)

# %%
fix_dpcapacity('State St & Van Buren St', 27)
fix_dpcapacity('South Shore Dr & 74th St', 11)
fix_dpcapacity('Paulina Ave & North Ave', 11)
fix_dpcapacity('Damen Ave & Thomas St (Augusta Blvd)', 22)
fix_dpcapacity('Dearborn Pkwy & Delaware Pl', 13)
fix_dpcapacity('Lincoln Ave & Addison St', 19)
fix_dpcapacity('Racine Ave & 35th St', 12)
fix_dpcapacity('Calumet Ave & 33rd St', 8)

# %%
fix_dpcapacity('McClurg Ct & Erie St', 30)
fix_dpcapacity('Sheridan Rd & Columbia Ave', 15)
fix_dpcapacity('Clark St & Berwyn Ave', 18)
fix_dpcapacity('Clark St & Lincoln Ave', 21)
fix_dpcapacity('Greenview Ave & Fullerton Ave', 15)
fix_dpcapacity('Sheridan Rd & Buena Ave', 16)
fix_dpcapacity('Damen Ave & Cortland St', 17)

# %%
fix_dpcapacity('California Ave & 21st St', 14)
fix_dpcapacity('Pine Grove Ave & Irving Park Rd', 15)
fix_dpcapacity('Glenwood Ave & Morse Ave', 15)
fix_dpcapacity('Streeter Dr & Grand Ave', 44)
fix_dpcapacity('Damen Ave & Pershing Rd', 11)
fix_dpcapacity('Canal St & Taylor St', 12)
fix_dpcapacity('Throop St & Taylor St', 15)
fix_dpcapacity('Canal St & Taylor St', 12)
fix_dpcapacity('Wabash Ave & 16th St', 37)
fix_dpcapacity('Leavitt St & Chicago Ave', 19)

# %%
fix_dpcapacity('Dorchester Ave & 63rd St', 11)
fix_dpcapacity('Clark St & Grace St', 23)
fix_dpcapacity('Stony Island Ave & 64th St', 11)
fix_dpcapacity('MLK Jr Dr & 47th St', 11)
fix_dpcapacity('Emerald Ave & 28th St', 14)
fix_dpcapacity('Sheffield Ave & Kingsbury St', 14)
fix_dpcapacity('Clark St & Randolph St', 42)
fix_dpcapacity('Clark St & Chicago Ave', 19)

# %%
fix_dpcapacity('Franklin St & Illinois St', 8)
fix_dpcapacity('Aberdeen St & Monroe St', 18)
fix_dpcapacity('State St & 19th St', 14)
fix_dpcapacity('May St & Taylor St', 15)
fix_dpcapacity('Clarendon Ave & Junior Ter', 23)

# %%
# Prairie Ave & Garfield Blvd is a 'Public Rack -'

fix_dpcapacity('Prairie Ave & Garfield Blvd', 1)
fix_dpcapacity('Franklin St & Adams St', 15)
fix_dpcapacity('Blackstone Ave & Hyde Park Blvd', 18)
fix_dpcapacity('Shedd Aquarium', 55)
fix_dpcapacity('MLK Jr Dr & 29th St', 16)
fix_dpcapacity('Sheridan Rd & Irving Park Rd', 27)
fix_dpcapacity('Hampden Ct & Diversey Ave', 8)
fix_dpcapacity('Lincoln Ave & Waveland Ave', 13)

# %%
fix_dpcapacity('Sheffield Ave & Wrightwood Ave', 31)
fix_dpcapacity('Kingsbury St & Erie St', 23)
fix_dpcapacity('Shields Ave & 28th Pl', 10)
fix_dpcapacity('Stony Island Ave & 75th St', 11)
fix_dpcapacity('Wentworth Ave & Cermak Rd', 14)
fix_dpcapacity('Wilton Ave & Diversey Pkwy*', 34)
fix_dpcapacity('Normal Ave & Archer Ave', 9)
fix_dpcapacity('W Oakdale Ave & N Broadway', 5)

# %%
fix_dpcapacity('Wood St & Augusta Blvd', 13)
fix_dpcapacity('Larrabee St & Division St', 23)
fix_dpcapacity('Ravenswood Ave & Berteau Ave', 14)
fix_dpcapacity('Lincoln Ave & Roscoe St*', 13)
fix_dpcapacity('Dearborn St & Erie St', 22)

# %%
fix_dpcapacity('Francisco Ave & Foster Ave', 15)
fix_dpcapacity('Clinton St & 18th St', 15)
fix_dpcapacity('Michigan Ave & Madison St', 17)
fix_dpcapacity('Wabash Ave & Adams St', 23)
fix_dpcapacity('Washtenaw Ave & Polk St', 9)
fix_dpcapacity('Albany Ave & Douglas Blvd', 9)
fix_dpcapacity('Damen Ave & Clybourn Ave', 15)

# %%
fix_dpcapacity('Broadway & Wilson - Truman College', 23)
fix_dpcapacity('Woodlawn Ave & Lake Park Ave', 15)
fix_dpcapacity('Wells St & Walton St', 18)
fix_dpcapacity('Winthrop Ave & Lawrence Ave', 14)
fix_dpcapacity('Albany Ave & Bloomingdale Ave', 14)
fix_dpcapacity('Stockton Dr & Wrightwood Ave', 13)

# %%
fix_dpcapacity('Larrabee St & Oak St', 14)
fix_dpcapacity('Cityfront Plaza Dr & Pioneer Ct', 29)
fix_dpcapacity('DuSable Lake Shore Dr & Belmont Ave', 17)
fix_dpcapacity('Wabash Ave & Roosevelt Rd', 20)
fix_dpcapacity('Green St & Washington Blvd', 11)
fix_dpcapacity('Dorchester Ave & 49th St', 15)
fix_dpcapacity('Kedzie Ave & Milwaukee Ave', 35)
fix_dpcapacity('Damen Ave & Madison St', 13)

# %%
fix_dpcapacity('Clarendon Ave & Leland Ave', 14)
fix_dpcapacity('Cannon Dr & Fullerton Ave', 15)
fix_dpcapacity('Wilton Ave & Diversey Pkwy', 34)
fix_dpcapacity('Loomis St & Lexington St', 20)
fix_dpcapacity('Whipple/Irving Park', 8)
fix_dpcapacity('Prairie Ave & 43rd St', 14)

# %%
fix_dpcapacity('Princeton Ave & 47th St', 11)
fix_dpcapacity('Public Rack - Monticello Ave & Belmont Ave', 2)
fix_dpcapacity('Burnham Harbor', 22)
fix_dpcapacity('Ashland Ave & Grace St', 15)
fix_dpcapacity('Sedgwick St & Webster Ave', 15)
fix_dpcapacity('Southport Ave & Belmont Ave', 15)
fix_dpcapacity('Clark St & Schiller St', 18)
fix_dpcapacity('Milwaukee Ave & Fullerton Ave', 9)
fix_dpcapacity('Stony Island Ave & 90th St', 15)

# %%
fix_dpcapacity('Mies van der Rohe Way & Chestnut St', 17)
fix_dpcapacity('Sheffield Ave & Fullerton Ave', 25)
fix_dpcapacity('Honore St & Division St', 23)
fix_dpcapacity('Wolcott (Ravenswood) Ave & Montrose Ave', 15)
fix_dpcapacity('Clark St & North Ave', 15)
fix_dpcapacity('Wabash Ave & Cermak Rd', 10)

# %%
fix_dpcapacity('California Ave & Montrose Ave', 15)
fix_dpcapacity('Ashland Ave & Wrightwood Ave', 14)
fix_dpcapacity('Paulina St & 18th St', 14)
fix_dpcapacity('State St & 33rd St', 12)
fix_dpcapacity('Southport Ave & Clybourn Ave', 15)
fix_dpcapacity('Clarendon Ave & Gordon Ter', 15)
fix_dpcapacity('Canal St & Jackson Blvd', 50)

# %%
fix_dpcapacity('Michigan Ave & Ida B Wells Dr', 14)
fix_dpcapacity('Dearborn St & Van Buren St', 14)
fix_dpcapacity('Damen Ave & Melrose Ave', 15)
fix_dpcapacity('Michigan Ave & Washington St', 40)
fix_dpcapacity('Morgan St & 18th St', 15)
fix_dpcapacity('Seeley Ave & Roscoe St', 11)
fix_dpcapacity('Peoria St & Jackson Blvd', 19)

# %%
fix_dpcapacity('Francisco Ave & Bloomingdale Ave', 8)
fix_dpcapacity('Green St & Madison Ave*', 15)
fix_dpcapacity('Drake Ave & Addison St', 15)
fix_dpcapacity('Aberdeen St & Jackson Blvd', 21)
fix_dpcapacity('LaSalle St & Adams St', 14)
fix_dpcapacity('LaSalle St & Illinois St', 27)

# %%
fix_dpcapacity('Michigan Ave & 8th St', 43)
fix_dpcapacity('Public Rack - Avers Ave & Irving Park Rd', 2)
fix_dpcapacity('Southport Ave & Wrightwood Ave', 15)
fix_dpcapacity('Michigan Ave & Jackson Blvd', 23)
fix_dpcapacity('Wells St & Elm St', 21)
fix_dpcapacity('Damen Ave & Leland Ave', 13)

# %%
fix_dpcapacity('Monticello Ave & Irving Park Rd', 15)
fix_dpcapacity('Orleans St & Merchandise Mart Plaza', 35)
fix_dpcapacity('Winchester Ave & Elston Ave', 14)
fix_dpcapacity('Sawyer Ave & Irving Park Rd', 14)
fix_dpcapacity('Lake Park Ave & 35th St', 17)
fix_dpcapacity('St. Louis Ave & Fullerton Ave', 15)
fix_dpcapacity('Leavitt St & North Ave', 15)

# %%
# - charging needs to be removed from 'Bissell St & Armitage Ave* - Charging'

fix_dpcapacity('California Ave & Fletcher St', 19)
fix_dpcapacity('Larrabee St & Armitage Ave', 14)
fix_dpcapacity('Damen Ave & Foster Ave', 14)
fix_dpcapacity('Southport Ave & Roscoe St', 17)
fix_dpcapacity('Kimball Ave & Belmont Ave', 15)
fix_dpcapacity('Ashland Ave & Belle Plaine Ave', 11)
fix_dpcapacity('Bissell St & Armitage Ave* - Charging', 14)
fix_dpcapacity('Damen Ave & Wellington Ave', 15)
fix_dpcapacity('California Ave & Francis Pl', 15)

# %%
fix_dpcapacity('Milwaukee Ave & Wabansia Ave', 12)
fix_dpcapacity('Canal St & Madison St', 25)
fix_dpcapacity('Rush St & Superior St', 22)
fix_dpcapacity('Field Museum', 54)

# %%
fix_dpcapacity('Public Rack - Halsted St & 64th St', 2)
fix_dpcapacity('Western Ave & Walton St', 23)
fix_dpcapacity('Artesian Ave & Hubbard St', 27)
fix_dpcapacity('Racine Ave & Fullerton Ave', 19)
fix_dpcapacity('Sheridan Rd & Lawrence Ave', 19)
fix_dpcapacity('Blue Island Ave & 18th St', 15)

# %%
fix_dpcapacity('Wells St & Hubbard St', 31)
fix_dpcapacity('Broadway & Ridge Ave', 14)
fix_dpcapacity('Jefferson St & Monroe St', 15)
fix_dpcapacity('Halsted St & 37th St', 8)
fix_dpcapacity('Damen Ave & Cullerton St', 10)
fix_dpcapacity('Wood St & Hubbard St', 19)
fix_dpcapacity('Public Rack - Jensen Park', 1)
fix_dpcapacity('St Louis Ave & 59th St', 9)

# %%
fix_dpcapacity('Halsted St & North Branch St', 14)
fix_dpcapacity('Lincoln Ave & Winona St', 15)
fix_dpcapacity('Leavitt St & Division St', 14)
fix_dpcapacity('Indiana Ave & 31st St', 10)
fix_dpcapacity('Wentworth Ave & 35th St', 10)
fix_dpcapacity('Elston Ave & Wabansia Ave', 21)
fix_dpcapacity('Rockwell St & Fletcher St', 9)
fix_dpcapacity('Canal St & Harrison St', 13)

# %%
fix_dpcapacity('Kedzie Ave & George St', 8)
fix_dpcapacity('Narragansett & Irving Park', 11)
fix_dpcapacity('Central Ave & Roscoe St', 9)
fix_dpcapacity('Archer Ave & 43rd St', 8)
fix_dpcapacity('Broadway & Argyle St', 19)
fix_dpcapacity('Calumet Ave & 35th St', 15)
fix_dpcapacity('Western Ave & Division St', 23)
fix_dpcapacity('Orleans St & Hubbard St', 11)

# %%
fix_dpcapacity('New St & Illinois St', 25)
fix_dpcapacity('Ravenswood Ave & Irving Park Rd', 17)
fix_dpcapacity('Bosworth Ave & Howard St', 11)
fix_dpcapacity('Wolcott Ave & Polk St', 23)
fix_dpcapacity('Cottage Grove Ave & 67th St', 11)

# %%
fix_dpcapacity('Museum of Science and Industry', 27)
fix_dpcapacity('Public Rack - Western Blvd & 49th St', 1)
fix_dpcapacity('Washtenaw Ave & Madison St', 8)
fix_dpcapacity('Milwaukee Ave & Grand Ave', 19)
fix_dpcapacity('Conservatory Dr & Lake St', 11)
fix_dpcapacity('Western Ave & 24th St', 7)

# %%
fix_dpcapacity('Western Ave & 21st St', 14)
fix_dpcapacity('Western Ave & Monroe St', 15)
fix_dpcapacity('Public Rack - State ST & 42nd St', 1)
fix_dpcapacity('Public Rack - Walden Pkwy & 99th St', 1)
fix_dpcapacity('Lincoln Ave & Sunnyside Ave', 15)
fix_dpcapacity('Wentworth Ave & 24th St', 14)
fix_dpcapacity('Ashland Ave & Lake St', 14)
fix_dpcapacity('State St & Kinzie St', 29)
fix_dpcapacity('Canal St & Monroe St', 25)
fix_dpcapacity('Lincoln Ave & Sunnyside Ave', 15)

# %%
fix_dpcapacity('Dearborn St & Adams St', 15)
fix_dpcapacity('Damen Ave & Walnut (Lake) St', 14)
fix_dpcapacity('Public Rack - South Shore Dr & 71st St', 2)
fix_dpcapacity('Talman Ave & Addison St', 14)
fix_dpcapacity('Shields Ave & 43rd St', 11)
fix_dpcapacity('Wallace St & 35th St', 15)
fix_dpcapacity('Ashland Ave & Archer Ave', 11)
fix_dpcapacity('North Ave & New England Ave', 9)
fix_dpcapacity('Public Rack - Kostner Ave & Armitage Ave', 1)

# %%
fix_dpcapacity('Eastlake Ter & Rogers Ave', 14)
fix_dpcapacity('Racine Ave & 15th St', 15)
fix_dpcapacity('California Ave & Lake St', 11)
fix_dpcapacity('Public Rack - Avondale Ave & Addison St', 4)
fix_dpcapacity('Indiana Ave & 26th St', 14)
fix_dpcapacity('McClurg Ct & Ohio St', 18)
fix_dpcapacity('Wood St & Taylor St', 20)
fix_dpcapacity('Clark St & Bryn Mawr Ave', 15)

# %%
fix_dpcapacity('Kedzie Ave & Palmer Ct', 12)
fix_dpcapacity('Oakley Ave & Irving Park Rd', 15)
fix_dpcapacity('Lakefront Trail & Wilson Ave', 15)
fix_dpcapacity('Cottage Grove Ave & 43rd St', 11)
fix_dpcapacity('Stetson Ave & South Water St', 18)
fix_dpcapacity('Public Rack - Wabash Ave & 87th St', 1)
fix_dpcapacity('Kosciuszko Park', 14)
fix_dpcapacity('Washtenaw Ave & Ogden Ave', 15)

# %%
fix_dpcapacity('Ellis Ave & 55th St', 19)
fix_dpcapacity('W Armitage Ave & N Sheffield Ave', 8)
fix_dpcapacity('Western Ave & Congress Pkwy', 19)
fix_dpcapacity('Avondale Ave & Irving Park Rd', 19)
fix_dpcapacity('Albany Ave & Belmont Ave', 8)
fix_dpcapacity('Halsted St & 21st St', 8)
fix_dpcapacity('Warren Park West', 11)
fix_dpcapacity('Loomis St & Jackson Blvd', 17)
fix_dpcapacity('Fairbanks St & Superior St', 11)

# %%
fix_dpcapacity('Campbell Ave & Irving Park Rd', 9)
fix_dpcapacity('Greenwood Ave & 47th St', 15)
fix_dpcapacity('Wentworth Ave & 63rd St', 11)
fix_dpcapacity('Damen Ave & Wabansia Ave', 6)
fix_dpcapacity('Sacramento Blvd & Franklin Blvd', 11)
fix_dpcapacity('Milwaukee Ave & Rockwell St', 19)
fix_dpcapacity('Field Blvd & South Water St', 19)
fix_dpcapacity('N Damen Ave & W Chicago Ave', 6)
fix_dpcapacity('Loomis St & Archer Ave', 10)

# %%
fix_dpcapacity('Rockwell St & Eastwood Ave', 13)
fix_dpcapacity('Kedzie Ave & 52nd St', 9)
fix_dpcapacity('Public Rack - Central Park Ave & Ogden Ave', 3)
fix_dpcapacity('Hoyne Ave & Balmoral Ave', 15)
fix_dpcapacity('State St & Harrison St', 22)
fix_dpcapacity('Stave St & Armitage Ave', 10)
fix_dpcapacity('Wabash Ave & Wacker Pl', 16)
fix_dpcapacity('Hoyne Ave & Balmoral Ave', 15)
fix_dpcapacity('California & 16th St', 9)

# %%
fix_dpcapacity('Rhodes Ave & 32nd St', 7)
fix_dpcapacity('Ellis Ave & 53rd St', 11)
fix_dpcapacity('Public Rack - California Ave & Cortez St', 2)
fix_dpcapacity('Marshfield Ave & 44th St', 11)
fix_dpcapacity('Dayton St & North Ave', 19)
fix_dpcapacity('Green St & Randolph St*', 10)
fix_dpcapacity('Lincoln Ave & Fullerton Ave', 15)
fix_dpcapacity('Leavitt St & Archer Ave', 15)

# %%
fix_dpcapacity('Seeley Ave & Garfield Blvd', 11)
fix_dpcapacity('Cornell Ave & Hyde Park Blvd', 17)
fix_dpcapacity('Washtenaw Ave & Lawrence Ave', 15)
fix_dpcapacity('Hoyne Ave & 47th St', 11)
fix_dpcapacity('Budlong Woods Library', 11)
fix_dpcapacity('Halsted St & Dickens Ave', 23)
fix_dpcapacity('Greenview Ave & Jarvis Ave', 19)

# %%
fix_dpcapacity('Public Rack - Lowell Ave & Elston Ave', 1)
fix_dpcapacity('Lake Park Ave & 56th St', 19)
fix_dpcapacity('Kildare Ave & Montrose Ave', 15)
fix_dpcapacity('Public Rack - Clyde Ave & 87th St', 3)
fix_dpcapacity('Halsted St & 51st St', 11)
fix_dpcapacity('Western Ave & Roscoe St', 11)
fix_dpcapacity('California Ave & Milwaukee Ave', 11)
fix_dpcapacity('Wood St & Chicago Ave', 12)
fix_dpcapacity('Halsted St & Archer Ave', 15)

# %%
fix_dpcapacity('Winchester (Ravenswood) Ave & Balmoral Ave', 15)
fix_dpcapacity('Harper Ave & 59th St', 15)
fix_dpcapacity('Ellis Ave & 58th St', 17)
fix_dpcapacity('Avenue O & 134th St', 15)
fix_dpcapacity('California Ave & Division St', 19)
fix_dpcapacity('Morgan Ave & 14th Pl', 15)

# %%
fix_dpcapacity('Public Rack - Woodlawn Ave & 63rd St N', 1)
fix_dpcapacity('Public Rack - N Narragansett Ave & Grand Ave', 1)
fix_dpcapacity('Public Rack - Prairie Ave & 47th St', 1)
fix_dpcapacity('Public Rack - Christiana Ave & Lawrence Ave', 2)
fix_dpcapacity('Spaulding Ave & 16th St', 9)
fix_dpcapacity('Richmond St & Lincoln Ave', 5)
fix_dpcapacity('Broadway & Berwyn Ave', 15)
fix_dpcapacity('Public Rack - Racine Ave & 109th Pl', 5)
fix_dpcapacity('Western Ave & Grace St', 9)
fix_dpcapacity('Public Rack - Woodlawn Ave & 63rd St S', 1)

# %%
fix_dpcapacity('Avers Ave & Belmont Ave', 11)
fix_dpcapacity('Broadway & Thorndale Ave', 18)
fix_dpcapacity('Public Rack - Karlov Ave & Milwaukee Ave', 1)
fix_dpcapacity('Vernon Ave & 75th St', 11)
fix_dpcapacity('Ellis Ave & 60th St', 18)
fix_dpcapacity('Leavitt St & Lawrence Ave', 19)
fix_dpcapacity('Altgeld Gardens', 13)
fix_dpcapacity('Elizabeth St & Fulton St', 15)

# %%
fix_dpcapacity('Narragansett Ave & School St', 8)
fix_dpcapacity('South Shore Dr & 67th St', 15)
fix_dpcapacity('Michigan Ave & 71st St', 7)
fix_dpcapacity('MLK Jr Dr & 56th St', 10)
fix_dpcapacity('Cicero Ave & Grace St', 5)
fix_dpcapacity('Sangamon St & Lake St', 23)
fix_dpcapacity('Pulaski Rd & 51st St', 10)
fix_dpcapacity('Public Rack - Ashland Ave & 71st St', 2)
fix_dpcapacity('Public Rack - Kedzie Ave & 64th St - SW', 2)

# %%
fix_dpcapacity('Kedzie Ave & Harrison St', 10)
fix_dpcapacity('Bradley Park', 1)
fix_dpcapacity('Troy St & North Ave', 14)
fix_dpcapacity('MLK Jr Dr & Pershing Rd', 15)
fix_dpcapacity('Cottage Grove Ave & Oakwood Blvd', 15)
fix_dpcapacity('Shields Ave & 31st St', 15)
fix_dpcapacity('Sedgwick St & North Ave', 19)
fix_dpcapacity('Clifton Ave & Armitage Ave', 10)

# %%
fix_dpcapacity('Broadway & Granville Ave', 22)
fix_dpcapacity('Public Rack - Calumet Ave & 51st St', 1)
fix_dpcapacity('California Ave & North Ave', 10)
fix_dpcapacity('Kedzie Ave & 21st St', 11)
fix_dpcapacity('Public Rack - Pulaski Rd & 44th St', 2)
fix_dpcapacity('Ashland Ave & 13th St', 15)

# %%
fix_dpcapacity('Princeton Ave & Garfield Blvd', 11)
fix_dpcapacity('Clark St & Schreiber Ave', 15)
fix_dpcapacity('Eberhart Ave & 131st St', 2)
fix_dpcapacity('Jeffery Blvd & 71st St', 11)
fix_dpcapacity('Keystone Ave & Fullerton Ave', 10)
fix_dpcapacity('Broadway & Belmont Ave', 19)
fix_dpcapacity('Ashland Ave & Chicago Ave', 14)

# %%
fix_dpcapacity('Damen Ave & Sunnyside Ave', 19)
fix_dpcapacity('Public Rack - Lake Park Ave & 47th St', 1)
fix_dpcapacity('Kedzie Ave & Leland Ave', 15)
fix_dpcapacity('Rockwell St & 63rd St', 6)
fix_dpcapacity('Public Rack - Throop St & 109th Pl', 4)
fix_dpcapacity('Campbell Ave & Montrose Ave', 15)

# %%
fix_dpcapacity('Halsted St & 59th St', 11)
fix_dpcapacity('Morgan St & Pershing Rd', 4)
fix_dpcapacity('Phillips Ave & 79th St', 11)
fix_dpcapacity('Elston Ave & Cortland St', 21)
fix_dpcapacity('Clinton St & Tilden St', 21)
fix_dpcapacity('Springfield Ave & 47th St', 9)
fix_dpcapacity('Sacramento Blvd & Addison St', 9)
fix_dpcapacity('Clinton St & Polk St', 15)
fix_dpcapacity('Sacramento Blvd & Addison St', 9)

# %%
fix_dpcapacity('Clinton St & Jackson Blvd', 31)
fix_dpcapacity('California Ave & Byron St', 19)
fix_dpcapacity('Pulaski Rd & Eddy St', 11)
fix_dpcapacity('Komensky Ave & 55th St', 9)
fix_dpcapacity('Public Rack - Halsted St & 95th St - SE', 3)

# %%
fix_dpcapacity('MLK Jr Dr & 63rd St', 11)
fix_dpcapacity('Clark St & 9th St (AMLI)', 14)
fix_dpcapacity('Ashland Ave & Wellington Ave', 19)
fix_dpcapacity('Paulina St & Montrose Ave', 15)
fix_dpcapacity('Cottage Grove Ave & 51st St', 14)
fix_dpcapacity('Troy St & Elston Ave', 15)

# %%
fix_dpcapacity('Clark St & Leland Ave', 19)
fix_dpcapacity('N Paulina St & Lincoln Ave', 6)
fix_dpcapacity('McCormick Place', 26)
fix_dpcapacity('Malcolm X College', 18)

# %%
fix_dpcapacity('Greenview Ave & Diversey Pkwy', 14)
fix_dpcapacity('Wells St & 19th St', 9)
fix_dpcapacity('Public Rack - Jonathan Y Scammon Public School', 1)
fix_dpcapacity('Humboldt Blvd & Armitage Ave', 19)
fix_dpcapacity('Kedzie Ave & Lake St', 15)
fix_dpcapacity('Racine Ave & Garfield Blvd', 11)
fix_dpcapacity('Public Rack - Hoyne Ave & 110th Pl', 2)
fix_dpcapacity('Albany Ave & 16th St', 9)

# %%
fix_dpcapacity('May St & Cullerton St', 11)
fix_dpcapacity('Jeffery Blvd & 76th St', 11)
fix_dpcapacity('W Washington Blvd & N Peoria St', 6)
fix_dpcapacity('Halsted & 63rd - Kennedy-King', 1)
fix_dpcapacity('May St & Cullerton St', 11)
fix_dpcapacity('Orange & Addison', 9)
fix_dpcapacity('Public Rack - Lawndale Ave & Diversey Ave', 1)
fix_dpcapacity('Sayre & Diversey', 8)
fix_dpcapacity('Ashland Ave & 66th St', 7)
fix_dpcapacity('Ashland Ave & 74th St', 15)

# %%
fix_dpcapacity('Public Rack - Hamlin Ave & Montrose Ave', 3)
fix_dpcapacity('Halsted St & Wrightwood Ave', 15)
fix_dpcapacity('Kedzie Ave & Foster Ave', 11)
fix_dpcapacity('Clark St & Drummond Pl', 23)
fix_dpcapacity('Southport Ave & Irving Park Rd', 15)
fix_dpcapacity('Lavergne Ave & 46th St', 9)
fix_dpcapacity('Central Ave & Madison St', 11)
fix_dpcapacity('Yates Blvd & 75th St', 10)
fix_dpcapacity('Nordica & Medill', 9)

# %%
fix_dpcapacity('Bernard St & Elston Ave', 11)
fix_dpcapacity('Ashland Ave & McDowell Ave', 10)
fix_dpcapacity('Western Ave & Leland Ave', 18)
fix_dpcapacity('Public Rack - Harper Ave & 63rd St', 6)
fix_dpcapacity('Public Rack - East End Ave & 87th St', 1)
fix_dpcapacity('Vernon Ave & 107th St', 15)
fix_dpcapacity('Stewart Ave & 63rd St', 11)

# %%
# change Sheffield Ave & Wellington Ave to 'N Sheffield Ave & W Wellington Ave'

fix_dpcapacity('Clark St & Elm St', 36)
fix_dpcapacity('Sheffield Ave & Wellington Ave', 6)
fix_dpcapacity('Racine Ave & 13th St', 14)
fix_dpcapacity('Albany Ave & 26th St', 11)
fix_dpcapacity('Chicago State University', 23)

# %%
fix_dpcapacity('Central Park Ave & Elbridge Ave', 14)
fix_dpcapacity('Ravenswood Ave & Lawrence Ave', 46)
fix_dpcapacity('Paulina St & Flournoy St', 29)
fix_dpcapacity('Columbus Dr & Randolph St', 54)
fix_dpcapacity('Western Ave & Lunt Ave', 15)
fix_dpcapacity('Sacramento Ave & Pershing Rd', 9)
fix_dpcapacity('Kenosha & Wellington', 6)
fix_dpcapacity('Halsted St & 47th Pl', 11)

# %%
fix_dpcapacity('University Ave & 57th St', 30)
fix_dpcapacity('Ashland Ave & Augusta Blvd', 14)
fix_dpcapacity('Perry Ave & 69th St', 11)
fix_dpcapacity('Marquette Ave & 89th St', 15)
fix_dpcapacity('California Ave & Marquette Rd', 10)
fix_dpcapacity('Ridge Blvd & Howard St', 11)
fix_dpcapacity('Public Rack - Champlain Ave & 65th St', 2)
fix_dpcapacity('Lawndale Ave & 111th St', 15)
fix_dpcapacity('Lincoln Ave & Balmoral Ave', 8)

# %%
fix_dpcapacity('Cottage Grove Ave & 71st St', 10)
fix_dpcapacity('Public Rack - Eberhart Ave & 61st St', 1)
fix_dpcapacity('Albany Ave & Montrose Ave', 11)
fix_dpcapacity('Sheridan Rd & Greenleaf Ave', 15)

# %%
fix_dpcapacity('Spaulding Ave & Division St', 11)
fix_dpcapacity('Laflin St & Cullerton St', 15)
fix_dpcapacity('Burling St & Diversey Pkwy', 19)
fix_dpcapacity('Public Rack - Kedzie Ave & Chicago Ave', 1)
fix_dpcapacity('Public Rack - Robert Fulton Elementary School', 2)
fix_dpcapacity('Kilbourn Ave & Irving Park Rd',11 )
fix_dpcapacity('Sedgwick St & Schiller St', 15)
fix_dpcapacity('Eggleston Ave & 69th St', 11)
fix_dpcapacity('Wolcott Ave & Fargo Ave', 11)

# %%
fix_dpcapacity('Smith Park', 15)
fix_dpcapacity('Public Rack - Rockwell & Division', 1)
fix_dpcapacity('Elston Ave & Henderson St', 9)
fix_dpcapacity('Public Rack - Nagle Ave & Belmont Ave', 4)
fix_dpcapacity('Elston Ave & George St', 9)
fix_dpcapacity('Burnham Greenway & 105th St', 11)
fix_dpcapacity('Michigan Ave & 114th St', 15)
fix_dpcapacity('Public Rack - Spaulding Ave & Bryn Mawr Ave', 2)
fix_dpcapacity('Western Ave & 111th St', 23)
fix_dpcapacity('Public Rack - King Dr & Oakwood Blvd', 1)

# %%
fix_dpcapacity('Western Ave & Berteau Ave', 5)
fix_dpcapacity('Drake Ave & Montrose Ave', 14)
fix_dpcapacity('Laramie Ave & Gladys Ave', 10)
fix_dpcapacity('Wood St & Webster Ave', 19)
fix_dpcapacity('Delano Ct & Roosevelt Rd', 17)
fix_dpcapacity('Public Rack - Kimbark Ave & 67th St', 2)
fix_dpcapacity('Eberhart Ave & 91st St', 15)
fix_dpcapacity('Stony Island Ave & 71st St', 11)
fix_dpcapacity('Narragansett & McLean', 9)
fix_dpcapacity('Kedzie Ave & Bryn Mawr Ave', 15)

# %%
fix_dpcapacity('Kedzie Ave & 48th Pl', 12)
fix_dpcapacity('Keystone Ave & Montrose Ave', 11)
fix_dpcapacity('Stewart Ave & 83rd St', 15)
fix_dpcapacity('Richmond St & Diversey Ave', 15)
fix_dpcapacity('Cottage Grove Ave & 78th St', 10)
fix_dpcapacity('Sheridan Rd & Loyola Ave', 22)

# %%
fix_dpcapacity('Central Park Ave & Bloomingdale Ave', 11)
fix_dpcapacity('Chicago Ave & Washington St', 14)
fix_dpcapacity('Logan Blvd & Elston Ave', 26)
fix_dpcapacity('N Southport Ave & W Newport Ave', 8)
fix_dpcapacity('Cottage Grove Ave & 47th St', 15)
fix_dpcapacity('Commercial Ave & 130th St', 15)
fix_dpcapacity('Hegewisch Metra Station', 13)

# %%
fix_dpcapacity('Public Rack - Pulaski Rd & Armitage Ave', 2)
fix_dpcapacity('Stony Island Ave & South Chicago Ave', 11)
fix_dpcapacity('Western Blvd & 48th Pl', 11)
fix_dpcapacity('Public Rack - Spaulding Ave & Evergreen Ave', 2)
fix_dpcapacity('Public Rack - Christiana Ave & Belmont Ave', 6)
fix_dpcapacity('Paulina St & Howard St', 19)
fix_dpcapacity('Baltimore Ave & 87th St', 14)
fix_dpcapacity('South Chicago Ave & 83rd St', 10)
fix_dpcapacity('Phillips Ave & 83rd St', 11)
fix_dpcapacity('South Chicago Ave & 83rd St', 10)

# %%
fix_dpcapacity('Public Rack - Greenwood Ave & Lake Park Ave', 1)
fix_dpcapacity('Fairfield Ave & Roosevelt Rd', 11)
fix_dpcapacity('2112 W Peterson Ave', 11)
fix_dpcapacity('Francisco Ave & Montrose Ave', 9)
fix_dpcapacity('Sheridan Rd & Noyes St (NU)', 13)
fix_dpcapacity('63rd St Beach', 10)
fix_dpcapacity('Public Rack - East End Ave & 75th St', 2)
fix_dpcapacity('California Ave & 23rd Pl', 11)
fix_dpcapacity('Kenneth Ave & 50th St', 6)
fix_dpcapacity('Kedzie Ave & Roosevelt Rd', 11)

# %%
fix_dpcapacity('Benson Ave & Church St', 13)
fix_dpcapacity('Whipple St & Roosevelt Rd', 8)
fix_dpcapacity('Torrence Ave & 126th Pl', 15)
fix_dpcapacity('Ashland Ave & Garfield Blvd', 11)
fix_dpcapacity('Public Rack - Kedzie Ave & Argyle St', 2)
fix_dpcapacity('MTV Hubbard St', 6)
fix_dpcapacity('Western Ave & Granville Ave', 11)
fix_dpcapacity('Monticello Ave & Chicago Ave', 6)
fix_dpcapacity('California Ave & Winona St', 6)
fix_dpcapacity('Whipple St & Roosevelt Rd', 8)

# %%
fix_dpcapacity('Clark St & Elmdale Ave', 15)
fix_dpcapacity('Woodlawn Ave & 55th St', 19)
fix_dpcapacity('Glenwood Ave & Touhy Ave', 15)
fix_dpcapacity('Austin Blvd & Chicago Ave', 7)
fix_dpcapacity('Woodlawn Ave & 55th St', 19)
fix_dpcapacity('Virginia Ave & Catalpa Ave', 9)
fix_dpcapacity('Damen Ave & Coulter St', 7)
fix_dpcapacity('Central Park Ave & Ohio St', 9)
fix_dpcapacity('Public Rack - Ashland Ave & 76th St', 2)
fix_dpcapacity('Milwaukee Ave & Cuyler Ave', 11)
fix_dpcapacity('Ping Tom Park (East)', 6)

# %% [markdown]
# ### Now to check end_dpcapacity for any missed values.

# %%
fix_dpcapacity('Central St & Girard Ave', 14)
fix_dpcapacity('Kildare & Cermak', 9)
fix_dpcapacity('Public Rack - Campbell Ave & Pratt Blvd', 1)
fix_dpcapacity('Public Rack - Hiawatha Park', 1)
fix_dpcapacity('Public Rack - Sacramento Ave & Devon Ave', 1)
fix_dpcapacity('Lawndale Ave & 30th St', 12)
fix_dpcapacity('Public Rack - Bishop St & 81st St', 2)
fix_dpcapacity('Oakley Ave & Touhy Ave', 10)

# %%
fix_dpcapacity('Public Rack - Champlain Ave & 134th St', 2)
fix_dpcapacity('Clark St & Lunt Ave', 19)
fix_dpcapacity('University Library (NU)', 14)
fix_dpcapacity('Summit Ave & 86th St', 15)
fix_dpcapacity('St. Louis Ave & Balmoral Ave', 15)

# %%
fix_dpcapacity('Pulaski & Ann Lurie Pl', 8)
fix_dpcapacity('Eggleston Ave & 92nd St', 13)
fix_dpcapacity('Commercial Ave & 83rd St', 11)
fix_dpcapacity('Western Ave & Howard St', 15)
fix_dpcapacity('Damen Ave & 59th St', 11)
fix_dpcapacity('Public Rack - Milwaukee Ave & Haussen Ct', 2)
fix_dpcapacity('Cottage Grove Ave & 111th Pl', 15)

# %%
fix_dpcapacity('Public Rack - Spaulding Ave & Foster Ave', 1)
fix_dpcapacity('Washtenaw Ave & Peterson Ave', 9)
fix_dpcapacity('Public Rack - Christiana Ave & Archer Ave', 1)
fix_dpcapacity('Kenton Ave & Madison St', 11)
fix_dpcapacity('Ashland Ave & 78th St', 15)
fix_dpcapacity('Lockwood Ave & Wrightwood Ave', 9)
fix_dpcapacity('Public Rack - Wentworth Ave & 103rd St', 1)
fix_dpcapacity('Halsted St & 96th St', 14)

# %%
fix_dpcapacity('Public Rack - Hamlin Ave & Fullerton Ave', 3)
fix_dpcapacity('Laramie Ave & Madison St', 11)
fix_dpcapacity('Kilbourn & Belden', 9)
fix_dpcapacity('Clark St & Jarvis Ave', 11)
fix_dpcapacity('Public Rack - Karlov Ave & Kamerling Ave', 2)

# %%
fix_dpcapacity('Public Rack - 532 E 43rd St', 1)
fix_dpcapacity('Public Rack - Milwaukee Ave & Diversey Ave', 2)
fix_dpcapacity('Halsted St & 56th St', 11)
fix_dpcapacity('Public Rack - Marquette Rd & 67th St', 2)
fix_dpcapacity('Dodge Ave & Church St', 14)

# %%
fix_dpcapacity('Harlem & Irving Park', 6)
fix_dpcapacity('Throop St & 52nd St', 7)
fix_dpcapacity('Rockwell St & Cermak Rd', 9)
fix_dpcapacity('Stony Island Ave & 82nd St', 11)
fix_dpcapacity('Clark St & Columbia Ave', 15)
fix_dpcapacity('Public Rack - Milwaukee Ave & Addison St', 2)

# %%
fix_dpcapacity('Kedzie Ave & 24th St', 10)
fix_dpcapacity('Indiana Ave & 103rd St', 15)
fix_dpcapacity('Clark St & Touhy Ave', 15)
fix_dpcapacity('State St & 95th St', 15)
fix_dpcapacity('Kilbourn & Roscoe', 9)

# %%
fix_dpcapacity('Rockwell St & Archer Ave', 8)
fix_dpcapacity('Wentworth Ave & 104th St', 15)
fix_dpcapacity('Kilbourn Ave & Milwaukee Ave', 15)
fix_dpcapacity('Public Rack - Midway Orange Line', 1)
fix_dpcapacity('Austin Blvd & Lake St', 11)
fix_dpcapacity('Union Ave & Root St', 11)
fix_dpcapacity('Public Rack - California Ave & Devon Ave - NE', 1)
fix_dpcapacity('Long Ave & Belden Ave', 9)
fix_dpcapacity('Komensky Ave & 31st St', 10)
fix_dpcapacity('Prospect Sq & 91st St', 15)

# %%
fix_dpcapacity('Ashland Ave & 50th St', 11)
fix_dpcapacity('Pulaski Rd & 21st St', 9)
fix_dpcapacity('Public Rack - Western Ave & Jarvis Ave', 1)
fix_dpcapacity('Burnham Greenway & 112th St', 14)

# %%
# change Sheffield Ave & Wellington Ave to 'N Sheffield Ave & W Wellington Ave'

merged2013_2022.loc[merged2013_2022['start_station_name'] == 'Sheffield Ave & Wellington Ave', 'start_station_name'] = 'N Sheffield Ave & W Wellington Ave'
merged2013_2022.loc[merged2013_2022['end_station_name'] == 'Sheffield Ave & Wellington Ave', 'end_station_name'] = 'N Sheffield Ave & W Wellington Ave'

# %%
# - charging needs to be removed from 'Bissell St & Armitage Ave* - Charging'

merged2013_2022.loc[merged2013_2022['start_station_name'] == 'Bissell St & Armitage Ave* - Charging', 'start_station_name'] = 'Bissell St & Armitage Ave*'
merged2013_2022.loc[merged2013_2022['end_station_name'] == 'Bissell St & Armitage Ave* - Charging', 'end_station_name'] = 'Bissell St & Armitage Ave*'

# %%
# 'Prairie Ave & Garfield Blvd' is a 'Public Rack -'

merged2013_2022.loc[merged2013_2022['start_station_name'] == 'Prairie Ave & Garfield Blvd', 'start_station_name'] = 'Public Rack - Prairie Ave & Garfield Blvd'
merged2013_2022.loc[merged2013_2022['end_station_name'] == 'Prairie Ave & Garfield Blvd', 'end_station_name'] = 'Public Rack - Prairie Ave & Garfield Blvd'

# %%
# Need to check Buckingham Fountain again at the end of this.

merged2013_2022[merged2013_2022['start_station_name'] == 'Buckingham Fountain']
# Out:
#          start_time  end_time  tripduration start_station_id  \
# 815        00:00:00  00:27:00          1600                2
# 816        00:00:00  00:27:00          1643                2
# 973        00:00:00  09:12:00         33109                2
# 1480       00:00:00  01:26:42          5202                2
# 1722       00:00:03  00:20:44          1241                2
# ...             ...       ...           ...              ...
# 33142202   23:59:50  00:21:12          1281                2
# 33142349   23:59:52  03:15:42         11749                2
# 33142475   23:59:54  00:16:00           966                2
# 33142503   23:59:54  00:09:56           601                2
# 33142507   23:59:54  00:18:12          1097                2
#
#            start_station_name end_station_id  \
# 815       Buckingham Fountain             35
# 816       Buckingham Fountain             35
# 973       Buckingham Fountain              7
# 1480      Buckingham Fountain              2
# ...

# %%
# Buckingham Fountain, Grant Park, Chicago has a dpcapacity of 39, had to search the park with
# satillite view and count to find this number.

fix_dpcapacity('Buckingham Fountain', 39)

# %%
# This is where the new section of fixes begins. Now I will be using a list to figure out which values to fix.

# %%
# these are our remaining values that need to be fixed
fix_dp_list = list(set(list(merged2013_2022[merged2013_2022['start_dpcapacity'] == 0]['start_station_name'].values) + list(merged2013_2022[merged2013_2022['end_dpcapacity'] == 0]['end_station_name'].values)))

# %%
len(fix_dp_list)
# Out:
# 652

# %%
len(list(set(list(merged2013_2022['start_station_name'].values) + list(merged2013_2022['end_station_name'].values))))
# Out:
# 1410

# %%
fix_dp_list[:10]
# Out:
# ['Public Rack - Laramie Ave & Grand Ave',
#  'Public Rack - Cottage Grove Ave & 98th St',
#  'Western Ave & 62nd St',
#  'Public Rack - Drake Ave & Leland Ave',
#  'Public Rack - Kildare Ave & Washignton Blvd',
#  'Divvy Valet - Oakwood Beach',
#  'Kildare Ave & 47th St',
#  'Mozart St & Jackson Blvd',
#  'Kilpatrick Ave & Parker Ave',
#  'Canty Elementary School']

# %%
# 'Harvard Ave & 103rd St' is a 'Public Rack - '
merged2013_2022.loc[merged2013_2022['start_station_name'] == 'Harvard Ave & 103rd St', 'start_station_name'] =  'Public Rack - Harvard Ave & 103rd St'
merged2013_2022.loc[merged2013_2022['end_station_name'] == 'Harvard Ave & 103rd St', 'end_station_name'] =  'Public Rack - Harvard Ave & 103rd St'

# 'Throop St & 58th St' is a 'Public Rack - '
merged2013_2022.loc[merged2013_2022['start_station_name'] == 'Throop St & 58th St', 'start_station_name'] =  'Public Rack - Throop St & 58th St'
merged2013_2022.loc[merged2013_2022['end_station_name'] == 'Throop St & 58th St', 'end_station_name'] =  'Public Rack - Throop St & 58th St'

fix_dpcapacity('Public Rack - Rockwell & 111th St', 2)
fix_dpcapacity('Public Rack - Brandon Ave & 91st St', 1)
fix_dpcapacity('Narragansett & Wrightwood', 9)
fix_dpcapacity('Public Rack - Harvard Ave & 103rd St', 1)
fix_dpcapacity('Maplewood Ave & 59th St', 9)
fix_dpcapacity('Public Rack - Central Park Ave & 16th St', 1)
fix_dpcapacity('Meade Ave & Addison St', 9)
fix_dpcapacity('Public Rack - Throop St & 58th St', 3)
fix_dpcapacity('Major Ave & Bloomingdale Ave', 9)
fix_dpcapacity('Dodge Ave & Main St', 15)

# %%
fix_dp_list[10:20]
# Out:
# ['Public Rack - Cicero Ave & Le Moyne St',
#  'Cottage Grove Ave & 83rd St',
#  'Public Rack - Al Raby School',
#  'Avenue L & 114th St',
#  'Parkside Ave & Armitage Ave',
#  'Parnell Ave & 98th St',
#  'Public Rack - 53rd St & Indiana Ave',
#  'Western Ave & Lake St',
#  'Homan Ave & 65th St',
#  'Public Rack - Richmond St & Thorndale Ave']

# %%
fix_dpcapacity('Public Rack - Newcastle Ave & Belmont Ave', 2)
fix_dpcapacity('Archer (Damen) Ave & 37th St', 11)
fix_dpcapacity('Public Rack - Sacramento Ave & Greenleaf Ave', 6)
fix_dpcapacity('The Montessori School of Englewood', 2)
fix_dpcapacity('Public Rack - Morgan St & 95th St', 2)
fix_dpcapacity('Public Rack - Halsted St & 113th St', 1)
fix_dpcapacity('Lawndale Ave & 16th St', 9)
fix_dpcapacity('Jeffery Blvd & 67th St', 11)
fix_dpcapacity('Public Rack - Chase Ave & Touhy Ave - NE', 4)
fix_dpcapacity('Public Rack - Western Ave & 107th Pl', 1)

# %%
fix_dp_list[20:30]
# Out:
# ['Public Rack - Hoyne Ave & 51st St',
#  'Ashland Ave & 46th St',
#  'Burling St (Halsted) & Diversey Pkwy',
#  'Public Rack - Melvina Ave & Belmont Ave',
#  'Lincolnwood Dr & Central St',
#  'Halsted St & 111th St',
#  'Troy Ave & 27th St',
#  'Parnell Ave & 119th St',
#  'Wells St & Institute Pl',
#  'Pullman - Ross Dress for Less']

# %%
fix_dpcapacity('Kedzie Ave & 57th St', 9)
fix_dpcapacity('Ewing Ave & 101st St', 1)
fix_dpcapacity('Homan Ave & 65th St', 13)
fix_dpcapacity('Public Rack - Francisco Ave & Touhy Ave', 2)
fix_dpcapacity('Sacramento Ave & 25th St', 9)
fix_dpcapacity('Public Rack - Piotrowski Park', 2)
# 'Oak Park & Wellington' is in 'Oak Park'
fix_dpcapacity('Oak Park & Wellington', 9)
fix_dpcapacity('Public Rack - Kenton Ave & Palmer St', 1)
fix_dpcapacity('Pittsburgh Ave & Irving Park', 1)
fix_dpcapacity('Carpenter St & 63rd St', 7)

# %%
for i in range(10):
    print(fix_dp_list[30:40][i])
# Out:
# Meade Ave & Addison St
# Elizabeth St & 47th St
# Public Rack - Homan Ave & Lake St
# Mason Ave & Roosevelt Rd
# Public Rack - Western Ave & 47th Pl
# Mt Greenwood Library - South
# Public Rack - Rutherford Ave & Belmont Ave
# Public Rack - Prairie Ave & Garfield Blvd N
# Western Ave & 106th St - West
# Public Rack - Zapata Academy

# %%
fix_dpcapacity('Greenwood Ave & 97th St', 15)
fix_dpcapacity('Public Rack - Grand Ave & North Ave', 2)
fix_dpcapacity('Wells St & Institute Pl', 11)
fix_dpcapacity('Ridge Blvd & Touhy Ave', 11)
fix_dpcapacity('Damen Ave & 33rd St', 9)
fix_dpcapacity('Public Rack - Western Ave & 111th St - NW', 1)
fix_dpcapacity('Karlov Ave & Madison St', 10)
fix_dpcapacity('Public Rack - Hamlin Ave & Madison St', 1)
fix_dpcapacity('Houston Ave & 92nd St', 15)
fix_dpcapacity('Public Rack - Lawndale & 63rd St', 1)

# %%
for i in range(10):
    print(fix_dp_list[40:50][i])
# Out:
# Public Rack - Neva Ave & Grand Ave
# Public Rack - Kedzie Ave & 63rd St
# Marshfield Ave & 59th St
# Marquette Ave & 79th St
# Plainfield & Irving Park
# Buffalo Ave & 133rd St
# Public Rack - Ashland Ave & 45th St
# Baltimore Ave & 132nd St
# Chicago Ave & Sheridan Rd
# Ingleside Ave & 79th St

# %%
# Christiana Ave & 55th St is a 'Public Rack - '
merged2013_2022.loc[merged2013_2022['start_station_name'] == 'Christiana Ave & 55th St', 'start_station_name'] =  'Public Rack - Christiana Ave & 55th St'
merged2013_2022.loc[merged2013_2022['end_station_name'] == 'Christiana Ave & 55th St', 'end_station_name'] =  'Public Rack - Christiana Ave & 55th St'

fix_dpcapacity('Public Rack - Kedzie & 103rd St - East', 1)
fix_dpcapacity('Public Rack - Loomis St & 87th St', 1)
fix_dpcapacity('Greenwood Ave & 79th St', 11)
fix_dpcapacity('Public Rack - Western Ave & 106th St - East', 1)
fix_dpcapacity('Public Rack - Christiana Ave & 55th St', 1)
fix_dpcapacity('Public Rack - Pulaski Rd & 15th St', 1)
fix_dpcapacity('Public Rack - Keef Ave & South Chicago Ave', 1)
fix_dpcapacity('Halsted St & 78th St', 10)
fix_dpcapacity('Public Rack - Pulaski & 52nd', 1)
fix_dpcapacity('Public Rack - Kildare Ave & Division St', 6)

# %%
for i in range(10):
    print(fix_dp_list[50:60][i])
# Out:
# Newcastle Ave & Wellington Ave
# Tripp Ave & 65th St
# Public Rack - Grand Ave & Lawndale Ave
# Public Rack - Austin Ave & Wrightwood Ave
# Augusta Blvd & Laramie Ave
# Kedvale Ave & 63rd St
# Wolcott Ave & 61st St
# Public Rack - Washtenaw Ave & Devon Ave
# Central Park Blvd & 5th Ave
# Cicero Ave & Quincy St

# %%
fix_dpcapacity('Public Rack - King Dr & 71st St', 2)
fix_dpcapacity('Keeler Ave & Madison St', 3)
fix_dpcapacity('Public Rack - Cicero Ave & Wellington Ave', 2)
fix_dpcapacity('Racine Ave & 61st St', 11)
fix_dpcapacity('Marshfield Ave & 59th St', 11)
fix_dpcapacity('Archer Park', 2)
fix_dpcapacity('Public Rack - Austin Ave & Wrightwood Ave', 2)
fix_dpcapacity('Public Rack - Nordica Ave & Addison St', 1)
fix_dpcapacity('Vernon Ave & 79th St', 11)
fix_dpcapacity('Public Rack - Wentworth Ave & 79th St', 1)

# %%
for i in range(10):
    print(fix_dp_list[60:70][i])
# Out:
# Public Rack - Keystone Ave & North Ave
# Stony Is Ave & 73rd St
# Public Rack - Division St & Christiana Ave
# Public Rack - Cicero Ave & Wellington Ave
# Public Rack - Grand Ave & North Ave
# Fullerton & Monitor
# Vincennes Ave & 87th St
# Langley Ave & 105th Pl
# Central Park & Augusta Blvd
# Artesian Ave & 55th St

# %%
fix_dpcapacity('Ada St & 113th St', 15)
fix_dpcapacity('Troy Ave & 27th St', 10)
fix_dpcapacity('Public Rack - Menard Ave & Belmont Ave', 1)
fix_dpcapacity('Millard Ave & 26th St', 7)
fix_dpcapacity('Public Rack - Damen Ave & 47th St', 1)
fix_dpcapacity('Public Rack - Kedzie Ave & Pershing Rd', 1)
fix_dpcapacity('Central Ave & Harrison St', 11)
fix_dpcapacity('Public Rack - Western Ave & 105th St', 1)
fix_dpcapacity('Public Rack - Chappel Ave & 71st St', 2)
fix_dpcapacity('Public Rack - Western Ave & 104th St - East', 2)

# %%
for i in range(10):
    print(fix_dp_list[70:80][i])
# Out:
# Public Rack - Foster Ave & Drake Ave
# Public Rack - Kedzie Ave & 62nd Pl
# Exchange Ave & 79th St
# Western & 28th - Velasquez Institute
# Public Rack - Harding Ave & 47th St
# Public Rack - Pullman - Walmart
# Michigan Ave & 102nd St
# Pulaski Rd & Congress Pkwy
# Public Rack - California Ave & Devon Ave - NW
# Public Rack - Mackinaw Ave & 108th St

# %%
fix_dpcapacity('Public Rack - Cicero Ave & Roscoe St', 1)
fix_dpcapacity('Public Rack - McVicker Ave & Grand Ave', 1)
fix_dpcapacity('Kildare Ave & Chicago Ave', 9)
fix_dpcapacity('Public Rack - Ewing Ave & 106th St', 1)
fix_dpcapacity('Public Rack - Pullman - Planet Fitness', 1)
fix_dpcapacity('Public Rack - Ewing Ave & 102nd St', 1)
fix_dpcapacity('Public Rack - Kostner Ave & Wrightwood Ave', 9)
fix_dpcapacity('Public Rack - Harding Ave & 47th St', 1)
fix_dpcapacity('Public Rack - Hamilton Ave & 95th St', 2)
fix_dpcapacity('Public Rack - West Chatham Park', 2)

# %%
for i in range(10):
    print(fix_dp_list[80:90][i])
# Out:
# Public Rack - Keeler Ave & 55th St
# Park Manor Elementary School
# Broadway & Wilson Ave
# Public Rack - Normal Ave & 111th St
# Menard Ave & Division St
# Public Rack - Loomis Blvd & 83rd St
# Public Rack - Kilbourn Ave & Fullerton Ave
# Elizabeth St & 92nd St
# Public Rack - Central Ave & North Ave
# Vincennes Ave & 104th St

# %%
# 'Cottage Grove Ave & 75th St' is a 'Public Rack - '
merged2013_2022.loc[merged2013_2022['start_station_name'] == 'Cottage Grove Ave & 75th St', 'start_station_name'] =  'Public Rack - Cottage Grove Ave & 75th St'
merged2013_2022.loc[merged2013_2022['end_station_name'] == 'Cottage Grove Ave & 75th St', 'end_station_name'] =  'Public Rack - Cottage Grove Ave & 75th St'

# 'Vincennes Ave & 87th St' is a 'Public Rack - '
merged2013_2022.loc[merged2013_2022['start_station_name'] == 'Vincennes Ave & 87th St', 'start_station_name'] =  'Public Rack - Vincennes Ave & 87th St'
merged2013_2022.loc[merged2013_2022['end_station_name'] == 'Vincennes Ave & 87th St', 'end_station_name'] =  'Public Rack - Vincennes Ave & 87th St'

# 'Chicage Ave & Dempster St' does not exist according to google maps, needs to be looked into further
# 'Chicage Ave & Dempster St' is in Evanston
fix_dpcapacity('Public Rack - Bell Ave & 95th St', 2)
fix_dpcapacity('Mackinaw Ave & 85th St', 1)
fix_dpcapacity('Kildare Ave & 55th St', 9)
fix_dpcapacity('Public Rack - Cottage Grove Ave & 75th St', 1)
fix_dpcapacity('Public Rack - Emerald Ave & 43rd St', 2)
fix_dpcapacity('Lavergne & Fullerton', 9)
fix_dpcapacity('Public Rack - Vincennes Ave & 87th St', 1)
fix_dpcapacity('Chicago Ave & Dempster St', -1)
fix_dpcapacity('William Rainey Harper High School', 2)
fix_dpcapacity('Central Ave & Congress Pkwy', 2)

# %%
for i in range(10):
    print(fix_dp_list[90:100][i])
# Out:
# Morgan St & 87th St
# The Montessori School of Englewood
# Public Rack - Pulaski Rd & 15th St
# Public Rack - Chopin Park
# Warren Park East
# Public Rack - Whipple St & 26th St
# Hoyne Ave & 34th St
# Public Rack - Crandon Ave & 80th St
# Public Rack - Langley Ave & Oakwood Blvd
# Pittsburgh Ave & Irving Park

# %%
fix_dpcapacity('Public Rack - Albany Ave & 111th St - NW', 1)
fix_dpcapacity('Public Rack - Spencer Elementary Technology Academy', 2)
fix_dpcapacity('Lamon Ave & Belmont Ave', 9)
fix_dpcapacity('Sacramento Blvd & Fulton Ave', 9)
fix_dpcapacity('Major Taylor Trail & 124th St', 15)
fix_dpcapacity('Public Rack - Kolin Ave & Archer Ave', 2)
fix_dpcapacity('Wallace St & 112 St', 3)
fix_dpcapacity('Public Rack - Kedzie Ave & 54th St - SE', 1)
fix_dpcapacity('Public Rack - Sawyer Ave & Bryn Mawr Ave - SE', 1)
fix_dpcapacity('Rhodes Ave & 79th St', 1)

# %%
for i in range(10):
    print(fix_dp_list[100:110][i])
# Out:
# Maplewood Ave & Peterson Ave
# Lawler Ave & 50th St
# James Madison School
# Public Rack - Kimball Ave & Carmen Ave
# Morgan St & 103rd St
# Walden Pkwy & 100th St
# Public Rack - Komensky Ave & 59th St
# Public Rack - Latrobe Ave & Lake St
# Pulaski Rd & 60th St
# Torrence Ave & 106th St

# %%
# 'Talman Ave & 51st St' is a 'Public Rack - '
merged2013_2022.loc[merged2013_2022['start_station_name'] == 'Talman Ave & 51st St', 'start_station_name'] =  'Public Rack - Talman Ave & 51st St'
merged2013_2022.loc[merged2013_2022['end_station_name'] == 'Talman Ave & 51st St', 'end_station_name'] =  'Public Rack - Talman Ave & 51st St'

fix_dpcapacity('Calumet Ave & Garfield Blvd', 1)
fix_dpcapacity('Public Rack - Central Ave & Corcoran Pl', 1)
fix_dpcapacity('Pulaski Rd & 60th St', 9)
fix_dpcapacity('Public Rack - Peterson Ave & Drake Ave', 2)
fix_dpcapacity('Public Rack - Cicero Ave & Le Moyne St', 1)
fix_dpcapacity('Public Rack - Emerald Ave & 45th St', 1)
fix_dpcapacity('Homan Ave & Fillmore St', 9)
fix_dpcapacity('Vincennes Ave & 104th St', 15)
fix_dpcapacity('Augusta Blvd & Laramie Ave', 9)
fix_dpcapacity('Public Rack - Talman Ave & 51st St', 2)

# %%
for i in range(10):
    print(fix_dp_list[110:120][i])
# Out:
# Ewing Ave & Indianapolis Ave
# Public Rack - Lorel Ave & Chicago Ave
# Public Rack - Leclaire Ave & Division St
# Public Rack - Western Ave & 110th St
# Public Rack - Kedzie Ave & 60th St
# Public Rack - Halsted St & 102nd St
# Public Rack - Kimbark Ave & 63rd St
# Public Rack - Peterson Ave & Drake Ave
# Central Park Ave & 24th St
# Public Rack - Oketo Ave & Belmont Ave

# %%
fix_dpcapacity('Mayfield & Roosevelt Rd', 9)
fix_dpcapacity('Public Rack - Eggleston Ave & 115th St', 3)
fix_dpcapacity('Marquette Ave & 83rd St', 1)
fix_dpcapacity('Kedzie Ave & 104th St', 8)
fix_dpcapacity('Public Rack - Division St & Christiana Ave', 2)
fix_dpcapacity('Long Ave & Belmont Ave', 9)
fix_dpcapacity('Public Rack - Kedzie Ave & 60th St', 1)
fix_dpcapacity('Public Rack - Langley Ave & 79th St', 2)
fix_dpcapacity('Lincoln Ave & Peterson Ave', 9)
fix_dpcapacity('Lincolnwood Dr & Central St', 14)

# %%
for i in range(10):
    print(fix_dp_list[120:130][i])
# Out:
# Lafayette Ave & 119th St
# Public Rack - Stony Island & 87th St
# Fairfield Ave & 44th St
# Public Rack - Keef Ave & South Chicago Ave
# Public Rack - Karlov Ave & 26th St
# Halsted St & 78th St
# Tripp Ave & 31st St
# Damen Ave & 74th St
# Halsted St & 104th St
# Public Rack - Vincennes Ave & 95th St

# %%
# 'Avenue J & 112th St' is a 'Public Rack - '
merged2013_2022.loc[merged2013_2022['start_station_name'] == 'Avenue J & 112th St', 'start_station_name'] =  'Public Rack - Avenue J & 112th St'
merged2013_2022.loc[merged2013_2022['end_station_name'] == 'Avenue J & 112th St', 'end_station_name'] =  'Public Rack - Avenue J & 112th St'

# 'Menard Ave & Dakin St' is a 'Public Rack - '
merged2013_2022.loc[merged2013_2022['start_station_name'] == 'Menard Ave & Dakin St', 'start_station_name'] =  'Public Rack - Menard Ave & Dakin St'
merged2013_2022.loc[merged2013_2022['end_station_name'] == 'Menard Ave & Dakin St', 'end_station_name'] =  'Public Rack - Menard Ave & Dakin St'

fix_dpcapacity('State St & 123rd St', 14)
fix_dpcapacity('Stony Island Ave & 67th St', 11)
fix_dpcapacity('Ewing Ave & Burnham Greenway', 11)
fix_dpcapacity('Public Rack - Kimball Ave & Carmen Ave', 3)
fix_dpcapacity('Public Rack - Saginaw Ave & 93rd St', 1)
fix_dpcapacity('Avenue J & 112th St', 2)
fix_dpcapacity('Public Rack - Pulaski Rd & Polk St', 1)
fix_dpcapacity('Kostner Ave & Lake St', 11)
fix_dpcapacity('Public Rack - Mt Greenwood Library N', 2)
fix_dpcapacity('Menard Ave & Dakin St', 2)

# %%
for i in range(10):
    print(fix_dp_list[130:140][i])
# Out:
# Knox Ave & Montrose Ave
# Kostner Ave & Adams St
# Public Rack - Western Ave & 107th Pl
# Baltimore Ave & 133rd St
# Public Rack - Paul Revere Elementary School
# Oak Park & Wellington
# Public Rack - Walden Pkwy & 103rd St
# Public Rack - Rockwell & 111th St
# Public Rack - Ashland Ave & 73rd St
# Kildare Ave & 26th St

# %%
# 'Lowe Ave & 98th St' is a 'Public Rack - '
merged2013_2022.loc[merged2013_2022['start_station_name'] == 'Lowe Ave & 98th St', 'start_station_name'] =  'Public Rack - Lowe Ave & 98th St'
merged2013_2022.loc[merged2013_2022['end_station_name'] == 'Lowe Ave & 98th St', 'end_station_name'] =  'Public Rack - Lowe Ave & 98th St'

# 'Washtenaw Ave & 63rd St' is a 'Public Rack - '
merged2013_2022.loc[merged2013_2022['start_station_name'] == 'Washtenaw Ave & 63rd St', 'start_station_name'] =  'Public Rack - Washtenaw Ave & 63rd St'
merged2013_2022.loc[merged2013_2022['end_station_name'] == 'Washtenaw Ave & 63rd St', 'end_station_name'] =  'Public Rack - Washtenaw Ave & 63rd St'

# 'Winchester Ave & 87th St' is a 'Public Rack - '
merged2013_2022.loc[merged2013_2022['start_station_name'] == 'Winchester Ave & 87th St', 'start_station_name'] =  'Public Rack - Winchester Ave & 87th St'
merged2013_2022.loc[merged2013_2022['end_station_name'] == 'Winchester Ave & 87th St', 'end_station_name'] =  'Public Rack - Winchester Ave & 87th St'

# 'Strohacker Park' is a 'Public Rack - '
merged2013_2022.loc[merged2013_2022['start_station_name'] == 'Strohacker Park', 'start_station_name'] =  'Public Rack - Strohacker Park'
merged2013_2022.loc[merged2013_2022['end_station_name'] == 'Strohacker Park', 'end_station_name'] =  'Public Rack - Strohacker Park'

# 'Avenue J & 106th St' is a 'Public Rack - '
merged2013_2022.loc[merged2013_2022['start_station_name'] == 'Avenue J & 106th St', 'start_station_name'] =  'Public Rack - Avenue J & 106th St'
merged2013_2022.loc[merged2013_2022['end_station_name'] == 'Avenue J & 106th St', 'end_station_name'] =  'Public Rack - Avenue J & 106th St'

fix_dpcapacity('Public Rack - Lowe Ave & 98th St', 1)
fix_dpcapacity('Public Rack - Cicero Ave & North Ave', 1)
fix_dpcapacity('Public Rack - Washtenaw Ave & 63rd St', 2)
fix_dpcapacity('California Ave & 29th St', 8)
fix_dpcapacity('Constance Ave & 95th St', 15)
fix_dpcapacity('Francisco Ave & Hollywood Ave', 9)
fix_dpcapacity('Public Rack - Racine Ave & 74th St', 1)
fix_dpcapacity('Public Rack - Winchester Ave & 87th St', 1)
fix_dpcapacity('Public Rack - Strohacker Park', 2)
fix_dpcapacity('Public Rack - Avenue J & 106th St', 1)

# %%
for i in range(10):
    print(fix_dp_list[140:150][i])
# Out:
# Lafayette Ave & 87th St - SW
# DIVVY CASSETTE REPAIR MOBILE STATION
# Public Rack - Kedzie Ave & Arthington St
# Vincennes Ave & 95th Pl
# Public Rack - Kolin Ave & Archer Ave
# Cicero Ave & Cortland St
# Public Rack - Buffalo Ave & 89th St
# Oketo Ave & Addison St
# Public Rack - Mozart Elementary School
# Public Rack - Perry Ave & 111th St

# %%
# 'New England Ave & Grace St' is a 'Public Rack - '
merged2013_2022.loc[merged2013_2022['start_station_name'] == 'New England Ave & Grace St', 'start_station_name'] =  'Public Rack - New England Ave & Grace St'
merged2013_2022.loc[merged2013_2022['end_station_name'] == 'New England Ave & Grace St', 'end_station_name'] =  'Public Rack - New England Ave & Grace St'

# 'Halsted St & 80th St' is a 'Public Rack - '
merged2013_2022.loc[merged2013_2022['start_station_name'] == 'Halsted St & 80th St', 'start_station_name'] =  'Public Rack - Halsted St & 80th St'
merged2013_2022.loc[merged2013_2022['end_station_name'] == 'Halsted St & 80th St', 'end_station_name'] =  'Public Rack - Halsted St & 80th St'

# 'Park Manor Elementary School' is a 'Public Rack - '
merged2013_2022.loc[merged2013_2022['start_station_name'] == 'Park Manor Elementary School', 'start_station_name'] =  'Public Rack - Park Manor Elementary School'
merged2013_2022.loc[merged2013_2022['end_station_name'] == 'Park Manor Elementary School', 'end_station_name'] =  'Public Rack - Park Manor Elementary School'

# 'Mackinaw Ave & 106th St' is a 'Public Rack - '
merged2013_2022.loc[merged2013_2022['start_station_name'] == 'Mackinaw Ave & 106th St', 'start_station_name'] =  'Public Rack - Mackinaw Ave & 106th St'
merged2013_2022.loc[merged2013_2022['end_station_name'] == 'Mackinaw Ave & 106th St', 'end_station_name'] =  'Public Rack - Mackinaw Ave & 106th St'

fix_dpcapacity('DIVVY CASSETTE REPAIR MOBILE STATION', -1)
fix_dpcapacity('Central Ave & Lake St', 10)
fix_dpcapacity('Public Rack - McCormick Blvd & Devon Ave', 3)
fix_dpcapacity('Public Rack - New England Ave & Grace St', 1)
fix_dpcapacity('Public Rack - Halsted St & 80th St', 1)
fix_dpcapacity('Public Rack - Park Manor Elementary School', 3)
fix_dpcapacity('Public Rack - Mackinaw Ave & 106th St', 1)
fix_dpcapacity('Public Rack - California Ave & Ogden Ave', 1)
fix_dpcapacity('Public Rack - Ewing Ave & 107th St', 1)
fix_dpcapacity('Public Rack - Lafayette Ave & 95th St', 10)

# %%
merged2013_2022.dtypes
# Out:
# start_time             object
# end_time               object
# tripduration            int64
# start_station_id       object
# start_station_name     object
# end_station_id         object
# end_station_name       object
# usertype                int64
# gender                  int64
# birthyear               int64
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# rideable_type           int64
# start_city              int64
# start_landmark          int64
# end_city                int64
# end_landmark            int64
# start_date             object
# end_date               object
# start_dpcapacity        int64
# end_dpcapacity          int64
# dtype: object

# %%
# Because this Public Rack fix is so common, I am adding a clause in the initial function to handle these cases

def fix_dpcapacity(station_name='', dp_capacity=int, pub_rack_bool=False):
    temp_station_name = station_name
    
    if pub_rack_bool:
        merged2013_2022.loc[merged2013_2022['start_station_name'] == temp_station_name, 'start_station_name'] = 'Public Rack - ' + temp_station_name
        merged2013_2022.loc[merged2013_2022['end_station_name'] == temp_station_name, 'end_station_name'] = 'Public Rack - ' + temp_station_name
        temp_station_name = 'Public Rack - ' + temp_station_name
    
    confirmed_list.append(temp_station_name)

    merged2013_2022.loc[merged2013_2022['start_station_name'] == temp_station_name, 'start_dpcapacity'] = dp_capacity
    merged2013_2022.loc[merged2013_2022['end_station_name'] == temp_station_name, 'end_dpcapacity'] = dp_capacity

# %%
for i in range(10):
    print(fix_dp_list[150:160][i])
# Out:
# Kedzie Ave & 104th St
# Public Rack - Brandon Ave & 91st St
# Public Rack - Komensky Ave & 26th St
# Public Rack - Pulaski Rd & Roosevelt Rd
# Public Rack - Hamilton Ave & 95th St
# W 103rd St & S Avers Ave
# Public Rack - Spaulding Ave & North Ave
# Kedzie Ave & 57th St
# Public Rack - Burnside Academy
# Public Rack - Halsted St & 109th St

# %%
fix_dpcapacity('Canty Elementary School', 2, True)
fix_dpcapacity('Francisco Ave & 47th St', 9)
fix_dpcapacity('Public Rack - Harriet E Sayre Public School', 3)
fix_dpcapacity('S Aberdeen St & W 106th St', 3)
fix_dpcapacity('Troy & 111th St', 1, True)
fix_dpcapacity('Public Rack - Jeffrey Blvd & 71st St', 1)
fix_dpcapacity('Eggleston Ave & 114th St', 3, True)
fix_dpcapacity('Oleander Ave & Addison St', 3, True)
fix_dpcapacity('Public Rack - Kedzie Ave & Walnut St', 1)
fix_dpcapacity('Public Rack - Lake Shore Dr & Hayes Dr', 15)

# %%
for i in range(10):
    print(fix_dp_list[160:170][i])
# Out:
# Public Rack - Wood St & 47th St
# Public Rack - Sawyer Ave & Bryn Mawr Ave - SW
# Olive Harvey College
# Major Ave & Bloomingdale Ave
# Public Rack - Harvey Ave & North Ave
# Claremont Ave & 71st St
# Public Rack - Kedzie & 103rd St - W
# Mulligan Ave & Wellington Ave
# Houston Ave & 92nd St
# Public Rack - Cicero Ave & Altgeld St

# %%
fix_dpcapacity('Loomis Blvd & 84th St', 15)
fix_dpcapacity('Public Rack - May St & 78th St', 1)
fix_dpcapacity('Cicero Ave & Cortland St', 1, True)
fix_dpcapacity('State St & 76th St', 11)
fix_dpcapacity('Public Rack - Hamlin Ave & Chicago Ave', 1)
fix_dpcapacity('Woodlawn Ave & 75th St', 11)
fix_dpcapacity('Muskegon Ave & 89th St', 1, True)
fix_dpcapacity('Public Rack - Lawndale Ave & Polk St', 2)
fix_dpcapacity('Public Rack - Chase Ave & Touhy Ave - NW', 1)
fix_dpcapacity('Public Rack - Kedzie Ave & 64th St - SE', 1)

# %%
for i in range(10):
    print(fix_dp_list[170:180][i])
# Out:
# Calumet Park
# Greenwood Ave & 79th St
# Talman Ave & 51st St
# Newland Ave & Diversey Ave
# Public Rack - Western Ave & 111th St - NW
# Public Rack - Kingston Ave & 75th St
# Lake Park Ave & 44th St
# Public Rack - Wentworth Ave & 79th St
# Public Rack - Ewing Ave & 96th St N
# State St & Pershing Rd

# %%
fix_dpcapacity('Public Rack - Pulaski Rd & Roosevelt Rd', 1)
fix_dpcapacity('Tripp Ave & 15th St', 9)
fix_dpcapacity('Central Park Blvd & 5th Ave', 11)
fix_dpcapacity('Commercial Ave & 100th St', 15)
fix_dpcapacity('Public Rack - Kedzie Ave & Archer Ave', 2)
fix_dpcapacity('Public Rack - Kildare Ave & Washignton Blvd', 1)
fix_dpcapacity('Halsted St & 111th St', 1, True)
fix_dpcapacity('N Damen Ave & W Wabansia St', 6)
fix_dpcapacity('Public Rack - Lotus Ave & Harrison St', 1)
fix_dpcapacity('Fairfield Ave & 44th St', 9)

# %%
for i in range(10):
    print(fix_dp_list[180:190][i])
# Out:
# Public Rack - Sacramento Blvd & Division St
# Lamon Ave & Chicago Ave
# Maryland Ave & 104th St
# Public Rack - Emerald Ave & 45th St
# Public Rack - Loomis St & 87th St
# Public Rack - Wood St & 103rd St
# Public Rack - Halsted St & 113th St
# Bishop St & 46th St
# St Louis Ave & Norman Bobbins Ave
# Public Rack - Langley Ave & 49th St

# %%
fix_dpcapacity('Public Rack - Union Ave & 111th St', 1)
fix_dpcapacity('Public Rack - Oakley Ave & 50th Pl', 1)
fix_dpcapacity('James Madison School', 2, True)
fix_dpcapacity('Public Rack - Zapata Academy', 3)
fix_dpcapacity('Lamon Ave & Archer Ave', -1)
fix_dpcapacity('Morgan St & 103rd St', 2, True)
fix_dpcapacity('Public Rack - Ashland Ave & 83rd St', 1)
fix_dpcapacity('Yates Blvd & 93rd St', 15)
fix_dpcapacity('Western Ave & Gunnison St', 8)
fix_dpcapacity('South Chicago Ave & Elliot Ave', 7)

# %%
for i in range(10):
    print(fix_dp_list[190:200][i])
# Out:
# Bloomingdale Ave & Harlem Ave
# Ewing Ave & 101st St
# Trumbull Ave & 111th St
# Public Rack - Hamlin Ave & Grand Ave
# Western Ave & Ardmore Ave
# Public Rack - Hamlin Ave & Chicago Ave
# Public Rack - Marshfield Ave & 45th St
# Hale Ave & 111th St
# Kostner Ave & 63rd St
# Panama Ave & Grace St

# %%
fix_dpcapacity('Richmond St & 59th St', 11)
fix_dpcapacity('Morgan St & 87th St', 1, True)
fix_dpcapacity('Public Rack - Homan Ave & Lake St', 2)
fix_dpcapacity('Austin Blvd & Madison St', 10)
fix_dpcapacity('Hamlin Ave & 62nd Pl', 12)
fix_dpcapacity('Lafayette Ave & 119th St', 1, True)
fix_dpcapacity('Cottage Grove & 84th St', 1, True)
fix_dpcapacity('Walden Pkwy & 100th St', 15)
fix_dpcapacity('Public Rack - Brainerd Park', 1)
fix_dpcapacity('Cottage Grove Ave & 91st St', 1, True)

# %%
for i in range(10):
    print(fix_dp_list[200:210][i])
# Out:
# Public Rack - Brainerd Park
# Cottage Grove Ave & 91st St
# Public Rack - Central Ave & George St
# Public Rack - Ashland Ave & 83rd St
# Public Rack - Nordica Ave & Addison St
# Damen Ave & 51st St
# Public Rack - Forrestville Ave & 47th St
# Western Ave & 104th St
# Public Rack - Ewing Ave & 102nd St
# Calumet Ave & Garfield Blvd

# %%
# 'Lincoln Ave & Roscoe St' --> 'Lincoln Ave & Roscoe St*'
merged2013_2022.loc[merged2013_2022['start_station_name'] == 'Lincoln Ave & Roscoe St', 'start_station_name'] = 'Lincoln Ave & Roscoe St*'
merged2013_2022.loc[merged2013_2022['end_station_name'] == 'Lincoln Ave & Roscoe St', 'end_station_name'] = 'Lincoln Ave & Roscoe St*'

fix_dpcapacity('Divvy Valet - Oakwood Beach', -1)
fix_dpcapacity('Lincoln Ave & Roscoe St*', 15)
fix_dpcapacity('Cicero Ave & Le Moyne St', 1, True)
fix_dpcapacity('Public Rack - 83rd St (Avalon Park) Metra', 1)
fix_dpcapacity('Public Rack - King Dr & 83rd St', 1)
fix_dpcapacity('Western Ave & 111th St - SE', 23)
fix_dpcapacity('Public Rack - Stony Island & 95th St', 1)
fix_dpcapacity('Central Park Ave & Douglas Blvd', 9)
fix_dpcapacity('Public Rack - Ashland Ave & 73rd St', 1)
fix_dpcapacity('Central Ave & Parker Ave', 8)

# %%
for i in range(10):
    print(fix_dp_list[210:220][i])
# Out:
# Long Ave & Belmont Ave
# 63rd & Western Ave - south corner
# Bissell St & Armitage Ave
# Public Rack - Hyde Park Blvd & 55th St
# Public Rack - Austin Ave & Wellington Ave
# Damen Ave & 33rd St
# Public Rack - Wallace St & 119th St
# Public Rack - Union Ave & 111th St
# Halsted St & 41st St
# Public Rack - Langley Ave & 79th St

# %%
fix_dpcapacity('Martin Luther King Dr & 111th St', 5)
fix_dpcapacity('Kenneth Ave & 63rd St', 1, True)
fix_dpcapacity('Jeffery Blvd & 91st St', -1)
fix_dpcapacity('Public  Rack - Albany Ave & 63rd St', 1)
fix_dpcapacity('Justine St & 87th St', 1, True)
fix_dpcapacity('Public Rack - Perry Ave & 111th St', 1)
fix_dpcapacity('Vincennes Ave & 95th Pl', 1, True)
fix_dpcapacity('Public Rack - Ozark Ave & Addison St', 2)
fix_dpcapacity('Public Rack - Wood St & 103rd St', 1)
fix_dpcapacity('Bennett Ave & 79th St', 11)

# %%
for i in range(10):
    print(fix_dp_list[220:230][i])
# Out:
# Hamilton Park
# Public Rack - Damen Ave & 47th St
# Jeffery Blvd & 91st St
# Woodlawn Ave & 75th St
# Public Rack - Kildare Ave & Division St
# Damen Ave & 80th St
# Public Rack - Chase Ave & Touhy Ave - NW
# DuSable Lake Shore Dr & Ohio St
# Longwood Dr & 111th St
# Public Rack - Fairfield Ave & 63rd St

# %%
fix_dpcapacity('Elizabeth St & 47th St', 11)
fix_dpcapacity('Kostner Ave & 63rd St', 9)
fix_dpcapacity('Stony Island Ave & 86th St', 1, True)
fix_dpcapacity('Harlem Ave & Grace St', 9)
fix_dpcapacity('Panama Ave & Grace St', 9)
fix_dpcapacity('Public Rack - Kedzie Ave & 63rd St', 1)
fix_dpcapacity('Public Rack - Perry Ave & 108th Pl', 2)
fix_dpcapacity('Public Rack - Michigan Ave & 96th St', 3)
fix_dpcapacity('Halsted St & 94th St', 1, True)
fix_dpcapacity('Public Rack - 111th St - Morgan Park Metra', 2)

# %%
for i in range(10):
    print(fix_dp_list[230:240][i])
# Out:
# Michigan Ave & 119th St
# Central St Metra
# Public Rack - McCormick Blvd & Devon Ave
# Evans Ave & 75th St
# Woodlawn & 103rd - Olive Harvey
# State St & 47th st
# Public Rack - 63rd & Western Ave N
# May St & 69th St
# Austin Blvd & Madison St
# Public Rack - Menard Ave & Agusta Blvd

# %%
fix_dpcapacity('Kostner Ave & Adams St', 11)
fix_dpcapacity('Public Rack - California Ave & Pershing Rd', 10)
fix_dpcapacity('Public Rack - Maplewood Ave & 63rd St', 1)
fix_dpcapacity('Ellis Ave & 83rd St', 11)
fix_dpcapacity('Drexel Ave & 87th St', 1, True)
fix_dpcapacity('Bloomingdale Ave & Harlem Ave', 9)
fix_dpcapacity('Public Rack - Maplewood Ave & 47th St', 1)
fix_dpcapacity('Public Rack - Kedvale Ave & 26th St', 1)
fix_dpcapacity('Public Rack - Western Ave & 92nd Pl', 2)
fix_dpcapacity('Kilpatrick Ave & Parker Ave', 8)

# %%
for i in range(10):
    print(fix_dp_list[240:250][i])
# Out:
# Rainbow Beach
# Green St & Randolph St
# Leamington Ave & Hirsch St
# Public Rack - Kedzie Ave & 54th Pl
# Maryland Ave & 87th ST
# Public Rack - Kedvale Ave & Addison St
# Jeffery Blvd & 67th St
# Public Rack - Racine Ave & 76th
# Greenwood Ave & 91st St
# Racine Ave & 65th St

# %%
fix_dpcapacity('Shabbona Park', 1)
fix_dpcapacity('Public Rack - Linder Ave & Belmont Ave', 2)
fix_dpcapacity('Public Rack - Kedzie Ave & 61st Pl E', 1)
fix_dpcapacity('Long Ave & North Ave', 9)
fix_dpcapacity('Public Rack - Pulaski Rd & 51st Rd', 1)
fix_dpcapacity('Public Rack - Michigan Ave & 113th St', 1)
fix_dpcapacity('DuSable Lake Shore Dr & Ohio St', 21)
fix_dpcapacity('Public Rack - Laramie Ave & Belmont Ave', 2)
fix_dpcapacity('Public Rack - Green St & 103rd St', 1)
fix_dpcapacity('Back of the Yards Park', 1, True)

# %%
for i in range(10):
    print(fix_dp_list[250:260][i])
# Out:
# S Aberdeen St & W 106th St
# Winchester Ave & 87th St
# Public Rack - Laflin St & 51st St
# Lamon Ave & Armitage Ave
# Public Rack - Kedvale Ave & 26th St
# Harding Ave & 26th St
# Sacramento Blvd & Washington Blvd
# Public Rack - Western Ave & 98th St
# Public Rack - Emerald Ave & 43rd St
# Public Rack - Maplewood Ave & 63rd St

# %%
# 'City Rack - Albany Ave & 103rd St'
# --> 'Public Rack - Albany Ave & 103rd St'
merged2013_2022.loc[merged2013_2022['start_station_name'] == 'City Rack - Albany Ave & 103rd St', 'start_station_name'] = 'Public Rack - Albany Ave & 103rd St'
merged2013_2022.loc[merged2013_2022['end_station_name'] == 'City Rack - Albany Ave & 103rd St', 'end_station_name'] = 'Public Rack - Albany Ave & 103rd St'

fix_dpcapacity('Homewood Ave & 115th St', 13)
fix_dpcapacity('Public Rack - Albany Ave & 103rd St', 1)
fix_dpcapacity('Calumet Ave & 103rd St', 1, True)
fix_dpcapacity('Sawyer Ave & 111th St', 1, True)
fix_dpcapacity('Hale Ave & 107th St', 11)
fix_dpcapacity('Public Rack - Western Ave & 107th St', 1)
fix_dpcapacity('Public Rack - Hoyne Ave & 51st St', 2)
# Valli Produce - Evanston Plaza is in Evanston
fix_dpcapacity('Valli Produce - Evanston Plaza', 14)
fix_dpcapacity('Public Rack - Hyde Park Blvd & 55th St', 1)
# Central St Metra is in Evanston
fix_dpcapacity('Central St Metra', 15)

# %%
for i in range(10):
    print(fix_dp_list[260:270][i])
# Out:
# McClurg Ct & Illinois St
# Public Rack - Perry Ave & 108th Pl
# Public Rack - Cottage Grove Ave & 87th St
# Morgan St & Lake St
# Marshfield Ave & Cortland St
# Central Ave & Parker Ave
# Public Rack - Halsted St & 95th St - SW
# Justine St & 87th St
# Public Rack - Jeffery Blvd & 81st St
# Latrobe Ave & Chicago Ave

# %%
# 'Morgan St & Lake St' --> 'Morgan St & Lake St*'
merged2013_2022.loc[merged2013_2022['start_station_name'] == 'Morgan St & Lake St', 'start_station_name'] = 'Morgan St & Lake St*'
merged2013_2022.loc[merged2013_2022['end_station_name'] == 'Morgan St & Lake St', 'end_station_name'] = 'Morgan St & Lake St*'

fix_dpcapacity('Oketo Ave & Addison St', 9)
fix_dpcapacity('Lawler Ave & 50th St', 8)
fix_dpcapacity('N Hampden Ct & W Diversey Ave', 9)
fix_dpcapacity('Mozart St & Jackson Blvd', 5)
fix_dpcapacity('Public Rack - Langley Ave & 87th St', 1)
fix_dpcapacity('Morgan St & Lake St*', 18)
fix_dpcapacity('Campbell Ave & 51st St', 9)
fix_dpcapacity('Plainfield & Irving Park', 2, True)
fix_dpcapacity('Mason Ave & Belmont Ave', 8)
fix_dpcapacity('Public Rack - Ave L & 105th St', 1)

# %%
for i in range(10):
    print(fix_dp_list[270:280][i])
# Out:
# Troy St & Jackson Blvd
# Public Rack - Bell Ave & 95th St
# Public Rack - Springfield Ave & 63rd St
# Public Rack - Menard Ave & Belmont Ave
# Roscoe & Harlem
# Public Rack - Kostner Ave & 16th St
# Cottage Grove & 84th St
# Racine Ave & 61st St
# Public Rack - Kedzie Ave & 61st Pl E
# Public Rack - Ave L & 105th St

# %%
fix_dpcapacity('Public Rack - Austin Branch Chicago Public Library', 2)
fix_dpcapacity('Public Rack - Martin Luther King Dr & 44th St', 2)
fix_dpcapacity('Cottage Grove Ave & 83rd St', 13)
fix_dpcapacity('Public Rack - Foster Ave & Drake Ave', 2)
fix_dpcapacity('Halsted St & 41st St', 1, True)
fix_dpcapacity('Mulligan Ave & Wellington Ave', 9)
fix_dpcapacity('Kedzie Ave & 45th St', 5)
fix_dpcapacity('St Louis Ave & Norman Bobbins Ave', 9)
fix_dpcapacity('Torrence Ave & 106th St', 1, True)
fix_dpcapacity('Public Rack - Lockwood Ave & Diversey Ave', 4)

# %%
for i in range(10):
    print(fix_dp_list[280:290][i])
# Out:
# Public Rack - Pulaski Rd & 40th St
# Muskegon Ave & 89th St
# Public Rack - Western Ave & 96th St
# Public Rack - Harold Washington Park
# Martin Luther King Dr & 111th St
# Vincennes Ave & 75th St
# Washtenaw Ave & 63rd St
# Public Rack - Kostner Ave & North Ave
# Public Rack - Waller Ave & Chicago Ave
# Public Rack - Harriet E Sayre Public School

# %%
fix_dpcapacity('Honore St & 87th St - SE', 1, True)
fix_dpcapacity('Stony Is Ave & 73rd St', 2, True)
fix_dpcapacity('Damen Ave & 51st St', 7)
fix_dpcapacity('Central Park Ave & North Ave', 15)
fix_dpcapacity('Public Rack - Langley Ave & Oakwood Blvd', 2)
fix_dpcapacity('Pulaski Rd & Congress Pkwy', 10)
fix_dpcapacity('Leamington Ave & Hirsch St', 9)
fix_dpcapacity('Public Rack - Whipple St & 26th St', 2)
fix_dpcapacity('Public Rack - Washtenaw Ave & Devon Ave', 2)
fix_dpcapacity('Public Rack - Pullman Community Center', 1)

# %%
for i in range(10):
    print(fix_dp_list[290:300][i])
# Out:
# Stony Island Ave & 67th St
# Public Rack - Martin Luther King Dr & 69th St
# Public Rack - Kedzie Ave & 54th St - SE
# Ellis Ave & 83rd St
# Valli Produce - Evanston Plaza
# Ashland Ave & 69th St
# Cottage Grove Ave & 75th St
# Whipple St & Irving Park Rd
# Avenue J & 106th St
# Halsted St & 73rd St

# %%
# 'Lake Shore Dr & Monroe St' --> 'DuSable Lake Shore Dr & Monroe St'
merged2013_2022.loc[merged2013_2022['start_station_name'] == 'Lake Shore Dr & Monroe St', 'start_station_name'] = 'DuSable Lake Shore Dr & Monroe St'
merged2013_2022.loc[merged2013_2022['end_station_name'] == 'Lake Shore Dr & Monroe St', 'end_station_name'] = 'DuSable Lake Shore Dr & Monroe St'

fix_dpcapacity('DuSable Lake Shore Dr & Monroe St', 39)
fix_dpcapacity('Dauphin Ave & 103rd St', 15)
fix_dpcapacity('Public Rack - Ashland Ave & 45th St', 1)
fix_dpcapacity('Olive Harvey College', 15)
fix_dpcapacity('McClurg Ct & Illinois St', -1)
fix_dpcapacity('Public Rack - Tripp Ave & North Ave', 2)
fix_dpcapacity('Public Rack - Pullman - Walmart', 1)
fix_dpcapacity('Public Rack - Exchange Ave & 73rd Pl', 1)
fix_dpcapacity('Loomis St & 89th St', 15)
fix_dpcapacity('Central Ave & Chicago Ave', 11)

# %%
for i in range(10):
    print(fix_dp_list[300:310][i])
# Out:
# Public Rack - Stony Island & 95th St
# Sacramento Blvd & Fulton Ave
# Keeler Ave & Roosevelt Rd
# Menard Ave & North Ave
# Public Rack - Cottage Grove & 85th St
# Lake Shore Dr & Belmont Ave
# Public Rack - Eggleston Ave & 115th St
# Public Rack - Sawyer Ave & Bryn Mawr Ave - SE
# Major Taylor Trail & 115th St
# Public Rack - Saginaw Ave & 93rd St

# %%
fix_dpcapacity('Albany Ave & 103rd St', 1, True)
fix_dpcapacity('Public Rack - Pulaski Rd & Lake St', 1)
fix_dpcapacity('Public Rack - Wood St & 47th St', 1)
fix_dpcapacity('Fullerton & Monitor', 9)
fix_dpcapacity('Western & 28th - Velasquez Institute', -1)
fix_dpcapacity('Cicero Ave & Quincy St', 10)
fix_dpcapacity('Public Rack - Michigan Ave & 107th St', 1)
fix_dpcapacity('Evans Ave & 75th St', 7)
fix_dpcapacity('Menard Ave & North Ave', 9)
fix_dpcapacity('Brighton Park Branch Chicago Library', 2, True)

# %%
for i in range(10):
    print(fix_dp_list[310:320][i])
# Out:
# Public Rack - Spencer Elementary Technology Academy
# Public Rack - Menard Ave & Madison St
# Public Rack - Lake Shore Dr & Hayes Dr
# Public Rack - Pulaski Rd & 5th Ave
# Strohacker Park
# Public Rack - Chase Ave & Touhy Ave - NE
# Torrence Ave  & 106th St
# Avenue J & 112th St
# Central Park Ave & North Ave
# Public Rack - Homan Ave & 26th St

# %%
fix_dpcapacity('Public Rack - Ewing Ave & 105th St', 1)
fix_dpcapacity('Public Rack - Laramie Ave & Warwick Ave', 5)
fix_dpcapacity('Public Rack - California Ave & Touhy Ave - SW', 1)
fix_dpcapacity('Public Rack - Neva Ave & Grand Ave', 1)
fix_dpcapacity('Public Rack - Laflin St & 51st St', 2)
fix_dpcapacity('Halsted St & 73rd St', 15)
fix_dpcapacity('MLK Jr Dr & 83rd St', 10)
fix_dpcapacity('Ada St & 79th St', 2, True)
fix_dpcapacity('Public Rack - Cottage Grove Ave & 87th St', 1)
fix_dpcapacity('Public Rack - Buffalo Ave & 89th St', 3)

# %%
for i in range(10):
    print(fix_dp_list[320:330][i])
# Out:
# Oglesby Ave & 100th St
# Public Rack - Pulaski Rd & 65th St
# Christiana Ave & 55th St
# Public Rack - Kedzie Ave & Walnut St
# Public Rack - Mt Greenwood Library N
# Rhodes Ave & 71st St
# Public Rack - Western Ave & 100th St
# Public Rack - Avers Ave & Archer Ave
# Central Ave & Harrison St
# Public Rack - Morgan St & 95th St

# %%
# 'Wilton Ave & Diversey Pkwy - Charging'
# --> 'Wilton Ave & Diversey Pkwy'
merged2013_2022.loc[merged2013_2022['start_station_name'] == 'Wilton Ave & Diversey Pkwy - Charging', 'start_station_name'] = 'Wilton Ave & Diversey Pkwy'
merged2013_2022.loc[merged2013_2022['end_station_name'] == 'Wilton Ave & Diversey Pkwy - Charging', 'end_station_name'] = 'Wilton Ave & Diversey Pkwy'

fix_dpcapacity('Public Rack - Western Ave & 116th St', 1)
fix_dpcapacity('Corliss Ave & 133rd St', -1)
fix_dpcapacity('Lyft Driver Center Private Rack', -1)
fix_dpcapacity('Linder Ave & Archer Ave', -1)
fix_dpcapacity('Cicero Ave & Lake St', 11)
fix_dpcapacity('Austin Ave & Wellington Ave', 1, True)
fix_dpcapacity('Public Rack - 53rd St & Indiana Ave', 1)
fix_dpcapacity('Wilton Ave & Diversey Pkwy', 34)
fix_dpcapacity('Public Rack - Kostner Ave & 16th St', 1)
fix_dpcapacity('Michigan Ave & 102nd St', 1, True)

# %%
for i in range(10):
    print(fix_dp_list[330:340][i])
# Out:
# Public Rack - St Louis Ave & Berteau Ave
# Cicero Ave & Le Moyne St
# Wallace St & 112 St
# Lamon Ave & Belmont Ave
# Public Rack - May St & 78th St
# Public Rack - Lamon Ave & Erie St
# Public Rack - Ozark Ave & Addison St
# Avenue M & 132nd St
# Wabash Ave & 83rd St
# Honore St & 87th St - SE

# %%
# 'Lake Shore Dr & North Blvd'
# --> 'DuSable Lake Shore Dr & North Blvd'
merged2013_2022.loc[merged2013_2022['start_station_name'] == 'Lake Shore Dr & North Blvd', 'start_station_name'] = 'DuSable Lake Shore Dr & North Blvd'
merged2013_2022.loc[merged2013_2022['end_station_name'] == 'Lake Shore Dr & North Blvd', 'end_station_name'] = 'DuSable Lake Shore Dr & North Blvd'

fix_dpcapacity('Public Rack - Rutherford Ave & Belmont Ave', 1)
fix_dpcapacity('State St & Pershing Rd', 11)
fix_dpcapacity('Hoyne Ave & 34th St', 9)
fix_dpcapacity('Damen Ave & 80th St', 2, True)
fix_dpcapacity('Bensley Ave & 103rd St', 1, True)
fix_dpcapacity('Public Rack - Western Ave & 47th Pl', 2)
fix_dpcapacity('Public Rack - Western Ave & 96th St', 1)
fix_dpcapacity('Public Rack - Legler Regional Library', 2)
fix_dpcapacity('DuSable Lake Shore Dr & North Blvd', 38)
fix_dpcapacity('Public Rack - Grand Ave & Lawndale Ave', 2)

# %%
for i in range(10):
    print(fix_dp_list[340:350][i])
# Out:
# Kedzie Ave & 45th St
# State St & 76th St
# Public Rack - Fullerton Ave & Narragansett Ave
# Troy & 111th St
# Public Rack - Western Ave & 104th St - West
# Public Rack - Pulaski Rd & Polk St
# Harvard Ave & 103rd St
# Public Rack - Laporte Ave & Armitage Ave
# Lyft Driver Center Private Rack
# Public Rack - Central Park Ave & Fulton Blvd

# %%
# 'Lake Shore Dr & Belmont Ave'
# --> 'DuSable Lake Shore Dr & Belmont Ave'
merged2013_2022.loc[merged2013_2022['start_station_name'] == 'Lake Shore Dr & Belmont Ave', 'start_station_name'] = 'DuSable Lake Shore Dr & Belmont Ave'
merged2013_2022.loc[merged2013_2022['end_station_name'] == 'Lake Shore Dr & Belmont Ave', 'end_station_name'] = 'DuSable Lake Shore Dr & Belmont Ave'

fix_dpcapacity('Laramie Ave & Kinzie St', 9)
fix_dpcapacity('Public Rack - Jeffery Blvd & 81st St', 1)
fix_dpcapacity('Longwood Dr & 95th St', 1)
fix_dpcapacity('Elizabeth St & 92nd St', 15)
fix_dpcapacity('Public Rack - Cornell Ave & 87th Pl', 1)
fix_dpcapacity('Public Rack - Halsted St & 102nd St', 1)
fix_dpcapacity('State St & 54th St', 11)
fix_dpcapacity('Buffalo Ave & 133rd St', 2, True)
fix_dpcapacity('DuSable Lake Shore Dr & Belmont Ave', 19)
fix_dpcapacity('Public Rack - Kedvale Ave & 63rd St W', 2)

# %%
for i in range(10):
    print(fix_dp_list[350:360][i])
# Out:
# Central Park Ave & Douglas Blvd
# Troy St & Grace St
# Public Rack - Pulaski Rd & Flournoy St
# South Chicago Ave & Elliot Ave
# Public Rack - Lorel Ave & Grand Ave
# Public Rack - Peterson Ave & Bernard Ave
# Indiana Ave & 40th St
# Throop St & 58th St
# Public Rack - Laflin St & 51st ST
# Archer Park

# %%
fix_dpcapacity('Kedzie Ave & 110th St', 11)
fix_dpcapacity('Public Rack - Percy Julian HS', 3)
fix_dpcapacity('Public Rack - Cottage Grove & 86th St', 1)
fix_dpcapacity('Major Taylor Trail & 115th St', 15)
fix_dpcapacity('Public Rack - Pulaski Rd & 5th Ave', 1)
fix_dpcapacity('Laflin St & 79th St', 1, True)
fix_dpcapacity('Public Rack - Talman Ave & Pershing Rd', 2)
fix_dpcapacity('Public Rack - Richmond St & Thorndale Ave', 10)
fix_dpcapacity('Kedvale Ave & 63rd St', 2, True)
fix_dpcapacity('Public Rack - Chopin Park', 1)

# %%
for i in range(10):
    print(fix_dp_list[360:370][i])
# Out:
# Public Rack - Eli Whitney Public School
# Public Rack - Langley Ave & 87th St
# Dauphin Ave & 87th St
# Public Rack - Cottage Grove & 86th St
# Lowe Ave & 98th St
# Public Rack - Western Ave & 107th St
# Tripp Ave & 15th St
# Eggleston Ave & 114th St
# State St & 123rd St
# Public Rack - Parnell Ave & 103rd St

# %%
# 'Bissell St & Armitage Ave' 
# --> 'Bissell St & Armitage Ave*'
merged2013_2022.loc[merged2013_2022['start_station_name'] == 'Bissell St & Armitage Ave', 'start_station_name'] = 'Bissell St & Armitage Ave*'
merged2013_2022.loc[merged2013_2022['end_station_name'] == 'Bissell St & Armitage Ave', 'end_station_name'] = 'Bissell St & Armitage Ave*'

fix_dpcapacity('Public Rack - Lorel Ave & Grand Ave', 10)
fix_dpcapacity('Public Rack - Hamlin Ave & Grand Ave', 3)
fix_dpcapacity('Troy St & Jackson Blvd', 9)
fix_dpcapacity('Public Rack - Forrestville Ave & 47th St', 1)
fix_dpcapacity('Public Rack - Oketo Ave & Belmont Ave', 1)
fix_dpcapacity('Cicero Ave & Flournoy St', 10)
fix_dpcapacity('Bissell St & Armitage Ave*', 16)
fix_dpcapacity('Public Rack - Laflin St & 51st ST', 2)
fix_dpcapacity('Knox Ave & Montrose Ave', 11)
fix_dpcapacity('Public Rack - Cottage Grove Ave & 98th St', 1)

# %%
for i in range(10):
    print(fix_dp_list[370:380][i])
# Out:
# Public Rack - Menard Ave & Dakin St
# Public Rack - Ewing Ave & 95th St
# Kildare Ave & 55th St
# California Ave & 26th St
# Public Rack - Lawndale & 63rd St
# Houston Ave & 91st St
# Laramie Ave & Kinzie St
# Public Rack - Michigan Ave & 107th St
# City Rack - Albany Ave & 103rd St
# Meade Ave & Diversey Ave

# %%
fix_dpcapacity('Public Rack - Racine Ave & 76th', 2)
fix_dpcapacity('Eastlake Ter & Howard St', 14)
fix_dpcapacity('May St & 69th St', 11)
fix_dpcapacity('Central Park & Augusta Blvd', 9)
fix_dpcapacity('Torrence Ave & 98th St', 2, True)
fix_dpcapacity('Spaulding Ave & 63rd St', 2)
fix_dpcapacity('Western Ave & 79th St', 1, True)
fix_dpcapacity('N Clark St & W Elm St', 4)
fix_dpcapacity('Public Rack - Lawndale Ave & 63rd St', 1)
fix_dpcapacity('Public Rack - Sawyer Ave & Chicago Ave', 1)

# %%
for i in range(10):
    print(fix_dp_list[380:390][i])
# Out:
# Public Rack - Avers Ave & Ogden Ave
# S Wentworth Ave & W 111th St
# Public Rack - Michigan Ave & 96th St
# Public  Rack - Albany Ave & 63rd St
# William Rainey Harper High School
# WEST CHI-WATSON
# Public Rack - Martin Luther King Dr & 44th St
# Doty Ave & 111th St
# Sacramento Blvd & Polk St
# Austin Ave & Wellington Ave

# %%
fix_dpcapacity('Public Rack - Kedzie Ave & 62nd Pl', 1)
fix_dpcapacity('Public Rack - Sangamon St & 79th St', 1)
fix_dpcapacity('Lamon Ave & Chicago Ave', 9)
fix_dpcapacity('Troy St & Grace St', 8)
fix_dpcapacity('Vincennes Ave & 75th St', 6)
fix_dpcapacity('Public Rack - Langley Ave & 49th St', 3)
fix_dpcapacity('Public Rack - Kedzie Ave & 58th St', 1)
fix_dpcapacity('Public Rack - Commercial Ave & 89th St', 1)
fix_dpcapacity('Harding Ave & 26th St', 9)
fix_dpcapacity('Public Rack - Parnell Ave & 103rd St', 1)

# %%
for i in range(10):
    print(fix_dp_list[390:400][i])
# Out:
# Public Rack - Halsted St & 63rd St
# Calumet Ave & 71st St
# Public Rack - Roswell B. Mason Elementary School
# Torrence Ave & 98th St
# Public Rack - Lawndale Ave & 63rd St
# Public Rack - Kedvale Ave & 63rd St W
# Public Rack - Cottage Grove Ave & 89th Pl
# Public Rack - Lockwood Ave & Diversey Ave
# Public Rack - Linder Ave & Belmont Ave
# Public Rack - Pulaski & 52nd

# %%
fix_dpcapacity('Public Rack - Kedvale Ave & Avondale Ave', 1)
fix_dpcapacity('Public Rack - Paul Revere Elementary School', 3)
fix_dpcapacity('Tripp Ave & 31st St', 9)
fix_dpcapacity('Lamon Ave & Armitage Ave', 9)
fix_dpcapacity('Western Ave & 104th St', 15)
fix_dpcapacity('Roscoe & Harlem', 9)
fix_dpcapacity('Public Rack - 63rd & Western Ave N', 1)
fix_dpcapacity('Rockwell St & 57th St', 6)
fix_dpcapacity('Harvard Ave & 119th St', 1, True)
fix_dpcapacity('Kildare Ave & 47th St', 7)

# %%
for i in range(10):
    print(fix_dp_list[400:410][i])
# Out:
# Linder Ave & Archer Ave
# Kilpatrick Ave & Grand Ave
# Kostner Ave & Lake St
# MLK Jr Dr & 83rd St
# Ada St & 119th St
# Public Rack - Pulaski Rd & Fullerton Ave
# Public Rack - Hamlin Ave & Madison St
# Kedzie Ave & 110th St
# Public Rack - Laramie Ave & Fullerton Ave
# Public Rack - Lawndale Ave & Polk St

# %%
# 'Green St & Randolph St'
# --> 'Green St & Randolph St*'
merged2013_2022.loc[merged2013_2022['start_station_name'] == 'Green St & Randolph St', 'start_station_name'] = 'Green St & Randolph St*'
merged2013_2022.loc[merged2013_2022['end_station_name'] == 'Green St & Randolph St', 'end_station_name'] = 'Green St & Randolph St*'

fix_dpcapacity('Public Rack - Loomis Blvd & 83rd St', 1)
fix_dpcapacity('Oglesby Ave & 105th St', 1, True)
fix_dpcapacity('Public Rack - Kildare Ave & Division Ave', 1)
fix_dpcapacity('Greenwood Ave & 87th St', 1, True)
fix_dpcapacity('Normal Ave & 72nd St', 3, True)
fix_dpcapacity('Public Rack - California Ave & Touhy Ave - NW', 4)
fix_dpcapacity('Public Rack - Milwaukee Ave & Waveland Ave', 1)
fix_dpcapacity('Plainfield Ave & Irving Park Rd', 2)
fix_dpcapacity('Green St & Randolph St', 12)
fix_dpcapacity('Maplewood Ave & Peterson Ave', 11)

# %%
for i in range(10):
    print(fix_dp_list[410:420][i])
# Out:
# Oleander Ave & Addison St
# Francisco Ave & 47th St
# Public Rack - Kedzie Ave & 64th St - SE
# Avenue O & 118th St
# Public Rack - Kedzie Ave & 54th St - SW
# Public Rack - Komensky Ave & 63rd St
# Longwood Dr & 95th St
# Public Rack - Western Ave & 92nd Pl
# Yates Blvd & 93rd St
# Public Rack - Pulaski Rd & 51st Rd

# %%
# 'Ashland Ave & 45th St - mid'
# --> 'Public Rack - Ashland Ave & 45th St'
merged2013_2022.loc[merged2013_2022['start_station_name'] == 'Ashland Ave & 45th St - mid', 'start_station_name'] = 'Public Rack - Ashland Ave & 45th St'
merged2013_2022.loc[merged2013_2022['end_station_name'] == 'Ashland Ave & 45th St - mid', 'end_station_name'] = 'Public Rack - Ashland Ave & 45th St'

fix_dpcapacity('Princeton Ave & 43rd St', 2)
fix_dpcapacity('Public Rack - Harold Washington Park', 3)
fix_dpcapacity('Trumbull Ave & 111th St', 1)
fix_dpcapacity('Hamilton Park', 1, True)
fix_dpcapacity('Public Rack - Al Raby School', 3)
fix_dpcapacity('Rainbow Beach', 15)
fix_dpcapacity('Bishop St & 46th St', 1, True)
fix_dpcapacity('Public Rack - Ashland Ave & 45th St', 1, True)
fix_dpcapacity('Public Rack - Yates Ave & 100th St', 2)
fix_dpcapacity('Public Rack - Menard Ave & Agusta Blvd', 1)

# %%
for i in range(10):
    print(fix_dp_list[420:430][i])
# Out:
# State St & 54th St
# Brighton Park Branch Chicago Library
# Ashland Ave & 45th St - mid
# Public Rack - Homan Ave & Roosevelt
# Chicago Ave & Dempster St
# Ewing Ave & 99th St
# Public Rack - Lafayette Ave & 95th St
# Sacramento Ave & 25th St
# Public Rack - Oakley Ave & 50th Pl
# Public Rack - Sangamon St & 79th St

# %%
fix_dpcapacity('Public Rack - Western Ave & 110th St', 3)
fix_dpcapacity('Parnell Ave & 98th St', 2)
fix_dpcapacity('WEST CHI-WATSON', -1)
fix_dpcapacity('Public Rack - Fairfield Ave & 63rd St', 2)
fix_dpcapacity('Public Rack - Sawyer Ave & Lawrence Ave', 1)
fix_dpcapacity('Sacramento Blvd & Polk St', 9)
fix_dpcapacity('Maryland Ave & 87th ST', 1, True)
fix_dpcapacity('Sacramento Blvd & Washington Blvd', 2, True)
fix_dpcapacity('Public Rack - Kildare Ave & 63rd St', 2)
fix_dpcapacity('Oglesby Ave & 100th St', 15)

# %%
for i in range(10):
    print(fix_dp_list[430:440][i])
# Out:
# Public Rack - Austin Ave & Roscoe St
# Lafayette Ave & 87th St - NW
# Bensley Ave & 103rd St
# Public Rack - Cornell Ave & 87th Pl
# Loomis Blvd & 84th St
# California Ave & 36th St
# Public Rack - Chappel Ave & 71st St
# N Damen Ave & W Wabansia St
# Mackinaw Ave & 106th St
# Public Rack - Yates Ave & 100th St

# %%
fix_dpcapacity('Public Rack - Kenneth Ave & 63rd St E', 1)
fix_dpcapacity('Houston Ave & 91st St', 1, True)
fix_dpcapacity('Public Rack - Keeler Ave & 55th St', 1)
fix_dpcapacity('Public Rack - Laramie Ave & Grand Ave', 1)
fix_dpcapacity('Hale Ave & 111th St', 1, True)
fix_dpcapacity('Public Rack - Pulaski Rd & Flournoy St', 1)
fix_dpcapacity('Public Rack - Kedzie & 103rd St - W', 1)
fix_dpcapacity('Central Park Ave & 24th St', 11)
fix_dpcapacity('Public Rack - Central Park Ave & Fulton Blvd', 2)
fix_dpcapacity('Bennett Ave & 96th St', 2, True)

# %%
for i in range(10):
    print(fix_dp_list[440:450][i])
# Out:
# Lavergne & Fullerton
# Public Rack - Milwaukee Ave & Waveland Ave
# Major Taylor Trail & 124th St
# Public Rack - Sacramento Ave & Greenleaf Ave
# Public Rack - Rockwell Ave & Touhy Ave
# Public Rack - Abbott Park
# Evanston Civic Center
# Halsted St & 80th St
# Public Rack - Cottage Grove Ave & 92nd St
# Indiana Ave & 133rd St

# %%
fix_dpcapacity('Cornell Dr & Hayes Dr', 10)
fix_dpcapacity('Lafayette Ave & 87th St - SW', 1, True)
fix_dpcapacity('Public Rack - Homan Ave & Roosevelt', 1)
fix_dpcapacity('Public Rack - Crandon Ave & 80th St', 1)
fix_dpcapacity('Public Rack - Kedzie Ave & Arthington St', 1)
fix_dpcapacity('May St & 63rd St', 1, True)
fix_dpcapacity('California Ave & 26th St', 11)
fix_dpcapacity('Public Rack - Washington Park Ct & 51st St', 2)
fix_dpcapacity('Public Rack - Michele Clark Magnet High School', 2)
fix_dpcapacity('Public Rack - Pulaski Rd & Fullerton Ave', 2)

# %%
for i in range(10):
    print(fix_dp_list[450:460][i])
# Out:
# Greenwood Ave & 87th St
# Western Ave & 111th St - SE
# La Villita Park (Albany/30th)
# Western Ave & Gunnison St
# Menard Ave & Dakin St
# Lake Shore Dr & Diversey Pkwy
# Elizabeth St & 59th St
# Public Rack - Cicero Ave & North Ave
# Public Rack - Laramie Ave & Belmont Ave
# Public Rack - Hyde Park Blvd & 53rd St

# %%
fix_dpcapacity('Public Rack - Washtenaw Ave & Superior St', 5)
fix_dpcapacity('Newcastle Ave & Belden Ave', 1)
fix_dpcapacity('Ashland Ave & 46th St', 1, True)
fix_dpcapacity('Public Rack - Mackinaw Ave & 108th St', 1)
fix_dpcapacity('Public Rack - Laporte Ave & Armitage Ave', 1)
fix_dpcapacity('Public Rack - Komensky Ave & 26th St', 1)
fix_dpcapacity('Whipple St & Irving Park Rd', 8)
fix_dpcapacity('Tripp Ave & 65th St', 8)
fix_dpcapacity('Mt Greenwood Library - South', 2, True)
fix_dpcapacity('Newcastle Ave & Wellington Ave', 1, True)

# %%
for i in range(10):
    print(fix_dp_list[460:470][i])
# Out:
# Lincoln Ave & Peterson Ave
# Lawndale Ave & 16th St
# Long Ave & North Ave
# Pubic Rack - Pulaski Rd & 41st
# Mackinaw Ave & 85th St
# Hale Ave & 107th St
# Public Rack - Ewing Ave & 106th St
# Public Rack - Newcastle Ave & Belmont Ave
# Public Rack - California Ave & Pershing Rd
# Public Rack - Francisco Ave & Touhy Ave

# %%
# 'Lake Shore Dr & Diversey Pkwy'
# --> 'DuSable Lake Shore Dr & Diversey Pkwy'
merged2013_2022.loc[merged2013_2022['start_station_name'] == 'Lake Shore Dr & Diversey Pkwy', 'start_station_name'] = 'DuSable Lake Shore Dr & Diversey Pkwy'
merged2013_2022.loc[merged2013_2022['end_station_name'] == 'Lake Shore Dr & Diversey Pkwy', 'end_station_name'] = 'DuSable Lake Shore Dr & Diversey Pkwy'

fix_dpcapacity('Lake Park Ave & 44th St', 1, True)
fix_dpcapacity('DuSable Lake Shore Dr & Diversey Pkwy', 23)
fix_dpcapacity('Oglesby Ave & 95th St', 1, True)
fix_dpcapacity('S Wentworth Ave & W 111th St', 5)
fix_dpcapacity('Longwood Dr & 111th St', 2, True)
fix_dpcapacity('Ashland Ave & Pershing Rd', 9)
fix_dpcapacity('Public Rack - Kedzie Ave & 54th St - SW', 1)
fix_dpcapacity('Public Rack - Lorel Ave & Chicago Ave', 2)
fix_dpcapacity('Ingleside Ave & 79th St', 1, True)
fix_dpcapacity('Avenue M & 132nd St', 2, True)

# %%
for i in range(10):
    print(fix_dp_list[470:480][i])
# Out:
# Public Rack - Maplewood Ave & 47th St
# Harlem Ave & Grace St
# Steelworkers Park
# Carpenter St & 63rd St
# N Clark St & W Elm St
# Hamlin Ave & 62nd Pl
# Public Rack - Western Ave & 104th St - East
# Public Rack - Percy Julian HS
# Public Rack - Austin Blvd & North Ave
# Public Rack - 10557 S Western Ave

# %%
fix_dpcapacity('Public Rack - La Moyne Ave and Leamington Ave', 2)
# 'Chicago Ave & Sheridan Rd' is in Evanston
fix_dpcapacity('Chicago Ave & Sheridan Rd', 14)
fix_dpcapacity('Public Rack - Narragansett Ave & Fullerton Ave', 1)
fix_dpcapacity('Elizabeth St & 59th St', 7)
fix_dpcapacity('Public Rack - Colfax Ave & 83rd St', 2)
fix_dpcapacity('Ewing Ave & 112th St', 1, True)
fix_dpcapacity('Kilpatrick Ave & Grand Ave', 9)
fix_dpcapacity('Public Rack - Sacramento Blvd & Division St', -1)
fix_dpcapacity('Ada St & 117th St', 1, True)
fix_dpcapacity('Public Rack - Waller Ave & Chicago Ave', -1)

# %%
for i in range(10):
    print(fix_dp_list[480:490][i])
# Out:
# Laflin St & 79th St
# Central Ave & Lake St
# Public Rack - 83rd St (Avalon Park) Metra
# Kildare Ave & Chicago Ave
# Public Rack - Central Park Ave & 16th St
# Public Rack - Kostner Ave & Diversey Ave
# Public Rack - Cicero Ave & Roscoe St
# Public Rack - Sawyer Ave & Chicago Ave
# Maplewood Ave & 59th St
# Public Rack - Western Ave & 116th St

# %%
fix_dpcapacity('Orville T Bright School', 2, True)
fix_dpcapacity('Parkside Ave & Armitage Ave', 9)
fix_dpcapacity('Public Rack - Halsted St & 63rd St', 1)
# Public Rack - Harvey Ave & North Ave is in Oak Park
fix_dpcapacity('Public Rack - Harvey Ave & North Ave', 3)
fix_dpcapacity('Public Rack - Homan Ave & 26th St', 1)
fix_dpcapacity('Public Rack - Laramie Ave & Fullerton Ave', 2)
fix_dpcapacity('Public Rack - Cottage Grove Ave & 92nd St', 1)
fix_dpcapacity('Public Rack - Kilbourn Ave & Fullerton Ave', 5)
fix_dpcapacity('Calumet Ave & 71st St', 11)
fix_dpcapacity('Baltimore Ave & 133rd St', 2, True)

# %%
for i in range(10):
    print(fix_dp_list[490:500][i])
# Out:
# Vernon Ave & 79th St
# Public Rack - Pulaski Rd & Lake St
# Public Rack - Fullerton Ave & Lavergne Ave
# Public Rack - Kedzie Ave & 61st Pl W
# Albany Ave & 103rd St
# Public Rack - Kildare Ave & 63rd St
# Newcastle Ave & Belden Ave
# Public Rack - Tripp Ave & North Ave
# May St & 63rd St
# S Michigan Ave & E 118th St

# %%
fix_dpcapacity('Newland Ave & Diversey Ave', 1, True)
fix_dpcapacity('Public Rack - Burnside Academy', 2)
fix_dpcapacity('Calumet Park', -1)
fix_dpcapacity('Doty Ave & 111th St', 15)
fix_dpcapacity('Torrence Ave  & 106th St', 1)
fix_dpcapacity('Baltimore Ave & 132nd St', 1)
fix_dpcapacity('Public Rack - Cicero Ave & Altgeld St', 2)
fix_dpcapacity('Wolcott Ave & 61st St', 4, True)
fix_dpcapacity('Western Ave & 111th St - SW', 2, True)
fix_dpcapacity('Public Rack - Rockwell Ave & Touhy Ave ', 2)

# %%
for i in range(10):
    print(fix_dp_list[500:510][i])
# Out:
# Public Rack - Paxton Ave & 79th St
# Homan Ave & Fillmore St
# Public Rack - Michigan Ave & 113th St
# Public Rack - Kedzie Ave & 58th St
# Cornell Dr & Hayes Dr
# Public Rack - Western Ave & 106th St - East
# Michigan Ave & 110th St
# Rhodes Ave & 79th St
# Public Rack - Homan Ave & 111th St
# Public Rack - Roscoe St & Osceola Ave

# %%
fix_dpcapacity('Public Rack - Western Ave & 100th St', 2)
fix_dpcapacity('Public Rack - Prairie Ave & Garfield Blvd N', 1)
fix_dpcapacity('Public Rack - Austin Blvd & North Ave', 1)
fix_dpcapacity('Mason Ave & Roosevelt Rd', 1, True)
fix_dpcapacity('Wabash Ave & 83rd St', 11)
fix_dpcapacity('Steelworkers Park', 6)
fix_dpcapacity('Ada St & 119th St', 1, True)
fix_dpcapacity('Avenue O & 118th St', 1, True)
fix_dpcapacity('Public Rack - Paxton Ave & 79th St', 1)
fix_dpcapacity('Lake Shore Dr & Ohio St', -1)

# %%
for i in range(10):
    print(fix_dp_list[510:520][i])
# Out:
# Public Rack - Green St & 103rd St
# Spaulding Ave & 63rd St
# Lake Shore Dr & Monroe St
# Halsted St & 76th St
# Dauphin Ave & 103rd St
# Public Rack - Central Ave & Corcoran Pl
# Oglesby Ave & 105th St
# Public Rack - Jeffrey Blvd & 71st St
# Public Rack - Kenneth Ave & 63rd St E
# Public Rack - Kedzie & 103rd St - East

# %%
fix_dpcapacity('Public Rack - Kildare Ave & North Ave', 2)
fix_dpcapacity('Western Ave & Ardmore Ave', 9)
fix_dpcapacity('Public Rack - Stewart Ave & 123rd St', 4)
fix_dpcapacity('Public Rack - Stony Island & 87th St', 1)
fix_dpcapacity('Public Rack - Karlov Ave & 26th St', 1)            
fix_dpcapacity('Dauphin Ave & 87th St', 15)
fix_dpcapacity('Public Rack - Halsted St & 109th St', 1)
fix_dpcapacity('Public Rack - Kimbark Ave & 63rd St', 2)
fix_dpcapacity('Damen Ave & 74th St', 11)
fix_dpcapacity('Public Rack - Marshfield Ave & 45th St', 1)

# %%
for i in range(10):
    print(fix_dp_list[520:530][i])
# Out:
# Keeler Ave & Madison St
# Narragansett & Wrightwood
# Public Rack - Lawndale Ave & 23rd St
# Ewing Ave & Burnham Greenway
# Public Rack - California Ave & Touhy Ave - SW
# Central Ave & Congress Pkwy
# Public Rack - King Dr & 83rd St
# Loomis St & 89th St
# Cottage Grove Ave & 111th St
# Orville T Bright School

# %%
fix_dpcapacity('Public Rack - Western Ave & 118th St', 1)
fix_dpcapacity('Public Rack - Mozart Elementary School', 6)
fix_dpcapacity('Pubic Rack - Pulaski Rd & 41st', 4)
fix_dpcapacity('Public Rack - Avers Ave & Ogden Ave', 2)
fix_dpcapacity('Public Rack - Central Ave & North Ave', 1)
fix_dpcapacity('Indiana Ave & 40th St', 11)
fix_dpcapacity('Maryland Ave & 104th St', 10)
fix_dpcapacity('Halsted St & 76th St', 4)
fix_dpcapacity('Public Rack - Vincennes Ave & 95th St', 1)
fix_dpcapacity('Rhodes Ave & 71st St', 11)

# %%
for i in range(10):
    print(fix_dp_list[530:540][i])
# Out:
# Public Rack - Penn Elementary School / KIPP Ascend Middle School
# Public Rack - Christiana Ave & 111th St
# Public Rack - Evans Ave & 63rd St
# Public Rack - Commercial Ave & 89th St
# Yale Ave & 119th St
# Constance Ave & 95th St
# Public Rack - Sawyer Ave & Lawrence Ave
# Public Rack - Washington Park Ct & 51st St
# Public Rack - King Dr & 71st St
# Sawyer Ave & 111th St

# %%
fix_dpcapacity('Public Rack - Cicero Ave & Wrightwood Ave', 4)
fix_dpcapacity('Western Ave & 106th St - West', 1)
fix_dpcapacity('W 103rd St & S Avers Ave', 12)
fix_dpcapacity('Halsted St & 104th St', 15)
fix_dpcapacity('Public Rack - Walden Pkwy & 103rd St', 1)
fix_dpcapacity('Public Rack - Menard Ave & Madison St', 2)
fix_dpcapacity('Pullman - Ross Dress for Less', 1, True)
fix_dpcapacity('Ewing Ave & Indianapolis Ave', 1, True)
fix_dpcapacity('Public Rack - Pulaski Rd & 40th St', 2)
fix_dpcapacity('Marquette Ave & 79th St', 1, True)

# %%
for i in range(10):
    print(fix_dp_list[540:550][i])
# Out:
# Lincoln Ave & Roscoe St
# Ashland Ave & Pershing Rd
# Harvard Ave & 119th St
# Corliss Ave & 133rd St
# Public Rack - Exchange Ave & 73rd Pl
# Public Rack - Piotrowski Park
# Bennett Ave & 79th St
# Public Rack - Menard Ave & Grand Ave
# Millard Ave & 26th St
# Public Rack - California Ave & Touhy Ave - NW

# %%
fix_dpcapacity('Public Rack - Central Ave & George St', 1)
fix_dpcapacity('Public Rack - Cicero Ave & Cortland St', 1)
fix_dpcapacity('Western Ave & 62nd St', 2)
fix_dpcapacity('Public Rack - Homan Ave & 111th St', 1)
fix_dpcapacity('Public Rack - Menard Ave & Dakin St', 2)
fix_dpcapacity('Tuley (Murray) Park', 2, True)
fix_dpcapacity('Public Rack - Halsted St & 95th St - SW', 1)
fix_dpcapacity('Lafayette Ave & 87th St - NW', 1, True)
fix_dpcapacity('Public Rack - Roswell B. Mason Elementary School', 4)
fix_dpcapacity('S Michigan Ave & E 118th St', 6)

# %%
for i in range(10):
    print(fix_dp_list[550:560][i])
# Out:
# Public Rack - Kildare Ave & North Ave
# Halsted St & 94th St
# Kenneth Ave & 63rd St
# 10101 S Stony Island Ave
# Halsted St & 69th St
# Public Rack - Colfax Ave & 83rd St
# Public Rack - Laramie Ave & Warwick Ave
# Public Rack - Marshfield Ave & 87th St
# Public Rack - Michele Clark Magnet High School
# Mason Ave & Belmont Ave

# %%
fix_dpcapacity('Public Rack - Drake Ave & Leland Ave', 2)
fix_dpcapacity('Public Rack - Hyde Park Blvd & 53rd St', 6)
fix_dpcapacity('Public Rack - Christiana Ave & Bryn Mawr Ave', 1)
fix_dpcapacity('Avenue L & 114th St', -1)
fix_dpcapacity('State St & 47th st', 2, True)
fix_dpcapacity('Public Rack - Abbott Park', 2)
fix_dpcapacity('Ewing Ave & 99th St', 1, True)
fix_dpcapacity('Public Rack - Fullerton Ave & Narragansett Ave', 1)
fix_dpcapacity('California Ave & 36th St', 9)
fix_dpcapacity('Public Rack - Keystone Ave & North Ave', 1)

# %%
for i in range(10):
    print(fix_dp_list[560:570][i])
# Out:
# Karlov Ave & Madison St
# Big Marsh Park
# Public Rack - Pulaski Rd & Grenshaw St
# Tuley (Murray) Park
# Francisco Ave & Hollywood Ave
# Public Rack - Kedvale Ave & Avondale Ave
# Homewood Ave & 115th St
# Public Rack - King Dr & 115th St
# Long & Irving Park
# Public Rack - La Moyne Ave and Leamington Ave

# %%
fix_dpcapacity('Public Rack - Lawndale Ave & 23rd St', 2)
fix_dpcapacity('Public Rack - Kostner Ave & Diversey Ave', 1)
fix_dpcapacity('Public Rack - Leclaire Ave & Division St', 1)
fix_dpcapacity('Public Rack - Roscoe St & Osceola Ave', 1)
# 'Elmwood Ave & Austin St' is in Evanston
fix_dpcapacity('Elmwood Ave & Austin St', 15)
fix_dpcapacity('Public Rack - Vincennes Ave & 77th St', 1)
fix_dpcapacity('Public Rack - Christiana Ave & 111th St', 1)
fix_dpcapacity('Public Rack - Austin Ave & Roscoe St', 5)
fix_dpcapacity('Public Rack - Wallace St & 119th St', 1)
fix_dpcapacity('Public Rack - Western Ave & Devon Ave', 2)

# %%
for i in range(10):
    print(fix_dp_list[570:580][i])
# Out:
# Western Ave & 28th St
# Public Rack - Ewing Ave & 107th St
# Back of the Yards Park
# Public Rack - Albany Ave & 111th St - NW
# Public Rack - Menard Ave & Adams Blvd
# Public Rack - Pullman Community Center
# Lake Shore Dr & Wellington Ave
# Wilton Ave & Diversey Pkwy - Charging
# Greenwood Ave & 97th St
# Public Rack - West Chatham Park

# %%
fix_dpcapacity('Greenwood Ave & 91st St', 15)
fix_dpcapacity('Artesian Ave & 55th St', 12)
fix_dpcapacity('Public Rack - Kedzie Ave & 61st Pl W', 1)
fix_dpcapacity('Big Marsh Park', 12)
fix_dpcapacity('Public Rack - Western Ave & 104th St - West', 2)
fix_dpcapacity('Public Rack - Kedzie Ave & 54th Pl', 1)
fix_dpcapacity('Keeler Ave & Roosevelt Rd', 9)
fix_dpcapacity('Public Rack - Peterson Ave & Bernard Ave', 1)
fix_dpcapacity('Public Rack - Menard Ave & Adams Blvd', 2)
fix_dpcapacity('Meade Ave & Diversey Ave', 9)

# %%
for i in range(10):
    print(fix_dp_list[580:590][i])
# Out:
# Public Rack - Central Park Ave & Fillmore St
# Ada St & 79th St
# Commercial Ave & 100th St
# California Ave & 29th St
# Lawrence Ave & 103rd St
# Public Rack - 111th St - Morgan Park Metra
# Public Rack - Kedzie Ave & Pershing Rd
# Public Rack - Narragansett Ave & Fullerton Ave
# N Hampden Ct & W Diversey Ave
# Campbell Ave & 51st St

# %%
fix_dpcapacity('Public Rack - Melvina Ave & Belmont Ave', 1)
fix_dpcapacity('Public Rack - Sawyer Ave & Bryn Mawr Ave - SW', 1)
fix_dpcapacity('Halsted St & 69th St', 10)
fix_dpcapacity('Public Rack - Cottage Grove Ave & 89th Pl', 1)
fix_dpcapacity('La Villita Park (Albany/30th)', 9)
fix_dpcapacity('Public Rack - Marshfield Ave & 87th St', 1)
fix_dpcapacity('Public Rack - Kedvale Ave & Addison St', 2)
fix_dpcapacity('Ashland Ave & 69th St', -1)
fix_dpcapacity('Exchange Ave & 79th St', 11)
fix_dpcapacity('Public Rack - Keystone Ave & Irving Park Rd', 2)

# %%
for i in range(10):
    print(fix_dp_list[590:600][i])
# Out:
# Plainfield Ave & Irving Park Rd
# Public Rack - Christiana Ave & Bryn Mawr Ave
# Elmwood Ave & Austin St
# Shabbona Park
# Public Rack - Western Ave & Devon Ave
# Lake Shore Dr & Ohio St
# Public Rack - Cicero Ave & Cortland St
# Public Rack - Kostner Ave & Wrightwood Ave
# Bennett Ave & 96th St
# Western Ave & 79th St

# %%
fix_dpcapacity('Public Rack - California Ave & Devon Ave - NW', 1)
fix_dpcapacity('Menard Ave & Division St', 9)
fix_dpcapacity('Marshfield Ave & Cortland St', -1)
fix_dpcapacity('Warren Park East', 11)
fix_dpcapacity('Western Ave & 28th St', 11)
fix_dpcapacity('Public Rack - Penn Elementary School / KIPP Ascend Middle School', 4)
fix_dpcapacity('Dodge Ave & Mulford St', 15)
fix_dpcapacity('Public Rack - Fullerton Ave & Lavergne Ave', 1)
fix_dpcapacity('Langley Ave & 105th Pl', 2)
fix_dpcapacity('Public Rack - Latrobe Ave & Lake St', 1)

# %%
for i in range(10):
    print(fix_dp_list[600:][i])
# Out:
# Eastlake Ter & Howard St
# Public Rack - Ashland Ave & 91st St
# Public Rack - Stewart Ave & 123rd St
# Richmond St & 59th St
# Public Rack - Kedzie Ave & Archer Ave
# Archer (Damen) Ave & 37th St
# Lake Shore Dr & North Blvd
# Lavergne Ave & Division St
# Rockwell St & 57th St
# Ewing Ave & 112th St

# %%
fix_dpcapacity('Public Rack - Austin Ave & Wellington Ave', 1)
fix_dpcapacity('Public Rack - Ewing Ave & 96th St N', 1)
fix_dpcapacity('Public Rack - Eli Whitney Public School', 1)
fix_dpcapacity('Burling St (Halsted) & Diversey Pkwy', -1)
fix_dpcapacity('Public Rack - Milwaukee Ave & School St', 1)
fix_dpcapacity('Michigan Ave & 119th St', 1, True)
fix_dpcapacity('Public Rack - Martin Luther King Dr & 69th St', 1)
fix_dpcapacity('Parnell Ave & 119th St', 1, True)
fix_dpcapacity('Yale Ave & 119th St', 1, True)
fix_dpcapacity('Racine Ave & 65th St', 11)

# %%
# Evanston: 1
Evanston_l = ['Chicage Ave & Dempster St', 'Valli Produce - Evanston Plaza', 'Central St Metra', 'Chicago Ave & Sheridan Rd',
'Elmwood Ave & Austin St']

for i in range(len(Evanston_l)):
    merged2013_2022.loc[merged2013_2022['start_station_name'] == Evanston_l[i], 'start_city'] = 1
    merged2013_2022.loc[merged2013_2022['end_station_name'] == Evanston_l[i], 'end_city'] = 1

# %%
# Oak Park: 2
Oak_Park_l = ['Oak Park & Wellington', 'Public Rack - Harvey Ave & North Ave']

for i in range(len(Oak_Park_l)):
    merged2013_2022.loc[merged2013_2022['start_station_name'] == Oak_Park_l[i], 'start_city'] = 2
    merged2013_2022.loc[merged2013_2022['end_station_name'] == Oak_Park_l[i], 'end_city'] = 2

# %%
x = Evanston_l + Oak_Park_l
for i in range(len(x)):
    confirmed_list.append(x[i])

# %%
merged2013_2022.dtypes
# Out:
# start_time             object
# end_time               object
# tripduration            int64
# start_station_id       object
# start_station_name     object
# end_station_id         object
# end_station_name       object
# usertype                int64
# gender                  int64
# birthyear               int64
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# rideable_type           int64
# start_city              int64
# start_landmark          int64
# end_city                int64
# end_landmark            int64
# start_date             object
# end_date               object
# start_dpcapacity        int64
# end_dpcapacity          int64
# dtype: object

# %%
check_these = list(set(list(merged2013_2022[merged2013_2022['start_dpcapacity'] == -1]['start_station_name'].values) + list(merged2013_2022[merged2013_2022['end_dpcapacity'] == -1]['end_station_name'].values)))

# %%
check_these
# Out:
# ['Public Rack - Sacramento Blvd & Division St',
#  'Jeffery Blvd & 91st St',
#  'Divvy Valet - Oakwood Beach',
#  'Corliss Ave & 133rd St',
#  'DIVVY CASSETTE REPAIR MOBILE STATION',
#  'Chicago Ave & Dempster St',
#  'Avenue L & 114th St',
#  'Public Rack - Waller Ave & Chicago Ave',
#  'Linder Ave & Archer Ave',
#  'Lake Shore Dr & Ohio St',
#  'Burling St (Halsted) & Diversey Pkwy',
#  'Western & 28th - Velasquez Institute',
#  'Ashland Ave & 69th St',
#  'Lyft Driver Center Private Rack',
#  'McClurg Ct & Illinois St',
#  'Calumet Park',
#  'Marshfield Ave & Cortland St',
#  'Lamon Ave & Archer Ave',
#  'WEST CHI-WATSON']

# %%
# All of the following will be choices that I will make on what to do with the above station names because they are not
# find-able through google maps or divvy's website

# %%
# 'Ashland Ave & 69th St' should be aggregated to 'Public Rack - Ashland Ave & 71st St', Chicago, IL 60636

# %%
# get id then deal with it
merged2013_2022[merged2013_2022['start_station_name'] == 'Public Rack - Ashland Ave & 71st St']
# Out:
#          start_time  end_time  tripduration start_station_id  \
# 12386502   13:12:07  13:39:53          1666              742
# 18436091   16:05:20  16:46:12          2452              742
# 19187633   16:21:24  16:27:54           390              742
# 20883816   16:53:52  17:00:10           378              742
# 28694688   19:25:57  19:36:31           634              742
#
#                            start_station_name end_station_id  \
# 12386502  Public Rack - Ashland Ave & 71st St            585
# 18436091  Public Rack - Ashland Ave & 71st St            585
# 19187633  Public Rack - Ashland Ave & 71st St           1197
# 20883816  Public Rack - Ashland Ave & 71st St            679
# 28694688  Public Rack - Ashland Ave & 71st St           1145
#
#                             end_station_name  usertype  gender  birthyear  \
# 12386502         Cottage Grove Ave & 83rd St         1      -1          0
# 18436091         Cottage Grove Ave & 83rd St         1      -1          0
# ...

# %%
merged2013_2022.loc[merged2013_2022['start_station_name'] == 'Ashland Ave & 69th St', 'start_station_id'] = 742
merged2013_2022.loc[merged2013_2022['end_station_name'] == 'Ashland Ave & 69th St', 'end_station_id'] = 742
merged2013_2022.loc[merged2013_2022['start_station_name'] == 'Ashland Ave & 69th St', 'start_station_name'] = 'Public Rack - Ashland Ave & 71st St'
merged2013_2022.loc[merged2013_2022['end_station_name'] == 'Ashland Ave & 69th St', 'end_station_name'] = 'Public Rack - Ashland Ave & 71st St'

# %%
# Avenue L & 114th St needs investigation, potential deletion
merged2013_2022[merged2013_2022['start_station_name'] == 'Avenue L & 114th St']
# Out:
#          start_time  end_time  tripduration start_station_id  \
# 250562     00:47:03  01:02:27           924            20220
# 724381     04:52:05  04:53:49           104            20220
# 7301846    10:14:24  10:19:38           314            20220
# 8132688    10:51:30  11:00:54           564            20220
# 8150576    10:52:10  10:58:27           377            20220
# 8639930    11:12:27  11:17:43           316            20220
# 10041595   12:00:43  12:43:05          2542            20220
# 10108188   12:02:54  12:24:30          1296            20220
# 13085572   13:33:16  14:09:35          2179            20220
# 13959456   13:59:55  14:54:52          3297            20220
# 14119141   14:04:51  14:55:23          3032            20220
# 15238859   14:38:41  15:00:21          1300            20220
# 15698132   14:52:26  15:31:47          2361            20220
# 15731265   14:53:25  14:53:41            16            20220
# ...

# %%
merged2013_2022[merged2013_2022['end_station_name'] == 'Avenue L & 114th St']
# Out:
#          start_time  end_time  tripduration start_station_id  \
# 225002     00:41:09  01:07:08          1559              707
# 627473     03:19:04  04:51:13          5529            20219
# 724381     04:52:05  04:53:49           104            20220
# 6185398    09:21:24  09:42:37          1273              722
# 7451088    10:21:27  10:27:18           351             1074
# 8037762    10:47:35  10:51:06           211              771
# 8132688    10:51:30  11:00:54           564            20220
# 9689300    11:49:28  11:57:00           452              710
# 10108188   12:02:54  12:24:30          1296            20220
# 13959456   13:59:55  14:54:52          3297            20220
# 14119141   14:04:51  14:55:23          3032            20220
# 15099370   14:34:24  14:47:45           801              707
# 15698132   14:52:26  15:31:47          2361            20220
# 15731265   14:53:25  14:53:41            16            20220
# ...

# %%
# Avenue L & 114th St will be given a dpcapacity of 1, because it is so low use but doesn't have a comparable
fix_dpcapacity('Avenue L & 114th St', 1)

# %%
# Burling St (Halsted) & Diversey Pkwy needs to be checked if there is a duplicate
fix_dpcapacity('Burling St (Halsted) & Diversey Pkwy', 19)

# %%
merged2013_2022[merged2013_2022['end_station_name'] == 'Burling St (Halsted) & Diversey Pkwy']
# Out:
#          start_time  end_time  tripduration start_station_id  \
# 2487       00:00:13  00:06:25           372              144
# 3477       00:00:26  00:06:28           362              144
# 3778       00:00:30  00:15:12           882              141
# 4084       00:00:34  00:12:32           718              289
# 4391       00:00:38  00:20:07          1169              290
# ...             ...       ...           ...              ...
# 33127220   23:57:22  00:16:33          1150              145
# 33128864   23:57:42  00:12:18           876     KA1504000134
# 33135832   23:58:47  00:03:15           268     TA1307000134
# 33138404   23:59:03  00:08:52           589              229
# 33142249   23:59:51  00:08:34           523              143
#
#                            start_station_name end_station_id  \
# 2487                Larrabee St & Webster Ave            456
# 3477                Larrabee St & Webster Ave            456
# ...

# %%
merged2013_2022[merged2013_2022['end_station_name'] == 'Burling St & Diversey Pkwy']
# Out:
#          start_time  end_time  tripduration start_station_id  \
# 163        00:00:00  00:20:00          1239              347
# 233        00:00:00  00:08:00           472     TA1309000019
# 309        00:00:00  00:46:00          2754              197
# 403        00:00:00  00:28:00          1661               53
# 693        00:00:00  00:04:00           226     TA1307000052
# ...             ...       ...           ...              ...
# 33141212   23:59:37  00:05:47           369     TA1307000134
# 33141820   23:59:46  00:13:02           796     TA1307000149
# 33141962   23:59:47  00:20:20          1232              238
# 33142135   23:59:49  00:06:05           375     TA1307000006
# 33142609   23:59:55  00:15:17           921              113
#
#                                start_station_name end_station_id  \
# 163                        Ashland Ave & Grace St            332
# 233                 Lakeview Ave & Fullerton Pkwy            332
# ...

# %%
# As I suspected, it is a repeat, so I will the repeat to end_station_id: 332 and station_name: Burling St & Diversey Pkwy

merged2013_2022.loc[merged2013_2022['start_station_name'] == 'Burling St (Halsted) & Diversey Pkwy', 'start_station_id'] = 332
merged2013_2022.loc[merged2013_2022['end_station_name'] == 'Burling St (Halsted) & Diversey Pkwy', 'end_station_id'] = 332
merged2013_2022.loc[merged2013_2022['start_station_name'] == 'Burling St (Halsted) & Diversey Pkwy', 'start_station_name'] = 'Burling St & Diversey Pkwy'
merged2013_2022.loc[merged2013_2022['end_station_name'] == 'Burling St (Halsted) & Diversey Pkwy', 'end_station_name'] = 'Burling St & Diversey Pkwy'

# %%
# 'Calumet Park' : (Google Code): PF79+FM Chicago, Illinois, 15 dpcapacity
fix_dpcapacity('Calumet Park', 15)

# %%
# 'Chicago Ave & Dempster St' there is no station here according to divvy, will check
merged2013_2022[merged2013_2022['end_station_name'] == 'Chicago Ave & Dempster St']
# Out:
#          start_time  end_time  tripduration start_station_id  \
# 21955      00:03:24  00:23:36          1212              523
# 22795      00:03:34  00:24:21          1247              523
# 39727      00:06:10  00:51:23          2713     TA1309000018
# 89974      00:14:42  01:00:47          2765              517
# 99892      00:16:25  00:21:03           278              596
# ...             ...       ...           ...              ...
# 33089878   23:51:45  23:56:12           266              596
# 33090246   23:51:49  00:39:09          2839             E011
# 33094096   23:52:16  00:41:31          2954              210
# 33096938   23:52:50  00:00:19           449              604
# 33125338   23:57:00  01:13:41          4600     KA1503000043
#
#                     start_station_name end_station_id  \
# 21955        Eastlake Ter & Rogers Ave           E011
# 22795        Eastlake Ter & Rogers Ave           E011
# 39727     Ravenswood Ave & Berteau Ave           E011
# ...

# %%
# Had to look at 2017-2019 google maps street view to find station, is not listed on divvy site or through basic google maps
# search. dpcapacity: 15
fix_dpcapacity('Chicago Ave & Dempster St', 15)
# Also, Evanston
merged2013_2022.loc[merged2013_2022['start_station_name'] == 'Chicago Ave & Dempster St', 'start_city'] = 2
merged2013_2022.loc[merged2013_2022['end_station_name'] == 'Chicago Ave & Dempster St', 'end_city'] = 2

# %%
# 'Corliss Ave & 133rd St' doesn't exist, continue to search
merged2013_2022[merged2013_2022['start_station_name'] == 'Corliss Ave & 133rd St']
# Out:
#          start_time  end_time  tripduration start_station_id  \
# 27785536   19:00:19  21:23:04          8565              870
#
#               start_station_name end_station_id      end_station_name  \
# 27785536  Corliss Ave & 133rd St            871  Ellis Ave & 132nd Pl
#
#           usertype  gender  birthyear  ...  end_lng  rideable_type  \
# 27785536         0      -1          0  ...    -87.6              2
#
#           start_city  start_landmark  end_city  end_landmark  start_date  \
# 27785536           0               0         0             0  2022-08-02
#
#             end_date  start_dpcapacity end_dpcapacity
# 27785536  2022-08-02                -1              0
#
# [1 rows x 23 columns]

# %%
merged2013_2022[merged2013_2022['end_station_name'] == 'Corliss Ave & 133rd St']
# Out:
#        start_time  end_time  tripduration start_station_id  \
# 532480   02:17:21  02:59:43          2542              695
#
#             start_station_name end_station_id        end_station_name  \
# 532480  Dauphin Ave & 103rd St            870  Corliss Ave & 133rd St
#
#         usertype  gender  birthyear  ...  end_lng  rideable_type  start_city  \
# 532480         0      -1          0  ...    -87.6              2           0
#
#         start_landmark  end_city  end_landmark  start_date    end_date  \
# 532480               0         0             0  2022-07-12  2022-07-12
#
#         start_dpcapacity end_dpcapacity
# 532480                15             -1
#
# [1 rows x 23 columns]

# %%
# Delete: 'Corliss Ave & 133rd St'
index1 = list(set(list(merged2013_2022[merged2013_2022['start_station_name'] == 'Corliss Ave & 133rd St'].index) + list(merged2013_2022[merged2013_2022['end_station_name'] == 'Corliss Ave & 133rd St'].index)))

# %%
# Delete: 'DIVVY CASSETTE REPAIR MOBILE STATION',
index2 = list(set(list(merged2013_2022[merged2013_2022['start_station_name'] == 'DIVVY CASSETTE REPAIR MOBILE STATION'].index) + list(merged2013_2022[merged2013_2022['end_station_name'] == 'DIVVY CASSETTE REPAIR MOBILE STATION'].index)))

# %%
# Couldn't find 'Divvy Valet - Oakwood Beach', delete it
index3 = list(set(list(merged2013_2022[merged2013_2022['start_station_name'] == 'Divvy Valet - Oakwood Beach'].index) + list(merged2013_2022[merged2013_2022['end_station_name'] == 'Divvy Valet - Oakwood Beach'].index)))

# %%
# Can't find 'Jeffery Blvd & 91st St' on google maps with street view or through divvy website
merged2013_2022[merged2013_2022['start_station_name'] == 'Jeffery Blvd & 91st St']
# Out:
#          start_time  end_time  tripduration start_station_id  \
# 5363706    08:50:46  08:55:40           294              734
# 8542541    11:08:36  11:37:15          1719              734
# 8564681    11:09:27  11:37:32          1685              734
# 9626276    11:47:31  12:13:36          1565              734
# 10190749   12:05:21  13:57:01          6700              734
# 10191905   12:05:24  12:41:08          2144              734
# 10560558   12:16:46  12:54:50          2284              734
# 15788318   14:55:02  15:52:01          3419              734
# 16126751   15:05:01  15:11:32           391              734
# 16903480   15:26:21  16:39:16          4375              734
# 25514258   18:09:38  18:10:49            71              734
# 25669984   18:12:38  18:27:35           897              734
# 26390314   18:27:02  18:56:10          1748              734
#
#               start_station_name end_station_id  \
# 5363706   Jeffery Blvd & 91st St            734
# ...

# %%
merged2013_2022[merged2013_2022['end_station_name'] == 'Jeffery Blvd & 91st St']
# Out:
#          start_time  end_time  tripduration start_station_id  \
# 3588177    08:02:46  08:15:21           755              690
# 5363706    08:50:46  08:55:40           294              734
# 8542541    11:08:36  11:37:15          1719              734
# 8564681    11:09:27  11:37:32          1685              734
# 9626276    11:47:31  12:13:36          1565              734
# 10190749   12:05:21  13:57:01          6700              734
# 10191905   12:05:24  12:41:08          2144              734
# 10423939   12:12:32  12:50:52          2300              686
# 10560558   12:16:46  12:54:50          2284              734
# 15906022   14:58:44  15:04:21           337              701
# 16903480   15:26:21  16:39:16          4375              734
# 24937594   17:58:49  18:08:30           581              701
# 25514258   18:09:38  18:10:49            71              734
# 32858542   23:21:01  23:34:40           819     KA1503000018
#
# ...

# %%
# Delete 'Jeffery Blvd & 91st St'
index4 = list(set(list(merged2013_2022[merged2013_2022['start_station_name'] == 'Jeffery Blvd & 91st St'].index) + list(merged2013_2022[merged2013_2022['end_station_name'] == 'Jeffery Blvd & 91st St'].index)))

# %%
# Look into if 'Lake Shore Dr & Ohio St' is a repeat
merged2013_2022[merged2013_2022['start_station_name'] == 'Lake Shore Dr & Ohio St']
# Out:
#          start_time  end_time  tripduration start_station_id  \
# 39         00:00:00  00:26:00          1554     TA1306000029
# 76         00:00:00  00:13:00           766     TA1306000029
# 77         00:00:00  00:13:00           760     TA1306000029
# 249        00:00:00  00:11:00           653     TA1306000029
# 344        00:00:00  00:24:00          1476     TA1306000029
# ...             ...       ...           ...              ...
# 33141473   23:59:41  00:19:20          1178     TA1306000029
# 33141509   23:59:42  00:25:34          1552     TA1306000029
# 33142071   23:59:49  00:43:27          2619     TA1306000029
# 33142651   23:59:56  00:25:52          1556     TA1306000029
# 33142858   23:59:58  00:19:18          1159     TA1306000029
#
#                start_station_name end_station_id  \
# 39        Lake Shore Dr & Ohio St             47
# 76        Lake Shore Dr & Ohio St   TA1307000039
# 77        Lake Shore Dr & Ohio St   TA1307000039
# ...

# %%
merged2013_2022[merged2013_2022['start_station_name'] == 'DuSable Lake Shore Dr & Ohio St']
# Out:
#          start_time  end_time  tripduration start_station_id  \
# 2131       00:00:08  00:15:33           925     TA1306000030
# 3421       00:00:25  00:18:38          1093     TA1306000030
# 3801       00:00:30  00:15:41           911     TA1306000030
# 4267       00:00:36  01:58:28          7072     TA1306000030
# 8129       00:01:06  00:15:41           875     TA1306000030
# ...             ...       ...           ...              ...
# 33140367   23:59:27  00:46:42          2834     TA1306000030
# 33140869   23:59:33  01:54:06          6872     TA1306000030
# 33141798   23:59:45  00:18:40          1134     TA1306000030
# 33142042   23:59:48  00:42:28          2559     TA1306000030
# 33142611   23:59:55  01:12:19          4343     TA1306000030
#
#                        start_station_name end_station_id  \
# 2131      DuSable Lake Shore Dr & Ohio St             90
# 3421      DuSable Lake Shore Dr & Ohio St             74
# 3801      DuSable Lake Shore Dr & Ohio St             90
# ...

# %%
# 'Lake Shore Dr & Ohio St' --> 'DuSable Lake Shore Dr & Ohio St'
merged2013_2022.loc[merged2013_2022['start_station_name'] == 'Lake Shore Dr & Ohio St', 'start_station_name'] = 'DuSable Lake Shore Dr & Ohio St'
merged2013_2022.loc[merged2013_2022['end_station_name'] == 'Lake Shore Dr & Ohio St', 'end_station_name'] = 'DuSable Lake Shore Dr & Ohio St'
# from earlier
fix_dpcapacity('DuSable Lake Shore Dr & Ohio St', 21)

# %%
# 'Lamon Ave & Archer Ave' does not exist on google maps, allocate
# --> 'Lawler & 50th St'
merged2013_2022.loc[merged2013_2022['start_station_name'] == 'Lamon Ave & Archer Ave', 'start_station_name'] = 'Lawler & 50th St'
merged2013_2022.loc[merged2013_2022['end_station_name'] == 'Lamon Ave & Archer Ave', 'end_station_name'] = 'Lawler & 50th St'
fix_dpcapacity('Lawler & 50th St', 8)

# %%
# 'Linder Ave & Archer Ave' station was permanently closed, cannot find dpcapacity or find on google maps, find out how
# significant it is and give it a number based on average give the range of similar station dpcapacity or delete
merged2013_2022[merged2013_2022['start_station_name'] == 'Linder Ave & Archer Ave']
# Out:
# Empty DataFrame
# Columns: [start_time, end_time, tripduration, start_station_id, start_station_name, end_station_id, end_station_name, usertype, gender, birthyear, start_lat, start_lng, end_lat, end_lng, rideable_type, start_city, start_landmark, end_city, end_landmark, start_date, end_date, start_dpcapacity, end_dpcapacity]
# Index: []
#
# [0 rows x 23 columns]

# %%
merged2013_2022[merged2013_2022['end_station_name'] == 'Linder Ave & Archer Ave']
# Out:
#          start_time  end_time  tripduration start_station_id  \
# 26838808   18:37:02  18:53:53          1011              343
#
#             start_station_name end_station_id         end_station_name  \
# 26838808  Pulaski Rd & 51st St            782  Linder Ave & Archer Ave
#
#           usertype  gender  birthyear  ...  end_lng  rideable_type  \
# 26838808         1      -1          0  ...   -87.76              2
#
#           start_city  start_landmark  end_city  end_landmark  start_date  \
# 26838808           0               0         0             0  2022-05-11
#
#             end_date  start_dpcapacity end_dpcapacity
# 26838808  2022-05-11                10             -1
#
# [1 rows x 23 columns]

# %%
# Delete 'Linder Ave & Archer Ave'
index5 = list(set(list(merged2013_2022[merged2013_2022['start_station_name'] == 'Linder Ave & Archer Ave'].index) + list(merged2013_2022[merged2013_2022['end_station_name'] == 'Linder Ave & Archer Ave'].index)))

# %%
# Delete: 'Lyft Driver Center Private Rack'
index6 = list(set(list(merged2013_2022[merged2013_2022['start_station_name'] == 'Lyft Driver Center Private Rack'].index) + list(merged2013_2022[merged2013_2022['end_station_name'] == 'Lyft Driver Center Private Rack'].index)))

# %%
# 'Marshfield Ave & Cortland St' google maps street view 2016
fix_dpcapacity('Marshfield Ave & Cortland St', 23)

# %%
# 'McClurg Ct & Illinois St' google maps street view 2016
fix_dpcapacity('McClurg Ct & Illinois St', 31)

# %%
# Investigate, if the locations are seperate give it a dpcapcity: 1
# else
# 'Public Rack - Sacramento Blvd & Division St' --> 'California Ave & Division St'
merged2013_2022[merged2013_2022['start_station_name'] == 'Public Rack - Sacramento Blvd & Division St']
# Out:
#          start_time  end_time  tripduration start_station_id  \
# 14974254   14:30:37  15:00:55          1818             1059
# 26159521   18:22:16  18:35:03           767             1059
# 26556841   18:30:54  18:34:22           208             1059
# 32005674   22:05:38  22:22:53          1035             1059
# 32222346   22:21:39  22:37:57           978             1059
# 32406878   22:36:41  22:52:26           945             1059
#
#                                    start_station_name end_station_id  \
# 14974254  Public Rack - Sacramento Blvd & Division St   TA1309000041
# 26159521  Public Rack - Sacramento Blvd & Division St   TA1305000041
# 26556841  Public Rack - Sacramento Blvd & Division St            509
# 32005674  Public Rack - Sacramento Blvd & Division St   TA1308000049
# 32222346  Public Rack - Sacramento Blvd & Division St   TA1308000049
# 32406878  Public Rack - Sacramento Blvd & Division St   TA1308000049
#
# ...

# %%
merged2013_2022[merged2013_2022['end_station_name'] == 'Public Rack - Sacramento Blvd & Division St']
# Out:
#          start_time  end_time  tripduration start_station_id  \
# 26469287   18:28:59  18:50:45          1306     TA1308000049
# 26928045   18:39:04  18:56:42          1058     TA1308000049
# 28352470   19:15:50  19:29:53           843               60
# 28605524   19:23:01  19:44:48          1307              512
#
#                                 start_station_name end_station_id  \
# 26469287                  Wells St & Evergreen Ave           1059
# 26928045                  Wells St & Evergreen Ave           1059
# 28352470                     Dayton St & North Ave           1059
# 28605524  Public Rack - California Ave & Cortez St           1059
#
#                                      end_station_name  usertype  gender  \
# 26469287  Public Rack - Sacramento Blvd & Division St         1      -1
# 26928045  Public Rack - Sacramento Blvd & Division St         1      -1
# 28352470  Public Rack - Sacramento Blvd & Division St         1      -1
# ...

# %%
# Deleting 'Public Rack - Sacramento Blvd & Division St'
index7 = list(set(list(merged2013_2022[merged2013_2022['start_station_name'] == 'Public Rack - Sacramento Blvd & Division St'].index) + list(merged2013_2022[merged2013_2022['end_station_name'] == 'Public Rack - Sacramento Blvd & Division St'].index)))

# %%
# 'Public Rack - Waller Ave & Chicago Ave'
fix_dpcapacity('Waller Ave & Chicago Ave', 1)

# %%
# Delete 'WEST CHI-WATSON'
index8 = list(set(list(merged2013_2022[merged2013_2022['start_station_name'] == 'WEST CHI-WATSON'].index) + list(merged2013_2022[merged2013_2022['end_station_name'] == 'WEST CHI-WATSON'].index)))

# %%
# 'Western & 28th - Velasquez Institute' 
# --> 'Western Ave & 28th St'
# dpcapacity: 11
merged2013_2022.loc[merged2013_2022['start_station_name'] == 'Western & 28th - Velasquez Institute', 'start_station_name'] = 'Western Ave & 28th St'
merged2013_2022.loc[merged2013_2022['end_station_name'] == 'Western & 28th - Velasquez Institute', 'end_station_name'] = 'Western Ave & 28th St'
fix_dpcapacity('Western Ave & 28th St', 8)

# %%
# Lastly I will check for any leftover DIVVY station names for deletion.
index9 = list(merged2013_2022[merged2013_2022['start_station_name'].str.lower().str.contains("divvy", regex=False, na=False) == True].index)
index9 += list(merged2013_2022[merged2013_2022['end_station_name'].str.lower().str.contains("divvy", regex=False, na=False) == True].index)
index9 = list(set(index9))

# %%
# Now to remove the values pegged for deletion
final_drop = list(set(index1 + index2 + index3 + index4 + index5 + index6 + index7 + index8 + index9))

# %%
merged2013_2022.drop(final_drop, inplace=True)

# %%
merged2013_2022.reset_index(inplace=True)

# %%
merged2013_2022.to_csv('1 Full Divvy Dataframe pt3.csv')
