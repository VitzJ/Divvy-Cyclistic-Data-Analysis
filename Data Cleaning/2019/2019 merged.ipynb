# %%
import pandas as pd
# pd.concat([, pd.read_csv('Divvy_Trips_2018_Q2.csv'), pd.read_csv('Divvy_Trips_2018_Q3.csv'), pd.read_csv('Divvy_Trips_2018_Q4.csv')], ignore_index=True)
df1 = pd.read_csv('Divvy_Trips_2019_Q1.csv')

# %%
df1
# Out:
#          trip_id           start_time             end_time  bikeid  \
# 0       21742443  2019-01-01 00:04:37  2019-01-01 00:11:07    2167
# 1       21742444  2019-01-01 00:08:13  2019-01-01 00:15:34    4386
# 2       21742445  2019-01-01 00:13:23  2019-01-01 00:27:12    1524
# 3       21742446  2019-01-01 00:13:45  2019-01-01 00:43:28     252
# 4       21742447  2019-01-01 00:14:52  2019-01-01 00:20:56    1170
# ...          ...                  ...                  ...     ...
# 365064  22178524  2019-03-31 23:51:32  2019-04-01 00:04:09    1501
# 365065  22178525  2019-03-31 23:52:37  2019-03-31 23:58:09    3270
# 365066  22178526  2019-03-31 23:52:38  2019-04-01 00:06:44    3584
# 365067  22178527  2019-03-31 23:53:08  2019-03-31 23:56:06    4384
# 365068  22178528  2019-03-31 23:53:48  2019-04-01 00:01:16    5589
#
#        tripduration  from_station_id                    from_station_name  \
# 0             390.0              199               Wabash Ave & Grand Ave
# ...

# %%
df2 = pd.read_csv('Divvy_Trips_2019_Q2.csv')

# %%
df2
# Out:
#          01 - Rental Details Rental ID 01 - Rental Details Local Start Time  \
# 0                             22178529                  2019-04-01 00:02:22
# 1                             22178530                  2019-04-01 00:03:02
# 2                             22178531                  2019-04-01 00:11:07
# 3                             22178532                  2019-04-01 00:13:01
# 4                             22178533                  2019-04-01 00:19:26
# ...                                ...                                  ...
# 1108158                       23479383                  2019-06-30 23:58:00
# 1108159                       23479384                  2019-06-30 23:58:04
# 1108160                       23479385                  2019-06-30 23:58:20
# 1108161                       23479386                  2019-06-30 23:58:52
# 1108162                       23479387                  2019-06-30 23:59:05
#
# ...

# %%
df2 = df2.rename(columns = {'01 - Rental Details Rental ID': 'trip_id', '01 - Rental Details Local Start Time' : 'start_time', '01 - Rental Details Local End Time' : 'end_time','01 - Rental Details Bike ID' : 'bikeid', '01 - Rental Details Duration In Seconds Uncapped' : 'tripduration', '03 - Rental Start Station ID' : 'from_station_id','01 - Rental Details Bike ID' : 'bikeid', '01 - Rental Details Duration In Seconds Uncapped' : 'tripduration', '03 - Rental Start Station ID' : 'from_station_id','03 - Rental Start Station Name' : 'from_station_name','02 - Rental End Station ID':'to_station_id','02 - Rental End Station Name':'to_station_name','User Type' : 'usertype','Member Gender':'gender','05 - Member Details Member Birthday Year':'birthyear'})

# %%
df2
# Out:
#           trip_id           start_time             end_time  bikeid  \
# 0        22178529  2019-04-01 00:02:22  2019-04-01 00:09:48    6251
# 1        22178530  2019-04-01 00:03:02  2019-04-01 00:20:30    6226
# 2        22178531  2019-04-01 00:11:07  2019-04-01 00:15:19    5649
# 3        22178532  2019-04-01 00:13:01  2019-04-01 00:18:58    4151
# 4        22178533  2019-04-01 00:19:26  2019-04-01 00:36:13    3270
# ...           ...                  ...                  ...     ...
# 1108158  23479383  2019-06-30 23:58:00  2019-07-01 00:20:22    4573
# 1108159  23479384  2019-06-30 23:58:04  2019-07-01 00:14:17    6301
# 1108160  23479385  2019-06-30 23:58:20  2019-07-01 00:25:51    4472
# 1108161  23479386  2019-06-30 23:58:52  2019-07-01 00:11:24    5021
# 1108162  23479387  2019-06-30 23:59:05  2019-07-01 00:26:14    4749
#
#         tripduration  from_station_id              from_station_name  \
# 0              446.0               81             Daley Center Plaza
# ...

# %%
df3 = pd.read_csv('Divvy_Trips_2019_Q3.csv')

# %%
df3
# Out:
#           trip_id           start_time             end_time  bikeid  \
# 0        23479388  2019-07-01 00:00:27  2019-07-01 00:20:41    3591
# 1        23479389  2019-07-01 00:01:16  2019-07-01 00:18:44    5353
# 2        23479390  2019-07-01 00:01:48  2019-07-01 00:27:42    6180
# 3        23479391  2019-07-01 00:02:07  2019-07-01 00:27:10    5540
# 4        23479392  2019-07-01 00:02:13  2019-07-01 00:22:26    6014
# ...           ...                  ...                  ...     ...
# 1640713  25223635  2019-09-30 23:56:27  2019-10-01 00:06:20    5690
# 1640714  25223636  2019-09-30 23:57:02  2019-10-01 00:02:13    5079
# 1640715  25223637  2019-09-30 23:57:45  2019-10-01 00:01:41    5535
# 1640716  25223638  2019-09-30 23:57:47  2019-10-01 00:04:41    6120
# 1640717  25223639  2019-09-30 23:59:37  2019-10-01 00:05:17      60
#
#         tripduration  from_station_id                 from_station_name  \
# 0            1,214.0              117          Wilton Ave & Belmont Ave
# ...

# %%
df4 = pd.read_csv('Divvy_Trips_2019_Q4.csv')

# %%
df4
# Out:
#          trip_id           start_time             end_time  bikeid  \
# 0       25223640  2019-10-01 00:01:39  2019-10-01 00:17:20    2215
# 1       25223641  2019-10-01 00:02:16  2019-10-01 00:06:34    6328
# 2       25223642  2019-10-01 00:04:32  2019-10-01 00:18:43    3003
# 3       25223643  2019-10-01 00:04:32  2019-10-01 00:43:43    3275
# 4       25223644  2019-10-01 00:04:34  2019-10-01 00:35:42    5294
# ...          ...                  ...                  ...     ...
# 704049  25962900  2019-12-31 23:56:13  2020-01-01 00:15:45    2196
# 704050  25962901  2019-12-31 23:56:34  2020-01-01 00:22:08    4877
# 704051  25962902  2019-12-31 23:57:05  2020-01-01 00:05:46     863
# 704052  25962903  2019-12-31 23:57:11  2020-01-01 00:05:45    2637
# 704053  25962904  2019-12-31 23:57:17  2019-12-31 23:59:18    5930
#
#        tripduration  from_station_id               from_station_name  \
# 0             940.0               20    Sheffield Ave & Kingsbury St
# ...

# %%
df = pd.concat([df1,df2,df3,df4], ignore_index=True)

# %%
df
# Out:
#           trip_id           start_time             end_time  bikeid  \
# 0        21742443  2019-01-01 00:04:37  2019-01-01 00:11:07    2167
# 1        21742444  2019-01-01 00:08:13  2019-01-01 00:15:34    4386
# 2        21742445  2019-01-01 00:13:23  2019-01-01 00:27:12    1524
# 3        21742446  2019-01-01 00:13:45  2019-01-01 00:43:28     252
# 4        21742447  2019-01-01 00:14:52  2019-01-01 00:20:56    1170
# ...           ...                  ...                  ...     ...
# 3817999  25962900  2019-12-31 23:56:13  2020-01-01 00:15:45    2196
# 3818000  25962901  2019-12-31 23:56:34  2020-01-01 00:22:08    4877
# 3818001  25962902  2019-12-31 23:57:05  2020-01-01 00:05:46     863
# 3818002  25962903  2019-12-31 23:57:11  2020-01-01 00:05:45    2637
# 3818003  25962904  2019-12-31 23:57:17  2019-12-31 23:59:18    5930
#
#         tripduration  from_station_id                    from_station_name  \
# ...

# %%
df.to_csv('Divvy 2019 nostation.csv')
